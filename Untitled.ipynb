# %%
from qiskit import QuantumCircuit, transpile
from qiskit.quantum_info import Statevector, DensityMatrix, state_fidelity, partial_trace
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from qiskit.circuit.library import standard_gates
from qiskit_aer import Aer
import time
import numpy as np
import json
import random
import math
import inspect
import itertools

# %%
def openFile(gate):
    with open(gate, 'r') as f:
        data = dict(json.load(f))
    return data

# %%
PI = math.pi
SEED = 11
random.seed(SEED)
TARGET = []
PENALTY_QUBITS = 0.1

# %%
# Gerando um vetor aleatório complexo com norma 1
num_qubits = 3  # Número de qubits desejado
dim = 2**num_qubits
random_vector = np.random.rand(dim) + 1j * np.random.rand(dim)
random_vector /= np.linalg.norm(random_vector)

# Criando o statevector a partir do vetor aleatório
svTarget = Statevector(random_vector)
print(svTarget)
# Out:
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))

# %%
removeString = ['barrier', 'pauli', 'append', 'cast','clear', 'compose','control', 'copy', 'decompose', 'delay', 'depth', 'draw', 'initialize', 'inverse', 'measure','power', 'repeat', 'reset', 'size','store', 'switch', 'tensor', 'unitary', 'width']
# Talvez -> ctrl_state
parametersOk = ['pauli_string', 'vz', 'target_qubit1', 'vy', 'phi','vx', 'qargs', 'control_qubits', 'q_target', 'target_qubit2', 'qubits', 'theta', 'qubit2', 'q_controls', 'target_qubit','gamma', 'qubit', 'control_qubit3', 'ancilla_qubits', 'control_qubit1', 'control_qubit', 'q_ancillae', 'control_qubit2', 'qubit1', 'lam']

# %%
def get_classes(module):
    gates = [(name,cls) for name, cls in inspect.getmembers(module) if inspect.isfunction(cls) and not (name.count('add') or name.count('_'))]
    gates = [(name, cls) for name, cls in gates if not name in removeString]
    return gates

# %%
classes = get_classes(QuantumCircuit)
typesDict = {
    "QubitSpecifier": ["int"],
    "<class 'qiskit.circuit.quantumregister.Qubit'>": ["int"],
    "Sequence[QubitSpecifier] | None": ["int", "None"],
    "typing.Union[qiskit.circuit.quantumregister.QuantumRegister, typing.List[qiskit.circuit.quantumregister.Qubit]]": ["int", "list[int]"],
    "Sequence[QubitSpecifier]": ["list[int]"],
    "QubitSpecifier | Sequence[QubitSpecifier] | None": ["int", "list[int]", "None"],
    "typing.Union[qiskit.circuit.quantumregister.QuantumRegister, typing.Tuple[qiskit.circuit.quantumregister.QuantumRegister, int], NoneType]": ["int", "list[int]", "None"],
    "typing.Union[qiskit.circuit.parameterexpression.ParameterExpression, float]": ["float"],
    "ParameterValueType": ["float"],
    "str": ["str"],
}
gatesParameters = {}
# Iterando sobre os parâmetros
for name, classe in classes:
    init_signature = inspect.signature(classe)
    #print(classe)
    gatesParameters[name] = dict()
    for parameter_name, parameter in init_signature.parameters.items():
        if parameter_name in parametersOk:
            gatesParameters[name][parameter_name] = typesDict[str(parameter.annotation)]
            #print(f"    Parâmetro: {parameter_name}, Tipo anotado: {parameter.annotation} -> {type(parameter.annotation)}")
parameters = [name for gateName, gateInfo in gatesParameters.items() for name in gateInfo.keys()]
#print(set(parameters))
gatesParameters
# Out:
# {'ccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int']},
#  'ccz': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int']},
#  'ch': {'control_qubit': ['int'], 'target_qubit': ['int']},
#  'cp': {'theta': ['float'], 'control_qubit': ['int'], 'target_qubit': ['int']},
#  'crx': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int']},
#  'cry': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int']},
#  'crz': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int']},
#  'cs': {'control_qubit': ['int'], 'target_qubit': ['int']},
#  'csdg': {'control_qubit': ['int'], 'target_qubit': ['int']},
#  'cswap': {'control_qubit': ['int'],
#   'target_qubit1': ['int'],
#   'target_qubit2': ['int']},
#  'csx': {'control_qubit': ['int'], 'target_qubit': ['int']},
#  'cu': {'theta': ['float'],
#   'phi': ['float'],
#   'lam': ['float'],
#   'gamma': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int']},
#  'cx': {'control_qubit': ['int'], 'target_qubit': ['int']},
#  'cy': {'control_qubit': ['int'], 'target_qubit': ['int']},
#  'cz': {'control_qubit': ['int'], 'target_qubit': ['int']},
#  'dcx': {'qubit1': ['int'], 'qubit2': ['int']},
#  'ecr': {'qubit1': ['int'], 'qubit2': ['int']},
#  'h': {'qubit': ['int']},
#  'id': {'qubit': ['int']},
#  'iswap': {'qubit1': ['int'], 'qubit2': ['int']},
#  'mcp': {'lam': ['float'],
#   'control_qubits': ['list[int]'],
#   'target_qubit': ['int']},
#  'mcrx': {'theta': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int']},
#  'mcry': {'theta': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int'],
#   'q_ancillae': ['int', 'list[int]', 'None']},
#  'mcrz': {'lam': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int']},
#  'mcx': {'control_qubits': ['list[int]'],
#   'target_qubit': ['int'],
#   'ancilla_qubits': ['int', 'list[int]', 'None']},
#  'ms': {'theta': ['float'], 'qubits': ['list[int]']},
#  'p': {'theta': ['float'], 'qubit': ['int']},
#  'r': {'theta': ['float'], 'phi': ['float'], 'qubit': ['int']},
#  'rcccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'control_qubit3': ['int'],
#   'target_qubit': ['int']},
#  'rccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int']},
#  'rv': {'vx': ['float'], 'vy': ['float'], 'vz': ['float'], 'qubit': ['int']},
#  'rx': {'theta': ['float'], 'qubit': ['int']},
#  'rxx': {'theta': ['float'], 'qubit1': ['int'], 'qubit2': ['int']},
#  'ry': {'theta': ['float'], 'qubit': ['int']},
#  'ryy': {'theta': ['float'], 'qubit1': ['int'], 'qubit2': ['int']},
#  'rz': {'phi': ['float'], 'qubit': ['int']},
#  'rzx': {'theta': ['float'], 'qubit1': ['int'], 'qubit2': ['int']},
#  'rzz': {'theta': ['float'], 'qubit1': ['int'], 'qubit2': ['int']},
#  's': {'qubit': ['int']},
#  'sdg': {'qubit': ['int']},
#  'swap': {'qubit1': ['int'], 'qubit2': ['int']},
#  'sx': {'qubit': ['int']},
#  'sxdg': {'qubit': ['int']},
#  't': {'qubit': ['int']},
#  'tdg': {'qubit': ['int']},
#  'u': {'theta': ['float'],
#   'phi': ['float'],
#   'lam': ['float'],
#   'qubit': ['int']},
#  'x': {'qubit': ['int']},
#  'y': {'qubit': ['int']},
#  'z': {'qubit': ['int']}}

# %%
for gatename, gateInfo in gatesParameters.items():
    affectedQubits = 0
    controlQubits = 0
    parametersCount = 0
    combinations = []
    valores = [list(v) for v in gateInfo.values()]
    combinacoes = itertools.product(*valores)
    gateInfo["info"] = {}
    # (Qubits, Parameters, Strs)
    gateInfo["info"]["combinations"] = [(x, x.count("int") + x.count("list[int]"), x.count("float"), x.count("str")) for x in combinacoes]

# %%
gatesParameters
# Out:
# {'ccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int', 'int'), 3, 0, 0)]}},
#  'ccz': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int', 'int'), 3, 0, 0)]}},
#  'ch': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'cp': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  'crx': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  'cry': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  'crz': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  'cs': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'csdg': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'cswap': {'control_qubit': ['int'],
#   'target_qubit1': ['int'],
#   'target_qubit2': ['int'],
#   'info': {'combinations': [(('int', 'int', 'int'), 3, 0, 0)]}},
#  'csx': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'cu': {'theta': ['float'],
#   'phi': ['float'],
#   'lam': ['float'],
#   'gamma': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('float',
#       'float',
#       'float',
#       'float',
#       'int',
#       'int'),
#      2,
#      4,
#      0)]}},
#  'cx': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'cy': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'cz': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'dcx': {'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'ecr': {'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'h': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'id': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'iswap': {'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'mcp': {'lam': ['float'],
#   'control_qubits': ['list[int]'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('float', 'list[int]', 'int'), 2, 1, 0)]}},
#  'mcrx': {'theta': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0),
#     (('float', 'list[int]', 'int'), 2, 1, 0)]}},
#  'mcry': {'theta': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int'],
#   'q_ancillae': ['int', 'list[int]', 'None'],
#   'info': {'combinations': [(('float', 'int', 'int', 'int'), 3, 1, 0),
#     (('float', 'int', 'int', 'list[int]'), 3, 1, 0),
#     (('float', 'int', 'int', 'None'), 2, 1, 0),
#     (('float', 'list[int]', 'int', 'int'), 3, 1, 0),
#     (('float', 'list[int]', 'int', 'list[int]'), 3, 1, 0),
#     (('float', 'list[int]', 'int', 'None'), 2, 1, 0)]}},
#  'mcrz': {'lam': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0),
#     (('float', 'list[int]', 'int'), 2, 1, 0)]}},
#  'mcx': {'control_qubits': ['list[int]'],
#   'target_qubit': ['int'],
#   'ancilla_qubits': ['int', 'list[int]', 'None'],
#   'info': {'combinations': [(('list[int]', 'int', 'int'), 3, 0, 0),
#     (('list[int]', 'int', 'list[int]'), 3, 0, 0),
#     (('list[int]', 'int', 'None'), 2, 0, 0)]}},
#  'ms': {'theta': ['float'],
#   'qubits': ['list[int]'],
#   'info': {'combinations': [(('float', 'list[int]'), 1, 1, 0)]}},
#  'p': {'theta': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'r': {'theta': ['float'],
#   'phi': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'float', 'int'), 1, 2, 0)]}},
#  'rcccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'control_qubit3': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int', 'int', 'int'), 4, 0, 0)]}},
#  'rccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int', 'int'), 3, 0, 0)]}},
#  'rv': {'vx': ['float'],
#   'vy': ['float'],
#   'vz': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'float', 'float', 'int'), 1, 3, 0)]}},
#  'rx': {'theta': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'rxx': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  'ry': {'theta': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'ryy': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  'rz': {'phi': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'rzx': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  'rzz': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  's': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'sdg': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'swap': {'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'sx': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'sxdg': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  't': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'tdg': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'u': {'theta': ['float'],
#   'phi': ['float'],
#   'lam': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'float', 'float', 'int'), 1, 3, 0)]}},
#  'x': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'y': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'z': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}}}

# %%
class Parameter:
    def __init__(self, name:str, type:list[str]):
        self.name = name
        self.type = type

class Circuit:
    def __init__(self, n_qubits, m_gates) -> None:
        self.n_qubits = n_qubits
        self.m_gates = m_gates
        self.gates = [[] for _ in range(m_gates)]
        self.fitness = None
        self.circuit = None
        
    def constructCircuit(self):
        self.circuit = QuantumCircuit(self.n_qubits)
        print("Construindo Circuito:")
        for gatesInDepth in self.gates:
            print(" Profundidade:")
            for gate in gatesInDepth:
                print(f"    {gate}")
                parametersString = ""
                for type, _, parameter in gate.parameters:
                    parametersString += f"{parameter}"
                    if type == "float":
                        parametersString += f"*{PI}"
                    parametersString += ","
                parametersString = parametersString[:-1]
                exec(f"self.circuit.{gate.name}({parametersString})")
    
    def __str__(self) -> str:
        return f"Circuit [{self.n_qubits} x {self.m_gates}] "

class Gate:
    def __init__(self, name:str, affected_qubits:list[int], gateInfo:dict={}) -> None:
        self.name =  name
        self.affected_qubits = affected_qubits
        self.parameters = gateInfo["combinations"][0]
        #self.gateInfo = gateInfo #? {'combinations': [[['str', 1], ['list[int]', 1, [0]]], 1, 0, 1]}} or {'combinations': [[['int', 1, 2]], 1, 0, 0]}
    def __str__(self) -> str:
        return f"[{self.name}] -> {self.affected_qubits}   -----------  {self.parameters}"

# %%
def fidelityFitnessFunction(circuit:Circuit, svTarget:Statevector, nQubit:int):
    # Mapeamento para um espaço maior (adicionando 5 qubits ancilla em |0⟩)
    difQubit = nQubit - circuit.n_qubits
    print(f"Qubits {nQubit} X {circuit.n_qubits}  --- {difQubit}")
    svTargetLocal = Statevector(svTarget)
    svSolution = Statevector.from_instruction(circuit.circuit)
    if difQubit < 0:
        svTargetLocal = svTargetLocal.tensor(Statevector.from_label('0'*(-difQubit)))
    elif difQubit > 0:
        svSolution = svSolution.tensor(Statevector.from_label('0'*difQubit))
    print(svTargetLocal)
    print(svSolution)
    fidelity = state_fidelity(svSolution, svTargetLocal)
    fidelity = fidelity - abs(nQubit - circuit.n_qubits) * PENALTY_QUBITS
    return max(0, fidelity)

def createGateToListQubits(qubitsFree:list, structLocal:dict):
    for gateName, gateInfo in structLocal.items():
        gateInfo["info"]["combinations"] = [combination for combination in gateInfo["info"]["combinations"] if combination[1] <= len(qubitsFree)]
    structLocal = {gateName: gateInfo for gateName, gateInfo in structLocal.items() if len(gateInfo["info"]["combinations"])}

    gateName, gateInfo = random.choice(list(structLocal.items()))
    gateInfo = gateInfo.copy()
    gateCounts = gateInfo.pop("info").copy()
    gateCounts["combinations"] = list(random.choice(gateCounts["combinations"]))
    gateCounts["combinations"][0] = list(gateCounts["combinations"][0])
    countFree = len(qubitsFree) - gateCounts["combinations"][1]
    types = []
    for type in gateCounts["combinations"][0]:
        type = [type, 1 if type != "None" else 0]
        if type.count("list[int]"):
            addCount = random.randint(0, countFree)
            countFree -= addCount
            type[1] += addCount
            gateCounts["combinations"][1] += addCount
        types.append(type)
    gateCounts["combinations"][0] = types
    
    qubitsChoice = random.sample(qubitsFree, gateCounts["combinations"][1])
    affectedQubits = list(qubitsChoice)
    qubitsFree = list(set(qubitsFree).difference(qubitsChoice))
    for param in gateCounts["combinations"][0]:
        if param[0] in ["int", "list[int]"]:
            qubits = random.sample(qubitsChoice, param[1])
            qubitsChoice = list(set(qubitsChoice).difference(qubits))
            if  param[0] == "int":
                qubits = qubits[0]
            param.append(qubits)
        elif param[0] == "float":
            param.append(random.uniform(0, 2)) #! Adicionar Estratégia Evolucionária
        #! Adicionar caso de str para o Pauli String
    gate = Gate(gateName, affectedQubits, gateCounts)
    return gate, qubitsFree

def createCircuit(numQubits, maxDepth, minDepth):
    depth = random.randint(minDepth, maxDepth)
    circuit = Circuit(numQubits, depth)
    print(f"Circuito = {numQubits} x {depth}:")
    for y in range(depth):
        print(f"    Depth {y}:")
        gatesParametersLocal = gatesParameters.copy()
        qubitsFree = list(range(numQubits))
        while qubitsFree:
            gate, qubitsFree = createGateToListQubits(qubitsFree, gatesParametersLocal)
            print(f"        {gate}")
            circuit.gates[y].append(gate)
    return circuit

def initialPopulation(numPopulation:int, numQubits:int, maxDepth:int, minDepth:int=0):
    population = []
    for _ in range(numPopulation):
        circuit = createCircuit(numQubits, maxDepth, minDepth)
        circuit.constructCircuit()
        circuit.fitness = fidelityFitnessFunction(circuit, svTarget, num_qubits)
        population.append(circuit)
    return population



def generations(population:list[Circuit], maxGeneration:int, svTarget:Statevector):
    for gen in range(maxGeneration):
        populationSelected = selection(population, svTarget)
        #populationNextGen = crossover(populationSelected)
    return populationSelected, len(populationSelected)
        #populationNextGen = mutation(populationNextGen)
        #population = selection(population + populationNextGen, svTarget)

def selection(population:list[Circuit], svTarget:Statevector):
    populationLocal = list(population)
    random.shuffle(populationLocal)
    lenPopulation = len(populationLocal)
    lenGroup = int(lenPopulation * 0.05)
    maxLenChampions = lenPopulation//2
    champions = []
    groups = [populationLocal[i:i+lenGroup] for i in range(0, lenPopulation, lenGroup)]
    for group in groups:
        champion = max(group, key=lambda circuit: circuit.fitness)
        populationLocal.remove(champion)
        champions.append(champion)

    while (maxLenChampions > len(champions)):
        lenPopulation = len(populationLocal)
        random.shuffle(populationLocal)
        group = populationLocal[:int(lenPopulation * 0.03)]
        champion = max(group, key=lambda circuit: fidelityFitnessFunction(circuit, svTarget, num_qubits))
        populationLocal.remove(champion)
        champions.append(champion)
    return champions
def crossover():
    pass
def mutation():
    pass
def survivorSelection():
    pass

# %%
#createPopulation(10,2, 5)
population = initialPopulation(100, 3, 10)
# Out:
# Circuito = 3 x 7:
#     Depth 0:
#         [h] -> [2]   -----------  [['int', 1, 2]]
#         [r] -> [0]   -----------  [['float', 1, 0.08290221816972365], ['float', 1, 1.7982640896715738], ['int', 1, 0]]
#         [t] -> [1]   -----------  [['int', 1, 1]]
#     Depth 1:
#         [t] -> [1]   -----------  [['int', 1, 1]]
#         [y] -> [0]   -----------  [['int', 1, 0]]
#         [rx] -> [2]   -----------  [['float', 1, 1.1417489118408797], ['int', 1, 2]]
#     Depth 2:
#         [z] -> [1]   -----------  [['int', 1, 1]]
#         [u] -> [2]   -----------  [['float', 1, 0.6467591637707624], ['float', 1, 1.5861364275106402], ['float', 1, 1.5160249239236352], ['int', 1, 2]]
#         [sxdg] -> [0]   -----------  [['int', 1, 0]]
#     Depth 3:
#         [r] -> [0]   -----------  [['float', 1, 1.1486377935965262], ['float', 1, 0.7083560742170565], ['int', 1, 0]]
#         [s] -> [2]   -----------  [['int', 1, 2]]
#         [ry] -> [1]   -----------  [['float', 1, 1.9690122237205714], ['int', 1, 1]]
#     Depth 4:
#         [u] -> [1]   -----------  [['float', 1, 1.4981315760283676], ['float', 1, 1.9654472103543845], ['float', 1, 0.3191154398232139], ['int', 1, 1]]
#         [rv] -> [2]   -----------  [['float', 1, 1.705724630310899], ['float', 1, 0.06117366849204098], ['float', 1, 1.913188749294978], ['int', 1, 2]]
#         [x] -> [0]   -----------  [['int', 1, 0]]
#     Depth 5:
#         [ry] -> [2]   -----------  [['float', 1, 1.1527146427176331], ['int', 1, 2]]
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
#         [h] -> [0]   -----------  [['int', 1, 0]]
#     Depth 6:
#         [z] -> [2]   -----------  [['int', 1, 2]]
#         [sx] -> [1]   -----------  [['int', 1, 1]]
#         [z] -> [0]   -----------  [['int', 1, 0]]
# Construindo Circuito:
#  Profundidade:
#     [h] -> [2]   -----------  [['int', 1, 2]]
#     [r] -> [0]   -----------  [['float', 1, 0.08290221816972365], ['float', 1, 1.7982640896715738], ['int', 1, 0]]
#     [t] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [t] -> [1]   -----------  [['int', 1, 1]]
#     [y] -> [0]   -----------  [['int', 1, 0]]
#     [rx] -> [2]   -----------  [['float', 1, 1.1417489118408797], ['int', 1, 2]]
#  Profundidade:
#     [z] -> [1]   -----------  [['int', 1, 1]]
#     [u] -> [2]   -----------  [['float', 1, 0.6467591637707624], ['float', 1, 1.5861364275106402], ['float', 1, 1.5160249239236352], ['int', 1, 2]]
#     [sxdg] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [r] -> [0]   -----------  [['float', 1, 1.1486377935965262], ['float', 1, 0.7083560742170565], ['int', 1, 0]]
#     [s] -> [2]   -----------  [['int', 1, 2]]
#     [ry] -> [1]   -----------  [['float', 1, 1.9690122237205714], ['int', 1, 1]]
#  Profundidade:
#     [u] -> [1]   -----------  [['float', 1, 1.4981315760283676], ['float', 1, 1.9654472103543845], ['float', 1, 0.3191154398232139], ['int', 1, 1]]
#     [rv] -> [2]   -----------  [['float', 1, 1.705724630310899], ['float', 1, 0.06117366849204098], ['float', 1, 1.913188749294978], ['int', 1, 2]]
#     [x] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [ry] -> [2]   -----------  [['float', 1, 1.1527146427176331], ['int', 1, 2]]
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
#     [h] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [z] -> [2]   -----------  [['int', 1, 2]]
#     [sx] -> [1]   -----------  [['int', 1, 1]]
#     [z] -> [0]   -----------  [['int', 1, 0]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.76449397+0.33491238j,  0.07874767-0.28254871j,
#               0.29331171-0.15922468j, -0.02184773+0.11523484j,
#              -0.09934606+0.24675435j, -0.04509068-0.08188797j,
#               0.03126211-0.10166754j,  0.02072758+0.03110695j],
#             dims=(2, 2, 2))
# Circuito = 3 x 5:
#     Depth 0:
#         [sdg] -> [2]   -----------  [['int', 1, 2]]
#         [ry] -> [1]   -----------  [['float', 1, 0.268777903436328], ['int', 1, 1]]
#         [tdg] -> [0]   -----------  [['int', 1, 0]]
#     Depth 1:
#         [z] -> [2]   -----------  [['int', 1, 2]]
#         [sx] -> [0]   -----------  [['int', 1, 0]]
#         [u] -> [1]   -----------  [['float', 1, 1.1605282616877097], ['float', 1, 0.7968865879772697], ['float', 1, 1.0922311479667894], ['int', 1, 1]]
#     Depth 2:
#         [z] -> [2]   -----------  [['int', 1, 2]]
#         [r] -> [1]   -----------  [['float', 1, 1.1439298992142957], ['float', 1, 0.5083879756549905], ['int', 1, 1]]
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#     Depth 3:
#         [ms] -> [0, 1, 2]   -----------  [['float', 1, 0.11493351382403083], ['list[int]', 3, [1, 2, 0]]]
#     Depth 4:
#         [s] -> [2]   -----------  [['int', 1, 2]]
#         [x] -> [0]   -----------  [['int', 1, 0]]
#         [s] -> [1]   -----------  [['int', 1, 1]]
# Construindo Circuito:
#  Profundidade:
#     [sdg] -> [2]   -----------  [['int', 1, 2]]
#     [ry] -> [1]   -----------  [['float', 1, 0.268777903436328], ['int', 1, 1]]
#     [tdg] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [z] -> [2]   -----------  [['int', 1, 2]]
#     [sx] -> [0]   -----------  [['int', 1, 0]]
#     [u] -> [1]   -----------  [['float', 1, 1.1605282616877097], ['float', 1, 0.7968865879772697], ['float', 1, 1.0922311479667894], ['int', 1, 1]]
#  Profundidade:
#     [z] -> [2]   -----------  [['int', 1, 2]]
#     [r] -> [1]   -----------  [['float', 1, 1.1439298992142957], ['float', 1, 0.5083879756549905], ['int', 1, 1]]
#     [sdg] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [ms] -> [0, 1, 2]   -----------  [['float', 1, 0.11493351382403083], ['list[int]', 3, [1, 2, 0]]]
#  Profundidade:
#     [s] -> [2]   -----------  [['int', 1, 2]]
#     [x] -> [0]   -----------  [['int', 1, 0]]
#     [s] -> [1]   -----------  [['int', 1, 1]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.61016081-0.10650383j,  0.61016081+0.10650383j,
#               0.26867021-0.16850435j, -0.26867021+0.16850435j,
#               0.08339133-0.03061943j, -0.08339133+0.03061943j,
#              -0.03061943-0.08339133j,  0.03061943+0.08339133j],
#             dims=(2, 2, 2))
# Circuito = 3 x 9:
#     Depth 0:
#         [s] -> [1]   -----------  [['int', 1, 1]]
#         [ms] -> [2, 0]   -----------  [['float', 1, 0.7752108786438765], ['list[int]', 2, [0, 2]]]
#     Depth 1:
#         [rz] -> [1]   -----------  [['float', 1, 1.9559011423989061], ['int', 1, 1]]
#         [h] -> [2]   -----------  [['int', 1, 2]]
#         [t] -> [0]   -----------  [['int', 1, 0]]
#     Depth 2:
#         [ry] -> [0]   -----------  [['float', 1, 0.5797909730353143], ['int', 1, 0]]
#         [sdg] -> [2]   -----------  [['int', 1, 2]]
#         [s] -> [1]   -----------  [['int', 1, 1]]
#     Depth 3:
#         [y] -> [2]   -----------  [['int', 1, 2]]
#         [ms] -> [0, 1]   -----------  [['float', 1, 0.1239243326090973], ['list[int]', 2, [1, 0]]]
#     Depth 4:
#         [h] -> [2]   -----------  [['int', 1, 2]]
#         [rz] -> [1]   -----------  [['float', 1, 0.22618799432850234], ['int', 1, 1]]
#         [s] -> [0]   -----------  [['int', 1, 0]]
#     Depth 5:
#         [x] -> [2]   -----------  [['int', 1, 2]]
#         [x] -> [0]   -----------  [['int', 1, 0]]
#         [rz] -> [1]   -----------  [['float', 1, 1.0052416115310494], ['int', 1, 1]]
#     Depth 6:
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
#         [sdg] -> [2]   -----------  [['int', 1, 2]]
#         [rz] -> [0]   -----------  [['float', 1, 1.2622833587387023], ['int', 1, 0]]
#     Depth 7:
#         [r] -> [0]   -----------  [['float', 1, 1.2932823909321824], ['float', 1, 0.5079987228969607], ['int', 1, 0]]
#         [ms] -> [2, 1]   -----------  [['float', 1, 1.4390404191384707], ['list[int]', 2, [2, 1]]]
#     Depth 8:
#         [t] -> [1]   -----------  [['int', 1, 1]]
#         [y] -> [0]   -----------  [['int', 1, 0]]
#         [sdg] -> [2]   -----------  [['int', 1, 2]]
# Construindo Circuito:
#  Profundidade:
#     [s] -> [1]   -----------  [['int', 1, 1]]
#     [ms] -> [2, 0]   -----------  [['float', 1, 0.7752108786438765], ['list[int]', 2, [0, 2]]]
#  Profundidade:
#     [rz] -> [1]   -----------  [['float', 1, 1.9559011423989061], ['int', 1, 1]]
#     [h] -> [2]   -----------  [['int', 1, 2]]
#     [t] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [ry] -> [0]   -----------  [['float', 1, 0.5797909730353143], ['int', 1, 0]]
#     [sdg] -> [2]   -----------  [['int', 1, 2]]
#     [s] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [y] -> [2]   -----------  [['int', 1, 2]]
#     [ms] -> [0, 1]   -----------  [['float', 1, 0.1239243326090973], ['list[int]', 2, [1, 0]]]
#  Profundidade:
#     [h] -> [2]   -----------  [['int', 1, 2]]
#     [rz] -> [1]   -----------  [['float', 1, 0.22618799432850234], ['int', 1, 1]]
#     [s] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [x] -> [2]   -----------  [['int', 1, 2]]
#     [x] -> [0]   -----------  [['int', 1, 0]]
#     [rz] -> [1]   -----------  [['float', 1, 1.0052416115310494], ['int', 1, 1]]
#  Profundidade:
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
#     [sdg] -> [2]   -----------  [['int', 1, 2]]
#     [rz] -> [0]   -----------  [['float', 1, 1.2622833587387023], ['int', 1, 0]]
#  Profundidade:
#     [r] -> [0]   -----------  [['float', 1, 1.2932823909321824], ['float', 1, 0.5079987228969607], ['int', 1, 0]]
#     [ms] -> [2, 1]   -----------  [['float', 1, 1.4390404191384707], ['list[int]', 2, [2, 1]]]
#  Profundidade:
#     [t] -> [1]   -----------  [['int', 1, 1]]
#     [y] -> [0]   -----------  [['int', 1, 0]]
#     [sdg] -> [2]   -----------  [['int', 1, 2]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 1.88764088e-01+0.1876912j ,  4.23504298e-01+0.2155645j ,
#               6.53764607e-05-0.23134901j, -3.13583852e-01+0.22955501j,
#               2.31905460e-01+0.15063636j,  6.43399966e-02-0.46350427j,
#              -9.59845174e-03+0.18958763j,  1.42690628e-01+0.38330141j],
#             dims=(2, 2, 2))
# Circuito = 3 x 2:
#     Depth 0:
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#         [tdg] -> [2]   -----------  [['int', 1, 2]]
#         [t] -> [0]   -----------  [['int', 1, 0]]
#     Depth 1:
#         [rz] -> [0]   -----------  [['float', 1, 0.9382610436311536], ['int', 1, 0]]
#         [h] -> [2]   -----------  [['int', 1, 2]]
#         [ms] -> [1]   -----------  [['float', 1, 1.1860435273326786], ['list[int]', 1, [1]]]
# Construindo Circuito:
#  Profundidade:
#     [sdg] -> [1]   -----------  [['int', 1, 1]]
#     [tdg] -> [2]   -----------  [['int', 1, 2]]
#     [t] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [rz] -> [0]   -----------  [['float', 1, 0.9382610436311536], ['int', 1, 0]]
#     [h] -> [2]   -----------  [['int', 1, 2]]
#     [ms] -> [1]   -----------  [['float', 1, 1.1860435273326786], ['list[int]', 1, [1]]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([0.0684673-0.70378422j, 0.       +0.j        ,
#              0.       +0.j        , 0.       +0.j        ,
#              0.0684673-0.70378422j, 0.       +0.j        ,
#              0.       +0.j        , 0.       +0.j        ],
#             dims=(2, 2, 2))
# Circuito = 3 x 3:
#     Depth 0:
#         [t] -> [2]   -----------  [['int', 1, 2]]
#         [s] -> [0]   -----------  [['int', 1, 0]]
#         [rv] -> [1]   -----------  [['float', 1, 1.5816540283056404], ['float', 1, 1.388680987421594], ['float', 1, 0.6765839775925448], ['int', 1, 1]]
#     Depth 1:
#         [p] -> [1]   -----------  [['float', 1, 0.5453189309238125], ['int', 1, 1]]
#         [y] -> [0]   -----------  [['int', 1, 0]]
#         [p] -> [2]   -----------  [['float', 1, 0.3946229202867195], ['int', 1, 2]]
#     Depth 2:
#         [u] -> [0]   -----------  [['float', 1, 0.2839907368897525], ['float', 1, 1.3274954297320498], ['float', 1, 0.9613841784819213], ['int', 1, 0]]
#         [p] -> [2]   -----------  [['float', 1, 1.5318427490397564], ['int', 1, 2]]
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
# Construindo Circuito:
#  Profundidade:
#     [t] -> [2]   -----------  [['int', 1, 2]]
#     [s] -> [0]   -----------  [['int', 1, 0]]
#     [rv] -> [1]   -----------  [['float', 1, 1.5816540283056404], ['float', 1, 1.388680987421594], ['float', 1, 0.6765839775925448], ['int', 1, 1]]
#  Profundidade:
#     [p] -> [1]   -----------  [['float', 1, 0.5453189309238125], ['int', 1, 1]]
#     [y] -> [0]   -----------  [['int', 1, 0]]
#     [p] -> [2]   -----------  [['float', 1, 0.3946229202867195], ['int', 1, 2]]
#  Profundidade:
#     [u] -> [0]   -----------  [['float', 1, 0.2839907368897525], ['float', 1, 1.3274954297320498], ['float', 1, 0.9613841784819213], ['int', 1, 0]]
#     [p] -> [2]   -----------  [['float', 1, 1.5318427490397564], ['int', 1, 2]]
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.09199303-0.39980186j,  0.61697505-0.5959899j ,
#              -0.00585042-0.13343359j,  0.23271872-0.15439183j,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ],
#             dims=(2, 2, 2))
# Circuito = 3 x 10:
#     Depth 0:
#         [h] -> [2]   -----------  [['int', 1, 2]]
#         [u] -> [0]   -----------  [['float', 1, 0.027639303405113225], ['float', 1, 1.345327334706845], ['float', 1, 1.6979875095322], ['int', 1, 0]]
#         [rz] -> [1]   -----------  [['float', 1, 0.4631483818400335], ['int', 1, 1]]
#     Depth 1:
#         [id] -> [2]   -----------  [['int', 1, 2]]
#         [z] -> [0]   -----------  [['int', 1, 0]]
#         [rx] -> [1]   -----------  [['float', 1, 1.2896728858777193], ['int', 1, 1]]
#     Depth 2:
#         [sxdg] -> [2]   -----------  [['int', 1, 2]]
#         [y] -> [1]   -----------  [['int', 1, 1]]
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#     Depth 3:
#         [rv] -> [1]   -----------  [['float', 1, 0.6404189068359634], ['float', 1, 0.9017111415169659], ['float', 1, 0.4504450547745962], ['int', 1, 1]]
#         [s] -> [0]   -----------  [['int', 1, 0]]
#         [ms] -> [2]   -----------  [['float', 1, 0.28189262788972513], ['list[int]', 1, [2]]]
#     Depth 4:
#         [s] -> [2]   -----------  [['int', 1, 2]]
#         [ry] -> [0]   -----------  [['float', 1, 0.28995911035036115], ['int', 1, 0]]
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#     Depth 5:
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
#         [rv] -> [2]   -----------  [['float', 1, 0.8003738143556287], ['float', 1, 1.8669635720509947], ['float', 1, 0.27635997786969924], ['int', 1, 2]]
#         [rv] -> [0]   -----------  [['float', 1, 0.3322411510778971], ['float', 1, 0.9161394484902223], ['float', 1, 1.6056779012624776], ['int', 1, 0]]
#     Depth 6:
#         [rv] -> [0]   -----------  [['float', 1, 0.6428358448736511], ['float', 1, 1.8521184691214752], ['float', 1, 1.352069999809046], ['int', 1, 0]]
#         [sx] -> [2]   -----------  [['int', 1, 2]]
#         [t] -> [1]   -----------  [['int', 1, 1]]
#     Depth 7:
#         [s] -> [2]   -----------  [['int', 1, 2]]
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#         [t] -> [1]   -----------  [['int', 1, 1]]
#     Depth 8:
#         [r] -> [1]   -----------  [['float', 1, 1.0800640961313874], ['float', 1, 1.4198937037499635], ['int', 1, 1]]
#         [z] -> [2]   -----------  [['int', 1, 2]]
#         [rz] -> [0]   -----------  [['float', 1, 0.4376143232923715], ['int', 1, 0]]
#     Depth 9:
#         [rx] -> [1]   -----------  [['float', 1, 0.8274988043597822], ['int', 1, 1]]
#         [rx] -> [2]   -----------  [['float', 1, 0.48974287697592334], ['int', 1, 2]]
#         [p] -> [0]   -----------  [['float', 1, 0.2985178996959761], ['int', 1, 0]]
# Construindo Circuito:
#  Profundidade:
#     [h] -> [2]   -----------  [['int', 1, 2]]
#     [u] -> [0]   -----------  [['float', 1, 0.027639303405113225], ['float', 1, 1.345327334706845], ['float', 1, 1.6979875095322], ['int', 1, 0]]
#     [rz] -> [1]   -----------  [['float', 1, 0.4631483818400335], ['int', 1, 1]]
#  Profundidade:
#     [id] -> [2]   -----------  [['int', 1, 2]]
#     [z] -> [0]   -----------  [['int', 1, 0]]
#     [rx] -> [1]   -----------  [['float', 1, 1.2896728858777193], ['int', 1, 1]]
#  Profundidade:
#     [sxdg] -> [2]   -----------  [['int', 1, 2]]
#     [y] -> [1]   -----------  [['int', 1, 1]]
#     [sdg] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [rv] -> [1]   -----------  [['float', 1, 0.6404189068359634], ['float', 1, 0.9017111415169659], ['float', 1, 0.4504450547745962], ['int', 1, 1]]
#     [s] -> [0]   -----------  [['int', 1, 0]]
#     [ms] -> [2]   -----------  [['float', 1, 0.28189262788972513], ['list[int]', 1, [2]]]
#  Profundidade:
#     [s] -> [2]   -----------  [['int', 1, 2]]
#     [ry] -> [0]   -----------  [['float', 1, 0.28995911035036115], ['int', 1, 0]]
#     [sdg] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
#     [rv] -> [2]   -----------  [['float', 1, 0.8003738143556287], ['float', 1, 1.8669635720509947], ['float', 1, 0.27635997786969924], ['int', 1, 2]]
#     [rv] -> [0]   -----------  [['float', 1, 0.3322411510778971], ['float', 1, 0.9161394484902223], ['float', 1, 1.6056779012624776], ['int', 1, 0]]
#  Profundidade:
#     [rv] -> [0]   -----------  [['float', 1, 0.6428358448736511], ['float', 1, 1.8521184691214752], ['float', 1, 1.352069999809046], ['int', 1, 0]]
#     [sx] -> [2]   -----------  [['int', 1, 2]]
#     [t] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [s] -> [2]   -----------  [['int', 1, 2]]
#     [sdg] -> [0]   -----------  [['int', 1, 0]]
#     [t] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [r] -> [1]   -----------  [['float', 1, 1.0800640961313874], ['float', 1, 1.4198937037499635], ['int', 1, 1]]
#     [z] -> [2]   -----------  [['int', 1, 2]]
#     [rz] -> [0]   -----------  [['float', 1, 0.4376143232923715], ['int', 1, 0]]
#  Profundidade:
#     [rx] -> [1]   -----------  [['float', 1, 0.8274988043597822], ['int', 1, 1]]
#     [rx] -> [2]   -----------  [['float', 1, 0.48974287697592334], ['int', 1, 2]]
#     [p] -> [0]   -----------  [['float', 1, 0.2985178996959761], ['int', 1, 0]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.02543292-0.39326672j,  0.39878578-0.15700131j,
#              -0.12605886+0.26281033j, -0.31697999-0.00240851j,
#              -0.37528271-0.0007016j , -0.17301522-0.36964042j,
#               0.25730091+0.10412318j,  0.01662827+0.3014049j ],
#             dims=(2, 2, 2))
# Circuito = 3 x 10:
#     Depth 0:
#         [rv] -> [2]   -----------  [['float', 1, 1.2613824473295199], ['float', 1, 1.8411862253150229], ['float', 1, 0.5352989177068344], ['int', 1, 2]]
#         [r] -> [1]   -----------  [['float', 1, 0.22200968480392236], ['float', 1, 0.03875953643519514], ['int', 1, 1]]
#         [id] -> [0]   -----------  [['int', 1, 0]]
#     Depth 1:
#         [h] -> [2]   -----------  [['int', 1, 2]]
#         [t] -> [0]   -----------  [['int', 1, 0]]
#         [r] -> [1]   -----------  [['float', 1, 0.1962314912971539], ['float', 1, 1.0106700682599954], ['int', 1, 1]]
#     Depth 2:
#         [sxdg] -> [1]   -----------  [['int', 1, 1]]
#         [rv] -> [2]   -----------  [['float', 1, 1.7762989480393638], ['float', 1, 0.9635331368761737], ['float', 1, 0.7368335975934892], ['int', 1, 2]]
#         [sx] -> [0]   -----------  [['int', 1, 0]]
#     Depth 3:
#         [x] -> [0]   -----------  [['int', 1, 0]]
#         [sx] -> [2]   -----------  [['int', 1, 2]]
#         [z] -> [1]   -----------  [['int', 1, 1]]
#     Depth 4:
#         [x] -> [1]   -----------  [['int', 1, 1]]
#         [rv] -> [2]   -----------  [['float', 1, 1.4890889748629035], ['float', 1, 0.7097212781586228], ['float', 1, 1.33051142228425], ['int', 1, 2]]
#         [p] -> [0]   -----------  [['float', 1, 0.22168908411575905], ['int', 1, 0]]
#     Depth 5:
#         [z] -> [0]   -----------  [['int', 1, 0]]
#         [sx] -> [2]   -----------  [['int', 1, 2]]
#         [rx] -> [1]   -----------  [['float', 1, 0.9068522489523252], ['int', 1, 1]]
#     Depth 6:
#         [t] -> [1]   -----------  [['int', 1, 1]]
#         [sxdg] -> [0]   -----------  [['int', 1, 0]]
#         [r] -> [2]   -----------  [['float', 1, 0.896272504953135], ['float', 1, 1.1002668895572891], ['int', 1, 2]]
#     Depth 7:
#         [r] -> [2]   -----------  [['float', 1, 1.504545393150529], ['float', 1, 0.7079471419703363], ['int', 1, 2]]
#         [tdg] -> [0]   -----------  [['int', 1, 0]]
#         [sx] -> [1]   -----------  [['int', 1, 1]]
#     Depth 8:
#         [sxdg] -> [1]   -----------  [['int', 1, 1]]
#         [p] -> [0]   -----------  [['float', 1, 1.012945202531162], ['int', 1, 0]]
#         [s] -> [2]   -----------  [['int', 1, 2]]
#     Depth 9:
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#         [t] -> [0]   -----------  [['int', 1, 0]]
#         [t] -> [2]   -----------  [['int', 1, 2]]
# Construindo Circuito:
#  Profundidade:
#     [rv] -> [2]   -----------  [['float', 1, 1.2613824473295199], ['float', 1, 1.8411862253150229], ['float', 1, 0.5352989177068344], ['int', 1, 2]]
#     [r] -> [1]   -----------  [['float', 1, 0.22200968480392236], ['float', 1, 0.03875953643519514], ['int', 1, 1]]
#     [id] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [h] -> [2]   -----------  [['int', 1, 2]]
#     [t] -> [0]   -----------  [['int', 1, 0]]
#     [r] -> [1]   -----------  [['float', 1, 0.1962314912971539], ['float', 1, 1.0106700682599954], ['int', 1, 1]]
#  Profundidade:
#     [sxdg] -> [1]   -----------  [['int', 1, 1]]
#     [rv] -> [2]   -----------  [['float', 1, 1.7762989480393638], ['float', 1, 0.9635331368761737], ['float', 1, 0.7368335975934892], ['int', 1, 2]]
#     [sx] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [x] -> [0]   -----------  [['int', 1, 0]]
#     [sx] -> [2]   -----------  [['int', 1, 2]]
#     [z] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [x] -> [1]   -----------  [['int', 1, 1]]
#     [rv] -> [2]   -----------  [['float', 1, 1.4890889748629035], ['float', 1, 0.7097212781586228], ['float', 1, 1.33051142228425], ['int', 1, 2]]
#     [p] -> [0]   -----------  [['float', 1, 0.22168908411575905], ['int', 1, 0]]
#  Profundidade:
#     [z] -> [0]   -----------  [['int', 1, 0]]
#     [sx] -> [2]   -----------  [['int', 1, 2]]
#     [rx] -> [1]   -----------  [['float', 1, 0.9068522489523252], ['int', 1, 1]]
#  Profundidade:
#     [t] -> [1]   -----------  [['int', 1, 1]]
#     [sxdg] -> [0]   -----------  [['int', 1, 0]]
#     [r] -> [2]   -----------  [['float', 1, 0.896272504953135], ['float', 1, 1.1002668895572891], ['int', 1, 2]]
#  Profundidade:
#     [r] -> [2]   -----------  [['float', 1, 1.504545393150529], ['float', 1, 0.7079471419703363], ['int', 1, 2]]
#     [tdg] -> [0]   -----------  [['int', 1, 0]]
#     [sx] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [sxdg] -> [1]   -----------  [['int', 1, 1]]
#     [p] -> [0]   -----------  [['float', 1, 1.012945202531162], ['int', 1, 0]]
#     [s] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [sdg] -> [1]   -----------  [['int', 1, 1]]
#     [t] -> [0]   -----------  [['int', 1, 0]]
#     [t] -> [2]   -----------  [['int', 1, 2]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.72401   -0.14976386j,  0.26040389+0.06500868j,
#               0.30463337+0.40494949j, -0.10452036-0.15138032j,
#              -0.20689177-0.1083113j ,  0.07344557+0.04234051j,
#               0.05737966+0.14942135j, -0.01860748-0.0550453j ],
#             dims=(2, 2, 2))
# Circuito = 3 x 9:
#     Depth 0:
#         [ry] -> [2]   -----------  [['float', 1, 0.01039946712601858], ['int', 1, 2]]
#         [rx] -> [0]   -----------  [['float', 1, 1.1373665401759916], ['int', 1, 0]]
#         [sx] -> [1]   -----------  [['int', 1, 1]]
#     Depth 1:
#         [r] -> [0]   -----------  [['float', 1, 1.6303515560291246], ['float', 1, 0.9083217656848017], ['int', 1, 0]]
#         [p] -> [2]   -----------  [['float', 1, 1.7575231182496056], ['int', 1, 2]]
#         [h] -> [1]   -----------  [['int', 1, 1]]
#     Depth 2:
#         [u] -> [2]   -----------  [['float', 1, 1.4917330271177893], ['float', 1, 1.7176020915289973], ['float', 1, 1.1339285598353108], ['int', 1, 2]]
#         [rv] -> [0]   -----------  [['float', 1, 1.474257606746696], ['float', 1, 0.005360795383259065], ['float', 1, 0.457057662724647], ['int', 1, 0]]
#         [s] -> [1]   -----------  [['int', 1, 1]]
#     Depth 3:
#         [p] -> [2]   -----------  [['float', 1, 1.1204516952333303], ['int', 1, 2]]
#         [ms] -> [0, 1]   -----------  [['float', 1, 0.39912904929107396], ['list[int]', 2, [1, 0]]]
#     Depth 4:
#         [z] -> [2]   -----------  [['int', 1, 2]]
#         [tdg] -> [0]   -----------  [['int', 1, 0]]
#         [x] -> [1]   -----------  [['int', 1, 1]]
#     Depth 5:
#         [sx] -> [0]   -----------  [['int', 1, 0]]
#         [ms] -> [2, 1]   -----------  [['float', 1, 0.9289261428412103], ['list[int]', 2, [2, 1]]]
#     Depth 6:
#         [r] -> [2]   -----------  [['float', 1, 1.2841389163739205], ['float', 1, 0.8901145643434205], ['int', 1, 2]]
#         [id] -> [0]   -----------  [['int', 1, 0]]
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
#     Depth 7:
#         [id] -> [1]   -----------  [['int', 1, 1]]
#         [tdg] -> [2]   -----------  [['int', 1, 2]]
#         [ms] -> [0]   -----------  [['float', 1, 1.633887320200328], ['list[int]', 1, [0]]]
#     Depth 8:
#         [ry] -> [0]   -----------  [['float', 1, 1.9041477201189738], ['int', 1, 0]]
#         [h] -> [1]   -----------  [['int', 1, 1]]
#         [p] -> [2]   -----------  [['float', 1, 1.6016979999935954], ['int', 1, 2]]
# Construindo Circuito:
#  Profundidade:
#     [ry] -> [2]   -----------  [['float', 1, 0.01039946712601858], ['int', 1, 2]]
#     [rx] -> [0]   -----------  [['float', 1, 1.1373665401759916], ['int', 1, 0]]
#     [sx] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [r] -> [0]   -----------  [['float', 1, 1.6303515560291246], ['float', 1, 0.9083217656848017], ['int', 1, 0]]
#     [p] -> [2]   -----------  [['float', 1, 1.7575231182496056], ['int', 1, 2]]
#     [h] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [u] -> [2]   -----------  [['float', 1, 1.4917330271177893], ['float', 1, 1.7176020915289973], ['float', 1, 1.1339285598353108], ['int', 1, 2]]
#     [rv] -> [0]   -----------  [['float', 1, 1.474257606746696], ['float', 1, 0.005360795383259065], ['float', 1, 0.457057662724647], ['int', 1, 0]]
#     [s] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [p] -> [2]   -----------  [['float', 1, 1.1204516952333303], ['int', 1, 2]]
#     [ms] -> [0, 1]   -----------  [['float', 1, 0.39912904929107396], ['list[int]', 2, [1, 0]]]
#  Profundidade:
#     [z] -> [2]   -----------  [['int', 1, 2]]
#     [tdg] -> [0]   -----------  [['int', 1, 0]]
#     [x] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [sx] -> [0]   -----------  [['int', 1, 0]]
#     [ms] -> [2, 1]   -----------  [['float', 1, 0.9289261428412103], ['list[int]', 2, [2, 1]]]
#  Profundidade:
#     [r] -> [2]   -----------  [['float', 1, 1.2841389163739205], ['float', 1, 0.8901145643434205], ['int', 1, 2]]
#     [id] -> [0]   -----------  [['int', 1, 0]]
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [id] -> [1]   -----------  [['int', 1, 1]]
#     [tdg] -> [2]   -----------  [['int', 1, 2]]
#     [ms] -> [0]   -----------  [['float', 1, 1.633887320200328], ['list[int]', 1, [0]]]
#  Profundidade:
#     [ry] -> [0]   -----------  [['float', 1, 1.9041477201189738], ['int', 1, 0]]
#     [h] -> [1]   -----------  [['int', 1, 1]]
#     [p] -> [2]   -----------  [['float', 1, 1.6016979999935954], ['int', 1, 2]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.00087948-0.03333731j,  0.17636149-0.01304818j,
#              -0.08048339+0.00212324j, -0.03150109-0.42577431j,
#               0.00359282-0.06248214j,  0.33186288+0.00330629j,
#              -0.15084523-0.00867384j,  0.00798208-0.80118786j],
#             dims=(2, 2, 2))
# Circuito = 3 x 10:
#     Depth 0:
#         [y] -> [1]   -----------  [['int', 1, 1]]
#         [x] -> [0]   -----------  [['int', 1, 0]]
#         [tdg] -> [2]   -----------  [['int', 1, 2]]
#     Depth 1:
#         [ry] -> [2]   -----------  [['float', 1, 1.4795695279215046], ['int', 1, 2]]
#         [u] -> [1]   -----------  [['float', 1, 1.1858331805965299], ['float', 1, 1.0170516901687352], ['float', 1, 1.2188486700290124], ['int', 1, 1]]
#         [p] -> [0]   -----------  [['float', 1, 1.0033951930814882], ['int', 1, 0]]
#     Depth 2:
#         [rx] -> [2]   -----------  [['float', 1, 1.5611962381499698], ['int', 1, 2]]
#         [x] -> [1]   -----------  [['int', 1, 1]]
#         [sx] -> [0]   -----------  [['int', 1, 0]]
#     Depth 3:
#         [h] -> [0]   -----------  [['int', 1, 0]]
#         [rv] -> [2]   -----------  [['float', 1, 0.8682851942215168], ['float', 1, 1.0079877176597938], ['float', 1, 0.680910829914823], ['int', 1, 2]]
#         [id] -> [1]   -----------  [['int', 1, 1]]
#     Depth 4:
#         [rv] -> [1]   -----------  [['float', 1, 0.10276293101065503], ['float', 1, 1.370381779112933], ['float', 1, 0.9828755100733013], ['int', 1, 1]]
#         [p] -> [0]   -----------  [['float', 1, 0.40001857369249416], ['int', 1, 0]]
#         [y] -> [2]   -----------  [['int', 1, 2]]
#     Depth 5:
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
#         [rx] -> [0]   -----------  [['float', 1, 0.7788385538896891], ['int', 1, 0]]
#         [s] -> [2]   -----------  [['int', 1, 2]]
#     Depth 6:
#         [x] -> [2]   -----------  [['int', 1, 2]]
#         [s] -> [1]   -----------  [['int', 1, 1]]
#         [h] -> [0]   -----------  [['int', 1, 0]]
#     Depth 7:
#         [r] -> [2]   -----------  [['float', 1, 1.1588541528876126], ['float', 1, 0.437270341908111], ['int', 1, 2]]
#         [p] -> [0]   -----------  [['float', 1, 1.1498034859898751], ['int', 1, 0]]
#         [s] -> [1]   -----------  [['int', 1, 1]]
#     Depth 8:
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#         [h] -> [0]   -----------  [['int', 1, 0]]
#         [t] -> [2]   -----------  [['int', 1, 2]]
#     Depth 9:
#         [h] -> [0]   -----------  [['int', 1, 0]]
#         [r] -> [2]   -----------  [['float', 1, 1.2385734424378185], ['float', 1, 1.6779651791593169], ['int', 1, 2]]
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
# Construindo Circuito:
#  Profundidade:
#     [y] -> [1]   -----------  [['int', 1, 1]]
#     [x] -> [0]   -----------  [['int', 1, 0]]
#     [tdg] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [ry] -> [2]   -----------  [['float', 1, 1.4795695279215046], ['int', 1, 2]]
#     [u] -> [1]   -----------  [['float', 1, 1.1858331805965299], ['float', 1, 1.0170516901687352], ['float', 1, 1.2188486700290124], ['int', 1, 1]]
#     [p] -> [0]   -----------  [['float', 1, 1.0033951930814882], ['int', 1, 0]]
#  Profundidade:
#     [rx] -> [2]   -----------  [['float', 1, 1.5611962381499698], ['int', 1, 2]]
#     [x] -> [1]   -----------  [['int', 1, 1]]
#     [sx] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [h] -> [0]   -----------  [['int', 1, 0]]
#     [rv] -> [2]   -----------  [['float', 1, 0.8682851942215168], ['float', 1, 1.0079877176597938], ['float', 1, 0.680910829914823], ['int', 1, 2]]
#     [id] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [rv] -> [1]   -----------  [['float', 1, 0.10276293101065503], ['float', 1, 1.370381779112933], ['float', 1, 0.9828755100733013], ['int', 1, 1]]
#     [p] -> [0]   -----------  [['float', 1, 0.40001857369249416], ['int', 1, 0]]
#     [y] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
#     [rx] -> [0]   -----------  [['float', 1, 0.7788385538896891], ['int', 1, 0]]
#     [s] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [x] -> [2]   -----------  [['int', 1, 2]]
#     [s] -> [1]   -----------  [['int', 1, 1]]
#     [h] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [r] -> [2]   -----------  [['float', 1, 1.1588541528876126], ['float', 1, 0.437270341908111], ['int', 1, 2]]
#     [p] -> [0]   -----------  [['float', 1, 1.1498034859898751], ['int', 1, 0]]
#     [s] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [sdg] -> [1]   -----------  [['int', 1, 1]]
#     [h] -> [0]   -----------  [['int', 1, 0]]
#     [t] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [h] -> [0]   -----------  [['int', 1, 0]]
#     [r] -> [2]   -----------  [['float', 1, 1.2385734424378185], ['float', 1, 1.6779651791593169], ['int', 1, 2]]
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.00658728-2.94617672e-02j,  0.00478055-2.01170690e-05j,
#               0.10234942-2.03615837e-01j,  0.03503967+8.63405968e-03j,
#              -0.01710619-1.24980603e-01j,  0.01869383-7.04074571e-03j,
#               0.10432595-9.46516982e-01j,  0.14980729-1.72130914e-02j],
#             dims=(2, 2, 2))
# Circuito = 3 x 2:
#     Depth 0:
#         [p] -> [2]   -----------  [['float', 1, 1.9616383201237508], ['int', 1, 2]]
#         [p] -> [0]   -----------  [['float', 1, 1.354022726761532], ['int', 1, 0]]
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#     Depth 1:
#         [rx] -> [0]   -----------  [['float', 1, 1.7127203301890344], ['int', 1, 0]]
#         [p] -> [1]   -----------  [['float', 1, 0.16969191601978695], ['int', 1, 1]]
#         [u] -> [2]   -----------  [['float', 1, 1.23868497844226], ['float', 1, 0.6602988053113248], ['float', 1, 0.5143481218479748], ['int', 1, 2]]
# Construindo Circuito:
#  Profundidade:
#     [p] -> [2]   -----------  [['float', 1, 1.9616383201237508], ['int', 1, 2]]
#     [p] -> [0]   -----------  [['float', 1, 1.354022726761532], ['int', 1, 0]]
#     [sdg] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [rx] -> [0]   -----------  [['float', 1, 1.7127203301890344], ['int', 1, 0]]
#     [p] -> [1]   -----------  [['float', 1, 0.16969191601978695], ['int', 1, 1]]
#     [u] -> [2]   -----------  [['float', 1, 1.23868497844226], ['float', 1, 0.6602988053113248], ['float', 1, 0.5143481218479748], ['int', 1, 2]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([0.32954599+0.j        , 0.        +0.15970041j,
#              0.        +0.j        , 0.        +0.j        ,
#              0.40410326-0.7334294j , 0.35542529+0.19583142j,
#              0.        +0.j        , 0.        +0.j        ],
#             dims=(2, 2, 2))
# Circuito = 3 x 4:
#     Depth 0:
#         [h] -> [0]   -----------  [['int', 1, 0]]
#         [x] -> [2]   -----------  [['int', 1, 2]]
#         [s] -> [1]   -----------  [['int', 1, 1]]
#     Depth 1:
#         [id] -> [2]   -----------  [['int', 1, 2]]
#         [ry] -> [0]   -----------  [['float', 1, 1.2386232374615511], ['int', 1, 0]]
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#     Depth 2:
#         [rv] -> [1]   -----------  [['float', 1, 1.3501948044789753], ['float', 1, 0.45302725542856526], ['float', 1, 0.22701458092995686], ['int', 1, 1]]
#         [id] -> [0]   -----------  [['int', 1, 0]]
#         [tdg] -> [2]   -----------  [['int', 1, 2]]
#     Depth 3:
#         [ry] -> [1]   -----------  [['float', 1, 0.12311077879361099], ['int', 1, 1]]
#         [sxdg] -> [0]   -----------  [['int', 1, 0]]
#         [u] -> [2]   -----------  [['float', 1, 1.4228972751479425], ['float', 1, 1.7690537162901543], ['float', 1, 1.0490874008626878], ['int', 1, 2]]
# Construindo Circuito:
#  Profundidade:
#     [h] -> [0]   -----------  [['int', 1, 0]]
#     [x] -> [2]   -----------  [['int', 1, 2]]
#     [s] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [id] -> [2]   -----------  [['int', 1, 2]]
#     [ry] -> [0]   -----------  [['float', 1, 1.2386232374615511], ['int', 1, 0]]
#     [sdg] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [rv] -> [1]   -----------  [['float', 1, 1.3501948044789753], ['float', 1, 0.45302725542856526], ['float', 1, 0.22701458092995686], ['int', 1, 1]]
#     [id] -> [0]   -----------  [['int', 1, 0]]
#     [tdg] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [ry] -> [1]   -----------  [['float', 1, 0.12311077879361099], ['int', 1, 1]]
#     [sxdg] -> [0]   -----------  [['int', 1, 0]]
#     [u] -> [2]   -----------  [['float', 1, 1.4228972751479425], ['float', 1, 1.7690537162901543], ['float', 1, 1.0490874008626878], ['int', 1, 2]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.10574358-0.36048081j,  0.32302333+0.19179168j,
#               0.40878595-0.0416152j , -0.2708436 +0.30900085j,
#              -0.24923052-0.15622762j,  0.28886904-0.0554761j ,
#               0.21784208-0.2367615j ,  0.00188284+0.32172602j],
#             dims=(2, 2, 2))
# Circuito = 3 x 6:
#     Depth 0:
#         [z] -> [0]   -----------  [['int', 1, 0]]
#         [sxdg] -> [1]   -----------  [['int', 1, 1]]
#         [ry] -> [2]   -----------  [['float', 1, 0.47722458436945203], ['int', 1, 2]]
#     Depth 1:
#         [z] -> [1]   -----------  [['int', 1, 1]]
#         [x] -> [2]   -----------  [['int', 1, 2]]
#         [y] -> [0]   -----------  [['int', 1, 0]]
#     Depth 2:
#         [rz] -> [2]   -----------  [['float', 1, 1.5772715592486644], ['int', 1, 2]]
#         [rz] -> [0]   -----------  [['float', 1, 0.5113060325282055], ['int', 1, 0]]
#         [r] -> [1]   -----------  [['float', 1, 1.0475685993870807], ['float', 1, 0.6394425041584819], ['int', 1, 1]]
#     Depth 3:
#         [x] -> [2]   -----------  [['int', 1, 2]]
#         [y] -> [1]   -----------  [['int', 1, 1]]
#         [id] -> [0]   -----------  [['int', 1, 0]]
#     Depth 4:
#         [u] -> [1]   -----------  [['float', 1, 0.5803034522234283], ['float', 1, 0.7890492626311669], ['float', 1, 0.9560856997473761], ['int', 1, 1]]
#         [r] -> [0]   -----------  [['float', 1, 0.9671637094785477], ['float', 1, 0.014838482688992016], ['int', 1, 0]]
#         [u] -> [2]   -----------  [['float', 1, 0.18549277354072968], ['float', 1, 0.8310146455521767], ['float', 1, 1.6644212522280735], ['int', 1, 2]]
#     Depth 5:
#         [z] -> [0]   -----------  [['int', 1, 0]]
#         [t] -> [2]   -----------  [['int', 1, 2]]
#         [s] -> [1]   -----------  [['int', 1, 1]]
# Construindo Circuito:
#  Profundidade:
#     [z] -> [0]   -----------  [['int', 1, 0]]
#     [sxdg] -> [1]   -----------  [['int', 1, 1]]
#     [ry] -> [2]   -----------  [['float', 1, 0.47722458436945203], ['int', 1, 2]]
#  Profundidade:
#     [z] -> [1]   -----------  [['int', 1, 1]]
#     [x] -> [2]   -----------  [['int', 1, 2]]
#     [y] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [rz] -> [2]   -----------  [['float', 1, 1.5772715592486644], ['int', 1, 2]]
#     [rz] -> [0]   -----------  [['float', 1, 0.5113060325282055], ['int', 1, 0]]
#     [r] -> [1]   -----------  [['float', 1, 1.0475685993870807], ['float', 1, 0.6394425041584819], ['int', 1, 1]]
#  Profundidade:
#     [x] -> [2]   -----------  [['int', 1, 2]]
#     [y] -> [1]   -----------  [['int', 1, 1]]
#     [id] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [u] -> [1]   -----------  [['float', 1, 0.5803034522234283], ['float', 1, 0.7890492626311669], ['float', 1, 0.9560856997473761], ['int', 1, 1]]
#     [r] -> [0]   -----------  [['float', 1, 0.9671637094785477], ['float', 1, 0.014838482688992016], ['int', 1, 0]]
#     [u] -> [2]   -----------  [['float', 1, 0.18549277354072968], ['float', 1, 0.8310146455521767], ['float', 1, 1.6644212522280735], ['int', 1, 2]]
#  Profundidade:
#     [z] -> [0]   -----------  [['int', 1, 0]]
#     [t] -> [2]   -----------  [['int', 1, 2]]
#     [s] -> [1]   -----------  [['int', 1, 1]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.14016243-0.04831351j, -0.00215428-0.00734424j,
#               0.37063934-0.32489197j, -0.01586265-0.01989503j,
#              -0.23986512-0.05688193j, -0.00351038+0.01223272j,
#              -0.80973338+0.12647118j,  0.004574  +0.04206126j],
#             dims=(2, 2, 2))
# Circuito = 3 x 3:
#     Depth 0:
#         [rx] -> [2]   -----------  [['float', 1, 0.1227931378930458], ['int', 1, 2]]
#         [ms] -> [0]   -----------  [['float', 1, 0.39520453958341784], ['list[int]', 1, [0]]]
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#     Depth 1:
#         [rv] -> [0]   -----------  [['float', 1, 1.369204875008262], ['float', 1, 1.449258105391787], ['float', 1, 0.4271052313768693], ['int', 1, 0]]
#         [h] -> [2]   -----------  [['int', 1, 2]]
#         [rz] -> [1]   -----------  [['float', 1, 0.38042711814199626], ['int', 1, 1]]
#     Depth 2:
#         [rv] -> [1]   -----------  [['float', 1, 1.130130565271634], ['float', 1, 1.1316889858286119], ['float', 1, 0.8621644915266171], ['int', 1, 1]]
#         [y] -> [2]   -----------  [['int', 1, 2]]
#         [s] -> [0]   -----------  [['int', 1, 0]]
# Construindo Circuito:
#  Profundidade:
#     [rx] -> [2]   -----------  [['float', 1, 0.1227931378930458], ['int', 1, 2]]
#     [ms] -> [0]   -----------  [['float', 1, 0.39520453958341784], ['list[int]', 1, [0]]]
#     [sdg] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [rv] -> [0]   -----------  [['float', 1, 1.369204875008262], ['float', 1, 1.449258105391787], ['float', 1, 0.4271052313768693], ['int', 1, 0]]
#     [h] -> [2]   -----------  [['int', 1, 2]]
#     [rz] -> [1]   -----------  [['float', 1, 0.38042711814199626], ['int', 1, 1]]
#  Profundidade:
#     [rv] -> [1]   -----------  [['float', 1, 1.130130565271634], ['float', 1, 1.1316889858286119], ['float', 1, 0.8621644915266171], ['int', 1, 1]]
#     [y] -> [2]   -----------  [['int', 1, 2]]
#     [s] -> [0]   -----------  [['int', 1, 0]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.18763992-0.65722811j,  0.02136971-0.03496971j,
#               0.16438103+0.06348358j,  0.00387593+0.00982925j,
#               0.4211449 +0.53832565j, -0.00664124+0.04044056j,
#              -0.17618765+0.00303328j, -0.00728953-0.00764851j],
#             dims=(2, 2, 2))
# Circuito = 3 x 10:
#     Depth 0:
#         [ry] -> [1]   -----------  [['float', 1, 1.2217302774326635], ['int', 1, 1]]
#         [y] -> [2]   -----------  [['int', 1, 2]]
#         [p] -> [0]   -----------  [['float', 1, 0.18278772516514974], ['int', 1, 0]]
#     Depth 1:
#         [s] -> [1]   -----------  [['int', 1, 1]]
#         [y] -> [0]   -----------  [['int', 1, 0]]
#         [rx] -> [2]   -----------  [['float', 1, 1.846955096441618], ['int', 1, 2]]
#     Depth 2:
#         [p] -> [1]   -----------  [['float', 1, 1.7463237917537826], ['int', 1, 1]]
#         [u] -> [2]   -----------  [['float', 1, 1.4761477676597177], ['float', 1, 0.5159810685369703], ['float', 1, 0.28024076764190387], ['int', 1, 2]]
#         [rv] -> [0]   -----------  [['float', 1, 0.7102571817569532], ['float', 1, 1.0576481046197865], ['float', 1, 1.5385497457592692], ['int', 1, 0]]
#     Depth 3:
#         [rv] -> [0]   -----------  [['float', 1, 0.7012358479685525], ['float', 1, 1.331963090632128], ['float', 1, 0.6512019910858515], ['int', 1, 0]]
#         [s] -> [2]   -----------  [['int', 1, 2]]
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#     Depth 4:
#         [id] -> [1]   -----------  [['int', 1, 1]]
#         [sx] -> [2]   -----------  [['int', 1, 2]]
#         [u] -> [0]   -----------  [['float', 1, 1.9487723293988033], ['float', 1, 1.6260057087628943], ['float', 1, 1.5159743838258108], ['int', 1, 0]]
#     Depth 5:
#         [r] -> [1]   -----------  [['float', 1, 1.3786835442401089], ['float', 1, 0.6496090369994065], ['int', 1, 1]]
#         [y] -> [2]   -----------  [['int', 1, 2]]
#         [ms] -> [0]   -----------  [['float', 1, 1.22004882357808], ['list[int]', 1, [0]]]
#     Depth 6:
#         [sxdg] -> [0]   -----------  [['int', 1, 0]]
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#         [sx] -> [2]   -----------  [['int', 1, 2]]
#     Depth 7:
#         [rz] -> [1]   -----------  [['float', 1, 1.2466237479626348], ['int', 1, 1]]
#         [rv] -> [0]   -----------  [['float', 1, 1.9235469406286712], ['float', 1, 0.7952767969859622], ['float', 1, 1.8656787769449787], ['int', 1, 0]]
#         [sxdg] -> [2]   -----------  [['int', 1, 2]]
#     Depth 8:
#         [h] -> [2]   -----------  [['int', 1, 2]]
#         [y] -> [1]   -----------  [['int', 1, 1]]
#         [t] -> [0]   -----------  [['int', 1, 0]]
#     Depth 9:
#         [x] -> [0]   -----------  [['int', 1, 0]]
#         [rz] -> [1]   -----------  [['float', 1, 0.5287280772561913], ['int', 1, 1]]
#         [rz] -> [2]   -----------  [['float', 1, 0.15100243577059347], ['int', 1, 2]]
# Construindo Circuito:
#  Profundidade:
#     [ry] -> [1]   -----------  [['float', 1, 1.2217302774326635], ['int', 1, 1]]
#     [y] -> [2]   -----------  [['int', 1, 2]]
#     [p] -> [0]   -----------  [['float', 1, 0.18278772516514974], ['int', 1, 0]]
#  Profundidade:
#     [s] -> [1]   -----------  [['int', 1, 1]]
#     [y] -> [0]   -----------  [['int', 1, 0]]
#     [rx] -> [2]   -----------  [['float', 1, 1.846955096441618], ['int', 1, 2]]
#  Profundidade:
#     [p] -> [1]   -----------  [['float', 1, 1.7463237917537826], ['int', 1, 1]]
#     [u] -> [2]   -----------  [['float', 1, 1.4761477676597177], ['float', 1, 0.5159810685369703], ['float', 1, 0.28024076764190387], ['int', 1, 2]]
#     [rv] -> [0]   -----------  [['float', 1, 0.7102571817569532], ['float', 1, 1.0576481046197865], ['float', 1, 1.5385497457592692], ['int', 1, 0]]
#  Profundidade:
#     [rv] -> [0]   -----------  [['float', 1, 0.7012358479685525], ['float', 1, 1.331963090632128], ['float', 1, 0.6512019910858515], ['int', 1, 0]]
#     [s] -> [2]   -----------  [['int', 1, 2]]
#     [sdg] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
# ...
#     [x] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [rz] -> [1]   -----------  [['float', 1, 1.521718112099552], ['int', 1, 1]]
#     [u] -> [0]   -----------  [['float', 1, 0.5893861504146916], ['float', 1, 0.23208002265833905], ['float', 1, 0.7917049501677624], ['int', 1, 0]]
#     [h] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [sxdg] -> [0]   -----------  [['int', 1, 0]]
#     [s] -> [2]   -----------  [['int', 1, 2]]
#     [rz] -> [1]   -----------  [['float', 1, 1.796067982652266], ['int', 1, 1]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.30155876-0.08201732j, -0.52398792+0.01080024j,
#              -0.23229242-0.20905684j,  0.29291552+0.43460383j,
#               0.01580212-0.18230149j, -0.09985003+0.29017566j,
#              -0.16179891+0.08546725j,  0.29800346-0.07325215j],
#             dims=(2, 2, 2))
# Circuito = 3 x 2:
#     Depth 0:
#         [t] -> [1]   -----------  [['int', 1, 1]]
#         [id] -> [0]   -----------  [['int', 1, 0]]
#         [ry] -> [2]   -----------  [['float', 1, 0.6850897472621884], ['int', 1, 2]]
#     Depth 1:
#         [sx] -> [1]   -----------  [['int', 1, 1]]
#         [tdg] -> [0]   -----------  [['int', 1, 0]]
#         [sx] -> [2]   -----------  [['int', 1, 2]]
# Construindo Circuito:
#  Profundidade:
#     [t] -> [1]   -----------  [['int', 1, 1]]
#     [id] -> [0]   -----------  [['int', 1, 0]]
#     [ry] -> [2]   -----------  [['float', 1, 0.6850897472621884], ['int', 1, 2]]
#  Profundidade:
#     [sx] -> [1]   -----------  [['int', 1, 1]]
#     [tdg] -> [0]   -----------  [['int', 1, 0]]
#     [sx] -> [2]   -----------  [['int', 1, 2]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([0.44006512+0.23736616j, 0.        +0.j        ,
#              0.23736616-0.44006512j, 0.        +0.j        ,
#              0.23736616+0.44006512j, 0.        +0.j        ,
#              0.44006512-0.23736616j, 0.        +0.j        ],
#             dims=(2, 2, 2))
# Circuito = 3 x 8:
#     Depth 0:
#         [r] -> [0]   -----------  [['float', 1, 0.07749925689971238], ['float', 1, 0.7997019249918542], ['int', 1, 0]]
#         [p] -> [2]   -----------  [['float', 1, 1.3635679084969574], ['int', 1, 2]]
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#     Depth 1:
#         [h] -> [1]   -----------  [['int', 1, 1]]
#         [sxdg] -> [2]   -----------  [['int', 1, 2]]
#         [p] -> [0]   -----------  [['float', 1, 1.5060540101665632], ['int', 1, 0]]
#     Depth 2:
#         [x] -> [1]   -----------  [['int', 1, 1]]
#         [rx] -> [2]   -----------  [['float', 1, 1.5921560183321737], ['int', 1, 2]]
#         [h] -> [0]   -----------  [['int', 1, 0]]
#     Depth 3:
#         [ry] -> [1]   -----------  [['float', 1, 1.7374476255421198], ['int', 1, 1]]
#         [sxdg] -> [2]   -----------  [['int', 1, 2]]
#         [u] -> [0]   -----------  [['float', 1, 0.9837428238939512], ['float', 1, 0.06487626063920904], ['float', 1, 0.6283329968121616], ['int', 1, 0]]
#     Depth 4:
#         [r] -> [0]   -----------  [['float', 1, 0.8725065542212085], ['float', 1, 1.9830347289796446], ['int', 1, 0]]
#         [sdg] -> [2]   -----------  [['int', 1, 2]]
#         [sx] -> [1]   -----------  [['int', 1, 1]]
#     Depth 5:
#         [rx] -> [0]   -----------  [['float', 1, 1.115289618294071], ['int', 1, 0]]
#         [sxdg] -> [1]   -----------  [['int', 1, 1]]
#         [s] -> [2]   -----------  [['int', 1, 2]]
#     Depth 6:
#         [sxdg] -> [0]   -----------  [['int', 1, 0]]
#         [rx] -> [1]   -----------  [['float', 1, 0.5475831585148856], ['int', 1, 1]]
#         [h] -> [2]   -----------  [['int', 1, 2]]
#     Depth 7:
#         [tdg] -> [0]   -----------  [['int', 1, 0]]
#         [s] -> [2]   -----------  [['int', 1, 2]]
#         [t] -> [1]   -----------  [['int', 1, 1]]
# Construindo Circuito:
#  Profundidade:
#     [r] -> [0]   -----------  [['float', 1, 0.07749925689971238], ['float', 1, 0.7997019249918542], ['int', 1, 0]]
#     [p] -> [2]   -----------  [['float', 1, 1.3635679084969574], ['int', 1, 2]]
#     [sdg] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [h] -> [1]   -----------  [['int', 1, 1]]
#     [sxdg] -> [2]   -----------  [['int', 1, 2]]
#     [p] -> [0]   -----------  [['float', 1, 1.5060540101665632], ['int', 1, 0]]
#  Profundidade:
#     [x] -> [1]   -----------  [['int', 1, 1]]
#     [rx] -> [2]   -----------  [['float', 1, 1.5921560183321737], ['int', 1, 2]]
#     [h] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [ry] -> [1]   -----------  [['float', 1, 1.7374476255421198], ['int', 1, 1]]
#     [sxdg] -> [2]   -----------  [['int', 1, 2]]
#     [u] -> [0]   -----------  [['float', 1, 0.9837428238939512], ['float', 1, 0.06487626063920904], ['float', 1, 0.6283329968121616], ['int', 1, 0]]
#  Profundidade:
#     [r] -> [0]   -----------  [['float', 1, 0.8725065542212085], ['float', 1, 1.9830347289796446], ['int', 1, 0]]
#     [sdg] -> [2]   -----------  [['int', 1, 2]]
#     [sx] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [rx] -> [0]   -----------  [['float', 1, 1.115289618294071], ['int', 1, 0]]
#     [sxdg] -> [1]   -----------  [['int', 1, 1]]
#     [s] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [sxdg] -> [0]   -----------  [['int', 1, 0]]
#     [rx] -> [1]   -----------  [['float', 1, 0.5475831585148856], ['int', 1, 1]]
#     [h] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [tdg] -> [0]   -----------  [['int', 1, 0]]
#     [s] -> [2]   -----------  [['int', 1, 2]]
#     [t] -> [1]   -----------  [['int', 1, 1]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.06803023-0.03334915j, -0.2429248 +0.39736922j,
#              -0.07714281-0.03462985j, -0.2559615 +0.45241401j,
#               0.05567813+0.05138311j,  0.34625931-0.31147913j,
#               0.06404584+0.05521206j,  0.37446813-0.36051123j],
#             dims=(2, 2, 2))
# Circuito = 3 x 0:
# Construindo Circuito:
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# Circuito = 3 x 9:
#     Depth 0:
#         [sxdg] -> [0]   -----------  [['int', 1, 0]]
#         [rz] -> [2]   -----------  [['float', 1, 0.28042911741444154], ['int', 1, 2]]
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
#     Depth 1:
#         [ry] -> [0]   -----------  [['float', 1, 1.2837577511284404], ['int', 1, 0]]
#         [p] -> [1]   -----------  [['float', 1, 1.9084026496527176], ['int', 1, 1]]
#         [sxdg] -> [2]   -----------  [['int', 1, 2]]
#     Depth 2:
#         [id] -> [2]   -----------  [['int', 1, 2]]
#         [p] -> [0]   -----------  [['float', 1, 0.4639909485674407], ['int', 1, 0]]
#         [y] -> [1]   -----------  [['int', 1, 1]]
#     Depth 3:
#         [p] -> [2]   -----------  [['float', 1, 1.8500921977847078], ['int', 1, 2]]
#         [id] -> [1]   -----------  [['int', 1, 1]]
#         [ms] -> [0]   -----------  [['float', 1, 0.7020044002440449], ['list[int]', 1, [0]]]
#     Depth 4:
#         [x] -> [2]   -----------  [['int', 1, 2]]
#         [sxdg] -> [1]   -----------  [['int', 1, 1]]
#         [z] -> [0]   -----------  [['int', 1, 0]]
#     Depth 5:
#         [t] -> [0]   -----------  [['int', 1, 0]]
#         [z] -> [1]   -----------  [['int', 1, 1]]
#         [ms] -> [2]   -----------  [['float', 1, 0.22687248362096368], ['list[int]', 1, [2]]]
#     Depth 6:
#         [t] -> [1]   -----------  [['int', 1, 1]]
#         [t] -> [0]   -----------  [['int', 1, 0]]
#         [sx] -> [2]   -----------  [['int', 1, 2]]
#     Depth 7:
#         [rx] -> [1]   -----------  [['float', 1, 1.0889212280616054], ['int', 1, 1]]
#         [y] -> [2]   -----------  [['int', 1, 2]]
#         [id] -> [0]   -----------  [['int', 1, 0]]
#     Depth 8:
#         [sx] -> [0]   -----------  [['int', 1, 0]]
#         [rx] -> [2]   -----------  [['float', 1, 1.0975422095853322], ['int', 1, 2]]
#         [r] -> [1]   -----------  [['float', 1, 1.297956053039391], ['float', 1, 0.4083973650447994], ['int', 1, 1]]
# Construindo Circuito:
#  Profundidade:
#     [sxdg] -> [0]   -----------  [['int', 1, 0]]
#     [rz] -> [2]   -----------  [['float', 1, 0.28042911741444154], ['int', 1, 2]]
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [ry] -> [0]   -----------  [['float', 1, 1.2837577511284404], ['int', 1, 0]]
#     [p] -> [1]   -----------  [['float', 1, 1.9084026496527176], ['int', 1, 1]]
#     [sxdg] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [id] -> [2]   -----------  [['int', 1, 2]]
#     [p] -> [0]   -----------  [['float', 1, 0.4639909485674407], ['int', 1, 0]]
#     [y] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [p] -> [2]   -----------  [['float', 1, 1.8500921977847078], ['int', 1, 2]]
#     [id] -> [1]   -----------  [['int', 1, 1]]
#     [ms] -> [0]   -----------  [['float', 1, 0.7020044002440449], ['list[int]', 1, [0]]]
#  Profundidade:
#     [x] -> [2]   -----------  [['int', 1, 2]]
#     [sxdg] -> [1]   -----------  [['int', 1, 1]]
#     [z] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [t] -> [0]   -----------  [['int', 1, 0]]
#     [z] -> [1]   -----------  [['int', 1, 1]]
#     [ms] -> [2]   -----------  [['float', 1, 0.22687248362096368], ['list[int]', 1, [2]]]
#  Profundidade:
#     [t] -> [1]   -----------  [['int', 1, 1]]
#     [t] -> [0]   -----------  [['int', 1, 0]]
#     [sx] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [rx] -> [1]   -----------  [['float', 1, 1.0889212280616054], ['int', 1, 1]]
#     [y] -> [2]   -----------  [['int', 1, 2]]
#     [id] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [sx] -> [0]   -----------  [['int', 1, 0]]
#     [rx] -> [2]   -----------  [['float', 1, 1.0975422095853322], ['int', 1, 2]]
#     [r] -> [1]   -----------  [['float', 1, 1.297956053039391], ['float', 1, 0.4083973650447994], ['int', 1, 1]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.13715603+0.09141281j, -0.00776623+0.00517609j,
#               0.08408452+0.20176626j,  0.00476114+0.01142467j,
#               0.25042575-0.52101169j,  0.01417993-0.02950139j,
#              -0.61440223-0.45847552j, -0.03478947-0.02596039j],
#             dims=(2, 2, 2))
# Circuito = 3 x 0:
# Construindo Circuito:
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# Circuito = 3 x 1:
#     Depth 0:
#         [x] -> [2]   -----------  [['int', 1, 2]]
#         [ms] -> [0, 1]   -----------  [['float', 1, 1.6246534146309344], ['list[int]', 2, [1, 0]]]
# Construindo Circuito:
#  Profundidade:
#     [x] -> [2]   -----------  [['int', 1, 2]]
#     [ms] -> [0, 1]   -----------  [['float', 1, 1.6246534146309344], ['list[int]', 2, [1, 0]]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ,
#              -0.83116703+0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        -0.55602282j],
#             dims=(2, 2, 2))
# Circuito = 3 x 3:
#     Depth 0:
#         [id] -> [1]   -----------  [['int', 1, 1]]
#         [id] -> [2]   -----------  [['int', 1, 2]]
#         [id] -> [0]   -----------  [['int', 1, 0]]
#     Depth 1:
#         [p] -> [1]   -----------  [['float', 1, 0.7551480046341126], ['int', 1, 1]]
#         [sxdg] -> [0]   -----------  [['int', 1, 0]]
#         [t] -> [2]   -----------  [['int', 1, 2]]
#     Depth 2:
#         [ms] -> [1, 0, 2]   -----------  [['float', 1, 1.976115967102341], ['list[int]', 3, [1, 2, 0]]]
# Construindo Circuito:
#  Profundidade:
#     [id] -> [1]   -----------  [['int', 1, 1]]
#     [id] -> [2]   -----------  [['int', 1, 2]]
#     [id] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [p] -> [1]   -----------  [['float', 1, 0.7551480046341126], ['int', 1, 1]]
#     [sxdg] -> [0]   -----------  [['int', 1, 0]]
#     [t] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [ms] -> [1, 0, 2]   -----------  [['float', 1, 1.976115967102341], ['list[int]', 3, [1, 2, 0]]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.49891884+0.49897161j, -0.49897161-0.49891884j,
#               0.01943063-0.01802476j, -0.01802476-0.01943063j,
#               0.01943063-0.01802476j, -0.01802476-0.01943063j,
#              -0.01802476-0.01943063j,  0.01943063-0.01802476j],
#             dims=(2, 2, 2))
# Circuito = 3 x 3:
#     Depth 0:
#         [z] -> [0]   -----------  [['int', 1, 0]]
#         [u] -> [2]   -----------  [['float', 1, 1.4872275665397396], ['float', 1, 1.373094886068225], ['float', 1, 0.6842131025033504], ['int', 1, 2]]
#         [sx] -> [1]   -----------  [['int', 1, 1]]
#     Depth 1:
#         [id] -> [0]   -----------  [['int', 1, 0]]
#         [sxdg] -> [1]   -----------  [['int', 1, 1]]
#         [s] -> [2]   -----------  [['int', 1, 2]]
#     Depth 2:
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
#         [sxdg] -> [2]   -----------  [['int', 1, 2]]
#         [id] -> [0]   -----------  [['int', 1, 0]]
# Construindo Circuito:
#  Profundidade:
#     [z] -> [0]   -----------  [['int', 1, 0]]
#     [u] -> [2]   -----------  [['float', 1, 1.4872275665397396], ['float', 1, 1.373094886068225], ['float', 1, 0.6842131025033504], ['int', 1, 2]]
#     [sx] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [id] -> [0]   -----------  [['int', 1, 0]]
#     [sxdg] -> [1]   -----------  [['int', 1, 1]]
#     [s] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
#     [sxdg] -> [2]   -----------  [['int', 1, 2]]
#     [id] -> [0]   -----------  [['int', 1, 0]]
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.12588411+0.53870809j,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ,
#              -0.15407073-0.81866293j,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ],
#             dims=(2, 2, 2))

# %%
generations(population, 1, svTarget)
# Out:
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.28700931-0.35281058j,  0.08932452+0.07268121j,
#               0.28700931-0.35281058j,  0.08932452+0.07268121j,
#              -0.49557636+0.13202282j, -0.03341476-0.12548476j,
#              -0.49557636+0.13202282j, -0.03341476-0.12548476j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.108845  -0.20412905j,  0.3007105 +0.19947685j,
#               0.09499361+0.39721196j, -0.42483329-0.47474867j,
#               0.05225792+0.12043084j, -0.16099946-0.12655056j,
#              -0.03561606-0.22901703j,  0.21865439+0.28792037j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.29270316+0.00292331j,  0.00989877-0.12351317j,
#              -0.08406806+0.12333367j,  0.04959157+0.03915022j,
#               0.45368141+0.61768325j,  0.27425848-0.17329184j,
#              -0.3903943 +0.01765611j, -0.00410047+0.16537437j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.00200057+0.02103376j, -0.00818565+0.03109898j,
#               0.24872096+0.22736647j,  0.31756425+0.40275711j,
#              -0.000768  -0.02708671j,  0.0055183 -0.04087217j,
#              -0.35239483-0.25019785j, -0.46765398-0.46258498j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.26924807-0.06884801j, -0.02805986+0.06267196j,
#              -0.07432144-0.15081601j,  0.04060031+0.00879953j,
#              -0.39911787+0.673354j  , -0.06893365-0.18070198j,
#               0.448385  +0.152347j  , -0.09838498+0.06333461j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.31767262-0.37567927j, -0.01536724+0.08782391j,
#              -0.31767262-0.37567927j, -0.01536724+0.08782391j,
#              -0.37567927-0.31767262j, -0.00056086+0.08915647j,
#              -0.37567927-0.31767262j, -0.00056086+0.08915647j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.30155876-0.08201732j, -0.52398792+0.01080024j,
#              -0.23229242-0.20905684j,  0.29291552+0.43460383j,
#               0.01580212-0.18230149j, -0.09985003+0.29017566j,
#              -0.16179891+0.08546725j,  0.29800346-0.07325215j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.1791989 +0.19063659j,  0.29889436-0.30308229j,
#               0.10637067+0.6007268j ,  0.08452621-0.18757551j,
#               0.14135557+0.37357316j,  0.17352225+0.28129899j,
#              -0.02927694+0.02239553j, -0.25631133+0.00069682j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.17767894-0.01182355j,  0.03868829+0.26558243j,
#              -0.01907217+0.51864369j, -0.78154333+0.03241571j,
#              -0.01124324+0.01891847j, -0.02975025-0.01466598j,
#              -0.05146909-0.03827464j,  0.05144951-0.08184284j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ,
#              -0.46677162+0.53375573j,  0.02878028+0.70455714j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([0.99296875+0.j        , 0.        +0.j        ,
#              0.        +0.j        , 0.        +0.j        ,
#              0.00613118+0.11821791j, 0.        +0.j        ,
#              0.        +0.j        , 0.        +0.j        ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.09938099-0.00689233j,  0.00689233-0.09938099j,
#               0.08515237+0.21655393j, -0.21655393+0.08515237j,
#               0.24160455-0.09565365j,  0.09565365+0.24160455j,
#              -0.44413672-0.41370228j,  0.41370228-0.44413672j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.00271375-0.00831014j,  0.00831014-0.00271375j,
#               0.0106888 +0.00085872j, -0.00085872+0.0106888j ,
#               0.01208986-0.44655129j,  0.44655129+0.01208986j,
#               0.49968711+0.22487145j, -0.22487145+0.49968711j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.12588411+0.53870809j,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ,
#              -0.15407073-0.81866293j,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.01610966+0.16113168j, -0.32840502+0.07048278j,
#              -0.29558331+0.1344665j , -0.34554981-0.57816165j,
#               0.10578113+0.01212904j, -0.0005291 +0.22084681j,
#               0.04516211+0.20868417j, -0.41970124+0.14136798j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.04917485+0.18906141j, -0.05887424+0.10705232j,
#               0.11149871+0.08155592j, -0.14587346-0.02841872j,
#               0.43246918-0.30331628j,  0.14961851-0.3069046j ,
#               0.05703409+0.51749014j, -0.45851171-0.16986115j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ,
#              -0.46677162+0.53375573j,  0.02878028+0.70455714j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.02580784+0.j        , -0.02580784+0.j        ,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        -0.70663566j,  0.        -0.70663566j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.02068225+0.2118826j ,  0.23715435-0.23561368j,
#              -0.03422254+0.35059826j,  0.39241497-0.38986565j,
#               0.09562811-0.15074042j, -0.26660368+0.08661327j,
#               0.15823409-0.24942741j, -0.44114423+0.1433174j ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.05992102-0.11142947j, -0.0589881 -0.16183628j,
#               0.1062899 -0.09347455j,  0.16146044-0.10520141j,
#               0.29141074+0.23389843j,  0.34699363+0.37203532j,
#              -0.18123583+0.3767202j , -0.31772893+0.47221897j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([0.32954599+0.j        , 0.        +0.15970041j,
#              0.        +0.j        , 0.        +0.j        ,
#              0.40410326-0.7334294j , 0.35542529+0.19583142j,
#              0.        +0.j        , 0.        +0.j        ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.72401   -0.14976386j,  0.26040389+0.06500868j,
#               0.30463337+0.40494949j, -0.10452036-0.15138032j,
#              -0.20689177-0.1083113j ,  0.07344557+0.04234051j,
#               0.05737966+0.14942135j, -0.01860748-0.0550453j ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.00000000e+00-6.93889390e-18j,
#              -3.46944695e-18-1.73472348e-18j,
#               2.83606992e-01+1.03389316e-01j,
#              -5.56685674e-02-2.02940522e-02j,
#               0.00000000e+00+0.00000000e+00j,
#              -1.38777878e-17+0.00000000e+00j,
#               8.07314674e-04+9.33690316e-01j,
#              -1.58465950e-04-1.83271935e-01j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.47439116+0.09325865j, -0.09116924+0.16708091j,
#              -0.1298233 +0.42697328j,  0.09657847+0.14676623j,
#              -0.45282959-0.16937979j, -0.16524866+0.09444966j,
#              -0.33445626+0.29546451j,  0.00526337+0.17561327j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.02770248+0.4287471j ,  0.43414281+0.02735818j,
#              -0.24909517+0.01609469j, -0.01589466+0.25222998j,
#               0.32275859+0.28358138j,  0.32633048-0.28764017j,
#              -0.16475622+0.18751755j,  0.16711431+0.18959275j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.04962692+0.34973684j,  0.10046544-0.1598874j ,
#              -0.13418798-0.00849487j,  0.06364508+0.03339931j,
#              -0.56097365-0.48974845j,  0.16704533+0.36133776j,
#               0.16927185-0.22735955j, -0.13218572+0.07407263j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([0.44006512+0.23736616j, 0.        +0.j        ,
#              0.23736616-0.44006512j, 0.        +0.j        ,
#              0.23736616+0.44006512j, 0.        +0.j        ,
#              0.44006512-0.23736616j, 0.        +0.j        ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.02158199-0.02158199j, -0.03891135+0.03891135j,
#               0.11552033-0.3214851j , -0.20827793+0.5796231j ,
#               0.02158199+0.02158199j, -0.03891135-0.03891135j,
#               0.3214851 +0.11552033j, -0.5796231 -0.20827793j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.04591295-0.27315718j,  0.4159143 -0.29621741j,
#               0.19030671+0.02720389j,  0.21260778+0.28352942j,
#               0.12706962+0.24612224j, -0.15518748+0.48646306j,
#              -0.16860312+0.09235629j, -0.3401658 -0.09938927j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.09395134+0.1103681j , -0.06241002-0.00880441j,
#               0.04469496-0.16990618j,  0.07280611-0.02314884j,
#              -0.41635232-0.38239144j,  0.04348571-0.24194824j,
#               0.6556388 +0.19916423j,  0.07952391+0.28716207j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.00000000e+00-6.93889390e-18j,
#              -3.46944695e-18-1.73472348e-18j,
#               2.83606992e-01+1.03389316e-01j,
#              -5.56685674e-02-2.02940522e-02j,
#               0.00000000e+00+0.00000000e+00j,
#              -1.38777878e-17+0.00000000e+00j,
#               8.07314674e-04+9.33690316e-01j,
#              -1.58465950e-04-1.83271935e-01j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([0.32954599+0.j        , 0.        +0.15970041j,
#              0.        +0.j        , 0.        +0.j        ,
#              0.40410326-0.7334294j , 0.35542529+0.19583142j,
#              0.        +0.j        , 0.        +0.j        ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.79288853+0.j        , -0.26936835+0.54659718j,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.22911318+0.12267986j, -0.17210624-0.0675102j ,
#              -0.25292662-0.29379918j,  0.20323384+0.18640176j,
#               0.27801196-0.24708775j, -0.17573745+0.19778935j,
#              -0.51961287+0.19449522j,  0.35080611-0.18083428j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.14829279-0.00566874j, -0.33050262-0.2513825j ,
#               0.042335  +0.13631296j,  0.15085812-0.36980148j,
#               0.18845015+0.03600032j, -0.34319474-0.41281005j,
#               0.01367248+0.18402632j,  0.29761456-0.421943j  ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.76449397+0.33491238j,  0.07874767-0.28254871j,
#               0.29331171-0.15922468j, -0.02184773+0.11523484j,
#              -0.09934606+0.24675435j, -0.04509068-0.08188797j,
#               0.03126211-0.10166754j,  0.02072758+0.03110695j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.1215138 +0.19109449j,  0.16977138+0.04954129j,
#               0.1162134 -0.49577467j, -0.39712955+0.02075252j,
#              -0.14314662+0.17547579j,  0.16276599+0.0691657j ,
#               0.17371908-0.47866456j, -0.3968139 -0.02610136j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.13715603+0.09141281j, -0.00776623+0.00517609j,
#               0.08408452+0.20176626j,  0.00476114+0.01142467j,
#               0.25042575-0.52101169j,  0.01417993-0.02950139j,
#              -0.61440223-0.45847552j, -0.03478947-0.02596039j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([ 0.10052436+0.11448701j,  0.22877999-0.34489257j,
#              -0.12326389+0.11450114j,  0.38777358+0.24186508j,
#              -0.17451947+0.01016997j,  0.1506264 +0.45036233j,
#              -0.01662299-0.19232305j, -0.49245935+0.18019195j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.39794619+0.01313888j, 0.21272961+0.40462306j,
#              0.02440914+0.13279592j, 0.39398401+0.2758833j ,
#              0.09435749+0.38093329j, 0.16916758+0.28897447j,
#              0.12723151+0.1772633j , 0.18779281+0.18415547j],
#             dims=(2, 2, 2))
# Statevector([-0.72401   -0.14976386j,  0.26040389+0.06500868j,
#               0.30463337+0.40494949j, -0.10452036-0.15138032j,
#              -0.20689177-0.1083113j ,  0.07344557+0.04234051j,
#               0.05737966+0.14942135j, -0.01860748-0.0550453j ],
#             dims=(2, 2, 2))
# ([<__main__.Circuit at 0x269257c6540>,
#   <__main__.Circuit at 0x26925061220>,
#   <__main__.Circuit at 0x26925899880>,
#   <__main__.Circuit at 0x2692586ef60>,
#   <__main__.Circuit at 0x2692587e990>,
#   <__main__.Circuit at 0x26925812fc0>,
#   <__main__.Circuit at 0x26925181640>,
#   <__main__.Circuit at 0x26925a30b60>,
#   <__main__.Circuit at 0x269250843e0>,
#   <__main__.Circuit at 0x26925a782c0>,
#   <__main__.Circuit at 0x26925792990>,
#   <__main__.Circuit at 0x269250e0140>,
#   <__main__.Circuit at 0x269251814c0>,
#   <__main__.Circuit at 0x2692587f650>,
#   <__main__.Circuit at 0x2690bc8c200>,
#   <__main__.Circuit at 0x2692583d8b0>,
#   <__main__.Circuit at 0x26925a49520>,
#   <__main__.Circuit at 0x269258d77d0>,
#   <__main__.Circuit at 0x269258b61e0>,
#   <__main__.Circuit at 0x269257c7590>,
#   <__main__.Circuit at 0x26925a4b5c0>,
#   <__main__.Circuit at 0x2692583c7d0>,
#   <__main__.Circuit at 0x2692508b3e0>,
#   <__main__.Circuit at 0x269251722a0>,
#   <__main__.Circuit at 0x26925811460>,
#   <__main__.Circuit at 0x269250d9910>,
#   <__main__.Circuit at 0x2692587c2f0>,
#   <__main__.Circuit at 0x2692583d100>,
#   <__main__.Circuit at 0x269258b7950>,
#   <__main__.Circuit at 0x269257e70b0>,
#   <__main__.Circuit at 0x269250da0f0>,
#   <__main__.Circuit at 0x26925172510>,
#   <__main__.Circuit at 0x2692587e180>,
#   <__main__.Circuit at 0x2692583d2b0>,
#   <__main__.Circuit at 0x2692586caa0>,
#   <__main__.Circuit at 0x26925a49730>,
#   <__main__.Circuit at 0x2692586cce0>,
#   <__main__.Circuit at 0x2692586e450>,
#   <__main__.Circuit at 0x2692587d400>,
#   <__main__.Circuit at 0x269257ad730>,
#   <__main__.Circuit at 0x26925827830>,
#   <__main__.Circuit at 0x269250dbd10>,
#   <__main__.Circuit at 0x26925060fe0>,
#   <__main__.Circuit at 0x2690bec1310>,
#   <__main__.Circuit at 0x26925171fa0>,
#   <__main__.Circuit at 0x2692516b620>,
#   <__main__.Circuit at 0x2692583cc50>,
#   <__main__.Circuit at 0x26925a67230>,
#   <__main__.Circuit at 0x269258d7680>,
#   <__main__.Circuit at 0x26925186360>],
#  50)

# %%
population[0].circuit.draw()
# Out:
#                 ┌───┐                  ░       ┌──────┐┌──────────────────┐»
# q_0: ───────────┤ I ├──────────────────░───────┤ √Xdg ├┤ R(2.4462,3.3243) ├»
#      ┌──────────┴───┴──────────┐ ┌────────────┐└┬───┬─┘└──┬───────────┬───┘»
# q_1: ┤ Rv(3.3964,5.2551,3.536) ├─┤ Ms(3.0725) ├─┤ I ├─────┤ P(6.2267) ├────»
#      └──────┬────────────┬─────┘ └───┬───┬────┘ ├───┤     ├───────────┴┐   »
# q_2: ───────┤ Rz(1.3899) ├───────────┤ X ├──────┤ T ├─────┤ Rz(5.7315) ├───»
#             └───┬───┬────┘      ┌────┴───┴────┐ ├───┤     └─────░──────┘   »
# q_3: ───────────┤ I ├───────────┤ Ry(0.53219) ├─┤ X ├───────────░──────────»
#                ┌┴───┴┐          ├─────────────┤ ├───┤         ┌───┐        »
# q_4: ──────────┤ Sdg ├──────────┤ Rx(0.99704) ├─┤ S ├─────────┤ H ├────────»
#                └─────┘          └─────────────┘ └───┘         └───┘        »
# «            ░              ┌────┐                ┌─────┐          »
# «q_0: ───────░──────────────┤ √X ├────────────────┤ Tdg ├──────────»
# «     ┌─────────────┐       ├────┤      ┌─────────┴─────┴─────────┐»
# «q_1: ┤0            ├───────┤ √X ├──────┤ U(3.5932,1.1203,1.2837) ├»
# «     │             │┌──────┴────┴─────┐└──────┬────────────┬─────┘»
# «q_2: ┤  Ms(3.6967) ├┤ R(5.362,3.0458) ├───────┤ Rx(2.6124) ├──────»
# «     │             │└──────┬───┬──────┘       └─────░──────┘      »
# «q_3: ┤1            ├───────┤ S ├────────────────────░─────────────»
# «     └────┬───┬────┘       └─░─┘              ┌────────────┐      »
# «q_4: ─────┤ T ├──────────────░────────────────┤ P(0.82383) ├──────»
# «          └───┘              ░                └────────────┘      »
# «     ┌───────────┐
# «q_0: ┤ P(4.2465) ├──────────────
# «     └───┬───┬───┘
# «q_1: ────┤ I ├──────────────────
# «      ┌──┴───┴───┐┌────────────┐
# «q_2: ─┤ P(1.696) ├┤ Rz(2.5476) ├
# «      └──┬───┬───┘└────────────┘
# «q_3: ────┤ T ├──────────────────
# «         ├───┤
# «q_4: ────┤ X ├──────────────────
# «         └───┘

# %%
gatesParameters
# Out:
# {'barrier': {'qargs': ['int'],
#   'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'ccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'ccz': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'ch': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cp': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'crx': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cry': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'crz': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cs': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'csdg': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cswap': {'control_qubit': ['int'],
#   'target_qubit1': ['int'],
#   'target_qubit2': ['int'],
#   'info': {'combinations': []}},
#  'csx': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cu': {'theta': ['float'],
#   'phi': ['float'],
#   'lam': ['float'],
#   'gamma': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cx': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cy': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cz': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'dcx': {'qubit1': ['int'], 'qubit2': ['int'], 'info': {'combinations': []}},
#  'ecr': {'qubit1': ['int'], 'qubit2': ['int'], 'info': {'combinations': []}},
#  'h': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'id': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'iswap': {'qubit1': ['int'], 'qubit2': ['int'], 'info': {'combinations': []}},
#  'mcp': {'lam': ['float'],
#   'control_qubits': ['list[int]'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'mcrx': {'theta': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int'],
#   'info': {'combinations': []}},
#  'mcry': {'theta': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int'],
#   'q_ancillae': ['int', 'list[int]', 'None'],
#   'info': {'combinations': []}},
#  'mcrz': {'lam': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int'],
#   'info': {'combinations': []}},
#  'mcx': {'control_qubits': ['list[int]'],
#   'target_qubit': ['int'],
#   'ancilla_qubits': ['int', 'list[int]', 'None'],
#   'info': {'combinations': []}},
#  'ms': {'theta': ['float'],
#   'qubits': ['list[int]'],
#   'info': {'combinations': [(('float', 'list[int]'), 1, 1, 0)]}},
#  'p': {'theta': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'pauli': {'pauli_string': ['str'],
#   'qubits': ['list[int]'],
#   'info': {'combinations': [(('str', 'list[int]'), 1, 0, 1)]}},
#  'r': {'theta': ['float'],
#   'phi': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'float', 'int'), 1, 2, 0)]}},
#  'rcccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'control_qubit3': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'rccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'rv': {'vx': ['float'],
#   'vy': ['float'],
#   'vz': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'float', 'float', 'int'), 1, 3, 0)]}},
#  'rx': {'theta': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'rxx': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': []}},
#  'ry': {'theta': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'ryy': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': []}},
#  'rz': {'phi': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'rzx': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': []}},
#  'rzz': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': []}},
#  's': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'sdg': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'swap': {'qubit1': ['int'], 'qubit2': ['int'], 'info': {'combinations': []}},
#  'sx': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'sxdg': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  't': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'tdg': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'u': {'theta': ['float'],
#   'phi': ['float'],
#   'lam': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'float', 'float', 'int'), 1, 3, 0)]}},
#  'x': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'y': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'z': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}}}

# %%
def criar_circuito(num_qubits, num_gates_por_qubit):
    qc = QuantumCircuit(num_qubits)
    for qubit in range(num_qubits):
        for _ in range(num_gates_por_qubit):
            qc.h(qubit)  # Aplicando a porta de Hadamard como exemplo

    #qc.measure_all()
    return qc
def simular_circuito(qc, simulador):
    qc_simulator = transpile(qc, backend=simulador)
    job = simulador.run(qc_simulator, shots=1024)
    return job

# %%
qc_1 = criar_circuito(10, 9)
qc_2 = criar_circuito(9, 7)

# %%
qc_1.draw()
# Out:
#      ┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐
# q_0: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_1: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_2: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_3: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_4: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_5: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_6: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_7: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_8: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_9: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      └───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘

# %%
qc_2.draw()
# Out:
#      ┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐
# q_0: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_1: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_2: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_3: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_4: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_5: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_6: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_7: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_8: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      └───┘└───┘└───┘└───┘└───┘└───┘└───┘

# %%
#job_1 = simular_circuito(qc_1, simulator)
sv2 = Statevector.from_label("0"*10)
sv2 = sv2.evolve(qc_2)
#job_1 = simular_circuito(qc_1, simulator)
sv1 = Statevector.from_label("0"*10)
sv1 = sv1.evolve(qc_1)

print(sv1)
print(sv2)
state_fidelity(sv1, sv2)
# Out:
# Statevector([0.03125+0.j, 0.03125+0.j, 0.03125+0.j, ..., 0.03125+0.j,
#              0.03125+0.j, 0.03125+0.j],
#             dims=(2, 2, 2, 2, 2, 2, 2, 2, 2, 2))
# Statevector([0.04419417+0.j, 0.04419417+0.j, 0.04419417+0.j, ...,
#              0.        +0.j, 0.        +0.j, 0.        +0.j],
#             dims=(2, 2, 2, 2, 2, 2, 2, 2, 2, 2))
# 0.49999999999998795

# %%
#job_2 = simular_circuito(qc_2, simulator)

# %%
result = job_1.result()

# %%
result.get_statevector()
# Out:
# Statevector([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2, 2))

# %%
result1 = job_2.result()

# %%
result1.get_statevector()
# Out:
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2, 2))

# %%
import matplotlib.pyplot as plt
import numpy as np

# Supondo que o statevector já esteja calculado e armazenado em uma lista


# Calculando as probabilidades
probabilities = np.abs(statevector)**2

# Criando os rótulos dos estados computacionais (ajuste conforme necessário)
states = ['0', '1']

# Criando o gráfico de barras
plt.bar(states, probabilities)
plt.xlabel('Computational basis states')
plt.ylabel('Amplitude')
plt.title('Probabilities')
plt.show()

# %%
statevector = result.get_statevector() # Substitua pelos seus valores
statevector2 = result1.get_statevector()
state_fidelity(statevector, statevector2)
# Out:
# 0.0
