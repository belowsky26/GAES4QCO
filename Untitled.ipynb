# %%
from qiskit import QuantumCircuit, transpile
from qiskit.quantum_info import Statevector, DensityMatrix, state_fidelity, partial_trace
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from qiskit.circuit.library import standard_gates
from qiskit_aer import Aer
import time
import numpy as np
import json
import random
import math
import inspect
import itertools

# %%
def openFile(gate):
    with open(gate, 'r') as f:
        data = dict(json.load(f))
    return data

# %%
PI = math.pi
SEED = 11
random.seed(SEED)
TARGET = []
PENALTY_QUBITS = 0.1
CROSSOVER = 80
MUTATION = 5

# %%
# Gerando um vetor aleatório complexo com norma 1
num_qubits = 3  # Número de qubits desejado
dim = 2**num_qubits
random_vector = np.random.rand(dim) + 1j * np.random.rand(dim)
random_vector /= np.linalg.norm(random_vector)

# Criando o statevector a partir do vetor aleatório
svTarget = Statevector(random_vector)
print(svTarget)
# Out:
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))

# %%
removeString = ['barrier', 'pauli', 'append', 'cast','clear', 'compose','control', 'copy', 'decompose', 'delay', 'depth', 'draw', 'initialize', 'inverse', 'measure','power', 'repeat', 'reset', 'size','store', 'switch', 'tensor', 'unitary', 'width']
# Talvez -> ctrl_state
parametersOk = ['pauli_string', 'vz', 'target_qubit1', 'vy', 'phi','vx', 'qargs', 'control_qubits', 'q_target', 'target_qubit2', 'qubits', 'theta', 'qubit2', 'q_controls', 'target_qubit','gamma', 'qubit', 'control_qubit3', 'ancilla_qubits', 'control_qubit1', 'control_qubit', 'q_ancillae', 'control_qubit2', 'qubit1', 'lam']

# %%
def get_classes(module):
    gates = [(name,cls) for name, cls in inspect.getmembers(module) if inspect.isfunction(cls) and not (name.count('add') or name.count('_'))]
    gates = [(name, cls) for name, cls in gates if not name in removeString]
    return gates

# %%
classes = get_classes(QuantumCircuit)
typesDict = {
    "QubitSpecifier": ["int"],
    "<class 'qiskit.circuit.quantumregister.Qubit'>": ["int"],
    "Sequence[QubitSpecifier] | None": ["int", "None"],
    "typing.Union[qiskit.circuit.quantumregister.QuantumRegister, typing.List[qiskit.circuit.quantumregister.Qubit]]": ["int", "list[int]"],
    "Sequence[QubitSpecifier]": ["list[int]"],
    "QubitSpecifier | Sequence[QubitSpecifier] | None": ["int", "list[int]", "None"],
    "typing.Union[qiskit.circuit.quantumregister.QuantumRegister, typing.Tuple[qiskit.circuit.quantumregister.QuantumRegister, int], NoneType]": ["int", "list[int]", "None"],
    "typing.Union[qiskit.circuit.parameterexpression.ParameterExpression, float]": ["float"],
    "ParameterValueType": ["float"],
    "str": ["str"],
}
gatesParameters = {}
# Iterando sobre os parâmetros
for name, classe in classes:
    init_signature = inspect.signature(classe)
    #print(classe)
    gatesParameters[name] = dict()
    for parameter_name, parameter in init_signature.parameters.items():
        if parameter_name in parametersOk:
            gatesParameters[name][parameter_name] = typesDict[str(parameter.annotation)]
            #print(f"    Parâmetro: {parameter_name}, Tipo anotado: {parameter.annotation} -> {type(parameter.annotation)}")
parameters = [name for gateName, gateInfo in gatesParameters.items() for name in gateInfo.keys()]
#print(set(parameters))
gatesParameters
# Out:
# {'ccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int']},
#  'ccz': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int']},
#  'ch': {'control_qubit': ['int'], 'target_qubit': ['int']},
#  'cp': {'theta': ['float'], 'control_qubit': ['int'], 'target_qubit': ['int']},
#  'crx': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int']},
#  'cry': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int']},
#  'crz': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int']},
#  'cs': {'control_qubit': ['int'], 'target_qubit': ['int']},
#  'csdg': {'control_qubit': ['int'], 'target_qubit': ['int']},
#  'cswap': {'control_qubit': ['int'],
#   'target_qubit1': ['int'],
#   'target_qubit2': ['int']},
#  'csx': {'control_qubit': ['int'], 'target_qubit': ['int']},
#  'cu': {'theta': ['float'],
#   'phi': ['float'],
#   'lam': ['float'],
#   'gamma': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int']},
#  'cx': {'control_qubit': ['int'], 'target_qubit': ['int']},
#  'cy': {'control_qubit': ['int'], 'target_qubit': ['int']},
#  'cz': {'control_qubit': ['int'], 'target_qubit': ['int']},
#  'dcx': {'qubit1': ['int'], 'qubit2': ['int']},
#  'ecr': {'qubit1': ['int'], 'qubit2': ['int']},
#  'h': {'qubit': ['int']},
#  'id': {'qubit': ['int']},
#  'iswap': {'qubit1': ['int'], 'qubit2': ['int']},
#  'mcp': {'lam': ['float'],
#   'control_qubits': ['list[int]'],
#   'target_qubit': ['int']},
#  'mcrx': {'theta': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int']},
#  'mcry': {'theta': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int'],
#   'q_ancillae': ['int', 'list[int]', 'None']},
#  'mcrz': {'lam': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int']},
#  'mcx': {'control_qubits': ['list[int]'],
#   'target_qubit': ['int'],
#   'ancilla_qubits': ['int', 'list[int]', 'None']},
#  'ms': {'theta': ['float'], 'qubits': ['list[int]']},
#  'p': {'theta': ['float'], 'qubit': ['int']},
#  'r': {'theta': ['float'], 'phi': ['float'], 'qubit': ['int']},
#  'rcccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'control_qubit3': ['int'],
#   'target_qubit': ['int']},
#  'rccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int']},
#  'rv': {'vx': ['float'], 'vy': ['float'], 'vz': ['float'], 'qubit': ['int']},
#  'rx': {'theta': ['float'], 'qubit': ['int']},
#  'rxx': {'theta': ['float'], 'qubit1': ['int'], 'qubit2': ['int']},
#  'ry': {'theta': ['float'], 'qubit': ['int']},
#  'ryy': {'theta': ['float'], 'qubit1': ['int'], 'qubit2': ['int']},
#  'rz': {'phi': ['float'], 'qubit': ['int']},
#  'rzx': {'theta': ['float'], 'qubit1': ['int'], 'qubit2': ['int']},
#  'rzz': {'theta': ['float'], 'qubit1': ['int'], 'qubit2': ['int']},
#  's': {'qubit': ['int']},
#  'sdg': {'qubit': ['int']},
#  'swap': {'qubit1': ['int'], 'qubit2': ['int']},
#  'sx': {'qubit': ['int']},
#  'sxdg': {'qubit': ['int']},
#  't': {'qubit': ['int']},
#  'tdg': {'qubit': ['int']},
#  'u': {'theta': ['float'],
#   'phi': ['float'],
#   'lam': ['float'],
#   'qubit': ['int']},
#  'x': {'qubit': ['int']},
#  'y': {'qubit': ['int']},
#  'z': {'qubit': ['int']}}

# %%
for gatename, gateInfo in gatesParameters.items():
    affectedQubits = 0
    controlQubits = 0
    parametersCount = 0
    combinations = []
    valores = [list(v) for v in gateInfo.values()]
    combinacoes = itertools.product(*valores)
    gateInfo["info"] = {}
    # (Qubits, Parameters, Strs)
    gateInfo["info"]["combinations"] = [(x, x.count("int") + x.count("list[int]"), x.count("float"), x.count("str")) for x in combinacoes]

# %%
gatesParameters
# Out:
# {'ccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int', 'int'), 3, 0, 0)]}},
#  'ccz': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int', 'int'), 3, 0, 0)]}},
#  'ch': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'cp': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  'crx': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  'cry': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  'crz': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  'cs': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'csdg': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'cswap': {'control_qubit': ['int'],
#   'target_qubit1': ['int'],
#   'target_qubit2': ['int'],
#   'info': {'combinations': [(('int', 'int', 'int'), 3, 0, 0)]}},
#  'csx': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'cu': {'theta': ['float'],
#   'phi': ['float'],
#   'lam': ['float'],
#   'gamma': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('float',
#       'float',
#       'float',
#       'float',
#       'int',
#       'int'),
#      2,
#      4,
#      0)]}},
#  'cx': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'cy': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'cz': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'dcx': {'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'ecr': {'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'h': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'id': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'iswap': {'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'mcp': {'lam': ['float'],
#   'control_qubits': ['list[int]'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('float', 'list[int]', 'int'), 2, 1, 0)]}},
#  'mcrx': {'theta': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0),
#     (('float', 'list[int]', 'int'), 2, 1, 0)]}},
#  'mcry': {'theta': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int'],
#   'q_ancillae': ['int', 'list[int]', 'None'],
#   'info': {'combinations': [(('float', 'int', 'int', 'int'), 3, 1, 0),
#     (('float', 'int', 'int', 'list[int]'), 3, 1, 0),
#     (('float', 'int', 'int', 'None'), 2, 1, 0),
#     (('float', 'list[int]', 'int', 'int'), 3, 1, 0),
#     (('float', 'list[int]', 'int', 'list[int]'), 3, 1, 0),
#     (('float', 'list[int]', 'int', 'None'), 2, 1, 0)]}},
#  'mcrz': {'lam': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0),
#     (('float', 'list[int]', 'int'), 2, 1, 0)]}},
#  'mcx': {'control_qubits': ['list[int]'],
#   'target_qubit': ['int'],
#   'ancilla_qubits': ['int', 'list[int]', 'None'],
#   'info': {'combinations': [(('list[int]', 'int', 'int'), 3, 0, 0),
#     (('list[int]', 'int', 'list[int]'), 3, 0, 0),
#     (('list[int]', 'int', 'None'), 2, 0, 0)]}},
#  'ms': {'theta': ['float'],
#   'qubits': ['list[int]'],
#   'info': {'combinations': [(('float', 'list[int]'), 1, 1, 0)]}},
#  'p': {'theta': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'r': {'theta': ['float'],
#   'phi': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'float', 'int'), 1, 2, 0)]}},
#  'rcccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'control_qubit3': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int', 'int', 'int'), 4, 0, 0)]}},
#  'rccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': [(('int', 'int', 'int'), 3, 0, 0)]}},
#  'rv': {'vx': ['float'],
#   'vy': ['float'],
#   'vz': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'float', 'float', 'int'), 1, 3, 0)]}},
#  'rx': {'theta': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'rxx': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  'ry': {'theta': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'ryy': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  'rz': {'phi': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'rzx': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  'rzz': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('float', 'int', 'int'), 2, 1, 0)]}},
#  's': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'sdg': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'swap': {'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': [(('int', 'int'), 2, 0, 0)]}},
#  'sx': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'sxdg': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  't': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'tdg': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'u': {'theta': ['float'],
#   'phi': ['float'],
#   'lam': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'float', 'float', 'int'), 1, 3, 0)]}},
#  'x': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'y': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'z': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}}}

# %%
class Parameter:
    def __init__(self, name:str, type:list[str]):
        self.name = name
        self.type = type

class Circuit:
    def __init__(self, n_qubits, m_gates) -> None:
        self.n_qubits = n_qubits
        self.m_gates = m_gates
        self.gates = [[] for _ in range(m_gates)]
        self.fitness = None
        self.circuit = None
        
    def constructCircuit(self):
        self.circuit = QuantumCircuit(self.n_qubits)
        print("Construindo Circuito:")
        for gatesInDepth in self.gates:
            print(" Profundidade:")
            for gate in gatesInDepth:
                print(f"    {gate}")
                parametersString = ""
                for type, _, parameter in gate.parameters:
                    parametersString += f"{parameter}"
                    if type == "float":
                        parametersString += f"*{PI}"
                    parametersString += ","
                parametersString = parametersString[:-1]
                exec(f"self.circuit.{gate.name}({parametersString})")
    
    def __str__(self) -> str:
        return f"Circuit [{self.n_qubits} x {self.m_gates}] "

class Gate:
    def __init__(self, name:str, affected_qubits:list[int], gateInfo:dict={}) -> None:
        self.name =  name
        self.affected_qubits = affected_qubits
        self.parameters = gateInfo["combinations"][0]
        #self.gateInfo = gateInfo #? {'combinations': [[['str', 1], ['list[int]', 1, [0]]], 1, 0, 1]}} or {'combinations': [[['int', 1, 2]], 1, 0, 0]}
    def __str__(self) -> str:
        return f"[{self.name}] -> {self.affected_qubits}   -----------  {self.parameters}"

# %%
def fidelityFitnessFunction(circuit:Circuit, svTarget:Statevector, nQubit:int):
    # Mapeamento para um espaço maior (adicionando 5 qubits ancilla em |0⟩)
    difQubit = nQubit - circuit.n_qubits
    print(f"Qubits {nQubit} X {circuit.n_qubits}  --- {difQubit}")
    svTargetLocal = Statevector(svTarget)
    svSolution = Statevector.from_instruction(circuit.circuit)
    if difQubit < 0:
        svTargetLocal = svTargetLocal.tensor(Statevector.from_label('0'*(-difQubit)))
    elif difQubit > 0:
        svSolution = svSolution.tensor(Statevector.from_label('0'*difQubit))
    print(svTargetLocal)
    print(svSolution)
    fidelity = state_fidelity(svSolution, svTargetLocal)
    fidelity = fidelity - abs(nQubit - circuit.n_qubits) * PENALTY_QUBITS
    return max(0, fidelity)

def createGateToListQubits(qubitsFree:list, structLocal:dict):
    for gateName, gateInfo in structLocal.items():
        gateInfo["info"]["combinations"] = [combination for combination in gateInfo["info"]["combinations"] if combination[1] <= len(qubitsFree)]
    structLocal = {gateName: gateInfo for gateName, gateInfo in structLocal.items() if len(gateInfo["info"]["combinations"])}

    gateName, gateInfo = random.choice(list(structLocal.items()))
    gateInfo = gateInfo.copy()
    gateCounts = gateInfo.pop("info").copy()
    gateCounts["combinations"] = list(random.choice(gateCounts["combinations"]))
    gateCounts["combinations"][0] = list(gateCounts["combinations"][0])
    countFree = len(qubitsFree) - gateCounts["combinations"][1]
    types = []
    for type in gateCounts["combinations"][0]:
        type = [type, 1 if type != "None" else 0]
        if type.count("list[int]"):
            addCount = random.randint(0, countFree)
            countFree -= addCount
            type[1] += addCount
            gateCounts["combinations"][1] += addCount
        types.append(type)
    gateCounts["combinations"][0] = types
    
    qubitsChoice = random.sample(qubitsFree, gateCounts["combinations"][1])
    affectedQubits = list(qubitsChoice)
    qubitsFree = list(set(qubitsFree).difference(qubitsChoice))
    for param in gateCounts["combinations"][0]:
        if param[0] in ["int", "list[int]"]:
            qubits = random.sample(qubitsChoice, param[1])
            qubitsChoice = list(set(qubitsChoice).difference(qubits))
            if  param[0] == "int":
                qubits = qubits[0]
            param.append(qubits)
        elif param[0] == "float":
            param.append(random.uniform(0, 2)) #! Adicionar Estratégia Evolucionária
        #! Adicionar caso de str para o Pauli String
    gate = Gate(gateName, affectedQubits, gateCounts)
    return gate, qubitsFree

def createCircuit(numQubits, maxDepth, minDepth):
    depth = random.randint(minDepth, maxDepth)
    circuit = Circuit(numQubits, depth)
    print(f"Circuito = {numQubits} x {depth}:")
    for y in range(depth):
        print(f"    Depth {y}:")
        gatesParametersLocal = gatesParameters.copy()
        qubitsFree = list(range(numQubits))
        while qubitsFree:
            gate, qubitsFree = createGateToListQubits(qubitsFree, gatesParametersLocal)
            print(f"        {gate}")
            circuit.gates[y].append(gate)
    return circuit

def initialPopulation(numPopulation:int, numQubits:int, maxDepth:int, minDepth:int=0):
    population = []
    for _ in range(numPopulation):
        circuit = createCircuit(numQubits, maxDepth, minDepth)
        circuit.constructCircuit()
        circuit.fitness = fidelityFitnessFunction(circuit, svTarget, num_qubits)
        population.append(circuit)
    return population



def generations(population:list[Circuit], maxGeneration:int, svTarget:Statevector):
    for gen in range(maxGeneration):
        populationSelected = selection(population, svTarget)
        populationNextGen = crossover(populationSelected)
    return populationSelected, len(populationSelected)
        #populationNextGen = mutation(populationNextGen)
        #population = selection(population + populationNextGen, svTarget)

def selection(population:list[Circuit], svTarget:Statevector):
    populationLocal = list(population)
    random.shuffle(populationLocal)
    lenPopulation = len(populationLocal)
    lenGroup = int(lenPopulation * 0.05)
    maxLenChampions = lenPopulation//2
    champions = []
    groups = [populationLocal[i:i+lenGroup] for i in range(0, lenPopulation, lenGroup)]
    for group in groups:
        champion = max(group, key=lambda circuit: circuit.fitness)
        populationLocal.remove(champion)
        champions.append(champion)

    while (maxLenChampions > len(champions)):
        lenPopulation = len(populationLocal)
        random.shuffle(populationLocal)
        group = populationLocal[:int(lenPopulation * 0.03)]
        champion = max(group, key=lambda circuit: fidelityFitnessFunction(circuit, svTarget, num_qubits))
        populationLocal.remove(champion)
        champions.append(champion)
    return champions

def crossover(population:list[Circuit]):
    populationLocal = list(population)
    random.shuffle(populationLocal)
    populationNextGen = []
    for i in range(0, len(populationLocal), 2):
        circuit1 = populationLocal[i]
        circuit2 = populationLocal[i+1]
        if random.random()%100 < CROSSOVER:
            circuitGates1 = []
            circuitGates2 = []
            minDepth = circuit1.m_gates if circuit1.m_gates <= circuit2.m_gates else circuit2.m_gates
            points = random.choices([0, 1], minDepth)
            for y in range(minDepth):
                if points[y] == 0:
                    circuitGates1.append(circuit1.gates[y])
                    circuitGates2.append(circuit2.gates[y])
                else:
                    circuitGates1.append(circuit2.gates[y])
                    circuitGates2.append(circuit1.gates[y])
            circuitGates1 += circuit1.gates[mi - 1:]
            circuitGates2 += circuit2.gates[circuit2.m_gates - 1:]
            
    
def mutation():
    pass
def survivorSelection():
    pass

# %%
#createPopulation(10,2, 5)
population = initialPopulation(100, 3, 10)
# Out:
# Circuito = 3 x 7:
#     Depth 0:
#         [s] -> [1]   -----------  [['int', 1, 1]]
#         [x] -> [0]   -----------  [['int', 1, 0]]
#         [y] -> [2]   -----------  [['int', 1, 2]]
#     Depth 1:
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#         [sdg] -> [2]   -----------  [['int', 1, 2]]
#     Depth 2:
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#         [x] -> [1]   -----------  [['int', 1, 1]]
#         [sdg] -> [2]   -----------  [['int', 1, 2]]
#     Depth 3:
#         [rv] -> [0]   -----------  [['float', 1, 1.0434910504266777], ['float', 1, 0.09458460989996276], ['float', 1, 0.5999018410104475], ['int', 1, 0]]
#         [rv] -> [1]   -----------  [['float', 1, 0.1969443968554354], ['float', 1, 1.2377960328097124], ['float', 1, 1.7152607116065808], ['int', 1, 1]]
#         [id] -> [2]   -----------  [['int', 1, 2]]
#     Depth 4:
#         [p] -> [0]   -----------  [['float', 1, 1.752883449877881], ['int', 1, 0]]
#         [sxdg] -> [1]   -----------  [['int', 1, 1]]
#         [p] -> [2]   -----------  [['float', 1, 0.1709853176131031], ['int', 1, 2]]
#     Depth 5:
#         [h] -> [2]   -----------  [['int', 1, 2]]
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#         [u] -> [1]   -----------  [['float', 1, 0.8242655748917092], ['float', 1, 0.08390354315258985], ['float', 1, 1.3812838023931406], ['int', 1, 1]]
#     Depth 6:
#         [rx] -> [0]   -----------  [['float', 1, 0.6951335599718749], ['int', 1, 0]]
#         [id] -> [1]   -----------  [['int', 1, 1]]
#         [u] -> [2]   -----------  [['float', 1, 0.5298887782907962], ['float', 1, 1.4083141051778025], ['float', 1, 0.10004057836742675], ['int', 1, 2]]
# Construindo Circuito:
#  Profundidade:
#     [s] -> [1]   -----------  [['int', 1, 1]]
#     [x] -> [0]   -----------  [['int', 1, 0]]
#     [y] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [sdg] -> [0]   -----------  [['int', 1, 0]]
#     [sdg] -> [1]   -----------  [['int', 1, 1]]
#     [sdg] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [sdg] -> [0]   -----------  [['int', 1, 0]]
#     [x] -> [1]   -----------  [['int', 1, 1]]
#     [sdg] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [rv] -> [0]   -----------  [['float', 1, 1.0434910504266777], ['float', 1, 0.09458460989996276], ['float', 1, 0.5999018410104475], ['int', 1, 0]]
#     [rv] -> [1]   -----------  [['float', 1, 0.1969443968554354], ['float', 1, 1.2377960328097124], ['float', 1, 1.7152607116065808], ['int', 1, 1]]
#     [id] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [p] -> [0]   -----------  [['float', 1, 1.752883449877881], ['int', 1, 0]]
#     [sxdg] -> [1]   -----------  [['int', 1, 1]]
#     [p] -> [2]   -----------  [['float', 1, 0.1709853176131031], ['int', 1, 2]]
#  Profundidade:
#     [h] -> [2]   -----------  [['int', 1, 2]]
#     [sdg] -> [0]   -----------  [['int', 1, 0]]
#     [u] -> [1]   -----------  [['float', 1, 0.8242655748917092], ['float', 1, 0.08390354315258985], ['float', 1, 1.3812838023931406], ['int', 1, 1]]
#  Profundidade:
#     [rx] -> [0]   -----------  [['float', 1, 0.6951335599718749], ['int', 1, 0]]
#     [id] -> [1]   -----------  [['int', 1, 1]]
#     [u] -> [2]   -----------  [['float', 1, 0.5298887782907962], ['float', 1, 1.4083141051778025], ['float', 1, 0.10004057836742675], ['int', 1, 2]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.30382107-0.67179853j, -0.37117428+0.1247318j ,
#               0.23008128-0.40336762j, -0.20087675-0.14307575j,
#               0.05101128+0.1106588j ,  0.06119139-0.02105618j,
#              -0.0375418 +0.06693514j,  0.03336766+0.02340494j],
#             dims=(2, 2, 2))
# Circuito = 3 x 7:
#     Depth 0:
#         [sx] -> [1]   -----------  [['int', 1, 1]]
#         [sdg] -> [2]   -----------  [['int', 1, 2]]
#         [x] -> [0]   -----------  [['int', 1, 0]]
#     Depth 1:
#         [u] -> [1]   -----------  [['float', 1, 0.9988967042165338], ['float', 1, 1.0670152891463782], ['float', 1, 1.7502009019182683], ['int', 1, 1]]
#         [t] -> [2]   -----------  [['int', 1, 2]]
#         [s] -> [0]   -----------  [['int', 1, 0]]
#     Depth 2:
#         [rx] -> [1]   -----------  [['float', 1, 1.713528598916604], ['int', 1, 1]]
#         [p] -> [0]   -----------  [['float', 1, 1.0062187874456658], ['int', 1, 0]]
#         [y] -> [2]   -----------  [['int', 1, 2]]
#     Depth 3:
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#         [id] -> [2]   -----------  [['int', 1, 2]]
#         [r] -> [1]   -----------  [['float', 1, 1.7103704727032236], ['float', 1, 0.2695641080633293], ['int', 1, 1]]
#     Depth 4:
#         [sxdg] -> [0]   -----------  [['int', 1, 0]]
#         [x] -> [2]   -----------  [['int', 1, 2]]
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
#     Depth 5:
#         [tdg] -> [2]   -----------  [['int', 1, 2]]
#         [p] -> [1]   -----------  [['float', 1, 1.921326481635287], ['int', 1, 1]]
#         [tdg] -> [0]   -----------  [['int', 1, 0]]
#     Depth 6:
#         [ry] -> [0]   -----------  [['float', 1, 1.3140871335409168], ['int', 1, 0]]
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
#         [h] -> [2]   -----------  [['int', 1, 2]]
# Construindo Circuito:
#  Profundidade:
#     [sx] -> [1]   -----------  [['int', 1, 1]]
#     [sdg] -> [2]   -----------  [['int', 1, 2]]
#     [x] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [u] -> [1]   -----------  [['float', 1, 0.9988967042165338], ['float', 1, 1.0670152891463782], ['float', 1, 1.7502009019182683], ['int', 1, 1]]
#     [t] -> [2]   -----------  [['int', 1, 2]]
#     [s] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [rx] -> [1]   -----------  [['float', 1, 1.713528598916604], ['int', 1, 1]]
#     [p] -> [0]   -----------  [['float', 1, 1.0062187874456658], ['int', 1, 0]]
#     [y] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [sdg] -> [0]   -----------  [['int', 1, 0]]
#     [id] -> [2]   -----------  [['int', 1, 2]]
#     [r] -> [1]   -----------  [['float', 1, 1.7103704727032236], ['float', 1, 0.2695641080633293], ['int', 1, 1]]
#  Profundidade:
#     [sxdg] -> [0]   -----------  [['int', 1, 0]]
#     [x] -> [2]   -----------  [['int', 1, 2]]
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [tdg] -> [2]   -----------  [['int', 1, 2]]
#     [p] -> [1]   -----------  [['float', 1, 1.921326481635287], ['int', 1, 1]]
#     [tdg] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [ry] -> [0]   -----------  [['float', 1, 1.3140871335409168], ['int', 1, 0]]
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
#     [h] -> [2]   -----------  [['int', 1, 2]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.03649161+0.04482104j,  0.11197402-0.02030487j,
#              -0.25182511+0.18913284j,  0.08667833+0.61401035j,
#               0.03649161+0.04482104j,  0.11197402-0.02030487j,
#              -0.25182511+0.18913284j,  0.08667833+0.61401035j],
#             dims=(2, 2, 2))
# Circuito = 3 x 5:
#     Depth 0:
#         [t] -> [2]   -----------  [['int', 1, 2]]
#         [id] -> [1]   -----------  [['int', 1, 1]]
#         [h] -> [0]   -----------  [['int', 1, 0]]
#     Depth 1:
#         [r] -> [0]   -----------  [['float', 1, 1.6036868141453078], ['float', 1, 0.8236433763544619], ['int', 1, 0]]
#         [rz] -> [1]   -----------  [['float', 1, 1.4430309342479797], ['int', 1, 1]]
#         [sx] -> [2]   -----------  [['int', 1, 2]]
#     Depth 2:
#         [t] -> [1]   -----------  [['int', 1, 1]]
#         [u] -> [2]   -----------  [['float', 1, 0.9374445112048446], ['float', 1, 0.05381317835253219], ['float', 1, 1.5112035728461157], ['int', 1, 2]]
#         [r] -> [0]   -----------  [['float', 1, 1.2429655937164361], ['float', 1, 1.0645571907423592], ['int', 1, 0]]
#     Depth 3:
#         [ms] -> [1, 2]   -----------  [['float', 1, 1.205131715991481], ['list[int]', 2, [1, 2]]]
#         [y] -> [0]   -----------  [['int', 1, 0]]
#     Depth 4:
#         [ms] -> [0, 2]   -----------  [['float', 1, 1.3488109985110566], ['list[int]', 2, [2, 0]]]
#         [h] -> [1]   -----------  [['int', 1, 1]]
# Construindo Circuito:
#  Profundidade:
#     [t] -> [2]   -----------  [['int', 1, 2]]
#     [id] -> [1]   -----------  [['int', 1, 1]]
#     [h] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [r] -> [0]   -----------  [['float', 1, 1.6036868141453078], ['float', 1, 0.8236433763544619], ['int', 1, 0]]
#     [rz] -> [1]   -----------  [['float', 1, 1.4430309342479797], ['int', 1, 1]]
#     [sx] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [t] -> [1]   -----------  [['int', 1, 1]]
#     [u] -> [2]   -----------  [['float', 1, 0.9374445112048446], ['float', 1, 0.05381317835253219], ['float', 1, 1.5112035728461157], ['int', 1, 2]]
#     [r] -> [0]   -----------  [['float', 1, 1.2429655937164361], ['float', 1, 1.0645571907423592], ['int', 1, 0]]
#  Profundidade:
#     [ms] -> [1, 2]   -----------  [['float', 1, 1.205131715991481], ['list[int]', 2, [1, 2]]]
#     [y] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [ms] -> [0, 2]   -----------  [['float', 1, 1.3488109985110566], ['list[int]', 2, [2, 0]]]
#     [h] -> [1]   -----------  [['int', 1, 1]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.13759587+0.21679141j,  0.00887529-0.46138248j,
#               0.22140794-0.04956449j, -0.23376753+0.34246681j,
#              -0.20598614+0.18544925j,  0.04391005-0.37731485j,
#               0.29491044-0.06559396j, -0.3122793 +0.29630728j],
#             dims=(2, 2, 2))
# Circuito = 3 x 3:
#     Depth 0:
#         [r] -> [0]   -----------  [['float', 1, 1.7372509945361938], ['float', 1, 1.0316833909999275], ['int', 1, 0]]
#         [sx] -> [2]   -----------  [['int', 1, 2]]
#         [h] -> [1]   -----------  [['int', 1, 1]]
#     Depth 1:
#         [rz] -> [0]   -----------  [['float', 1, 1.948732524867961], ['int', 1, 0]]
#         [sx] -> [1]   -----------  [['int', 1, 1]]
#         [rx] -> [2]   -----------  [['float', 1, 1.2676785585670085], ['int', 1, 2]]
#     Depth 2:
#         [rv] -> [0]   -----------  [['float', 1, 1.3752536871735872], ['float', 1, 1.9750589856061185], ['float', 1, 0.3567838602491158], ['int', 1, 0]]
#         [x] -> [1]   -----------  [['int', 1, 1]]
#         [x] -> [2]   -----------  [['int', 1, 2]]
# Construindo Circuito:
#  Profundidade:
#     [r] -> [0]   -----------  [['float', 1, 1.7372509945361938], ['float', 1, 1.0316833909999275], ['int', 1, 0]]
#     [sx] -> [2]   -----------  [['int', 1, 2]]
#     [h] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [rz] -> [0]   -----------  [['float', 1, 1.948732524867961], ['int', 1, 0]]
#     [sx] -> [1]   -----------  [['int', 1, 1]]
#     [rx] -> [2]   -----------  [['float', 1, 1.2676785585670085], ['int', 1, 2]]
#  Profundidade:
#     [rv] -> [0]   -----------  [['float', 1, 1.3752536871735872], ['float', 1, 1.9750589856061185], ['float', 1, 0.3567838602491158], ['int', 1, 0]]
#     [x] -> [1]   -----------  [['int', 1, 1]]
#     [x] -> [2]   -----------  [['int', 1, 2]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.13300027+0.07050395j,  0.0112058 +0.20223131j,
#              -0.13300027+0.07050395j,  0.0112058 +0.20223131j,
#               0.18454529+0.34813046j,  0.52934387-0.02933138j,
#               0.18454529+0.34813046j,  0.52934387-0.02933138j],
#             dims=(2, 2, 2))
# Circuito = 3 x 6:
#     Depth 0:
#         [ry] -> [2]   -----------  [['float', 1, 1.7156243959065332], ['int', 1, 2]]
#         [u] -> [0]   -----------  [['float', 1, 0.04457878165056717], ['float', 1, 1.4161867970576278], ['float', 1, 1.0317437090392663], ['int', 1, 0]]
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#     Depth 1:
#         [s] -> [1]   -----------  [['int', 1, 1]]
#         [y] -> [2]   -----------  [['int', 1, 2]]
#         [ms] -> [0]   -----------  [['float', 1, 0.15609181546402606], ['list[int]', 1, [0]]]
#     Depth 2:
#         [t] -> [2]   -----------  [['int', 1, 2]]
#         [rx] -> [0]   -----------  [['float', 1, 0.1131102172492009], ['int', 1, 0]]
#         [x] -> [1]   -----------  [['int', 1, 1]]
#     Depth 3:
#         [rx] -> [1]   -----------  [['float', 1, 0.9825118298112585], ['int', 1, 1]]
#         [z] -> [2]   -----------  [['int', 1, 2]]
#         [rz] -> [0]   -----------  [['float', 1, 1.6736409857069796], ['int', 1, 0]]
#     Depth 4:
#         [rv] -> [1]   -----------  [['float', 1, 0.8102727929270006], ['float', 1, 0.501848694998912], ['float', 1, 1.1535045294428412], ['int', 1, 1]]
#         [z] -> [2]   -----------  [['int', 1, 2]]
#         [ms] -> [0]   -----------  [['float', 1, 1.8819055138411742], ['list[int]', 1, [0]]]
#     Depth 5:
#         [ry] -> [1]   -----------  [['float', 1, 1.0009616198056832], ['int', 1, 1]]
#         [tdg] -> [2]   -----------  [['int', 1, 2]]
#         [p] -> [0]   -----------  [['float', 1, 0.6946540547227116], ['int', 1, 0]]
# Construindo Circuito:
#  Profundidade:
#     [ry] -> [2]   -----------  [['float', 1, 1.7156243959065332], ['int', 1, 2]]
#     [u] -> [0]   -----------  [['float', 1, 0.04457878165056717], ['float', 1, 1.4161867970576278], ['float', 1, 1.0317437090392663], ['int', 1, 0]]
#     [sdg] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [s] -> [1]   -----------  [['int', 1, 1]]
#     [y] -> [2]   -----------  [['int', 1, 2]]
#     [ms] -> [0]   -----------  [['float', 1, 0.15609181546402606], ['list[int]', 1, [0]]]
#  Profundidade:
#     [t] -> [2]   -----------  [['int', 1, 2]]
#     [rx] -> [0]   -----------  [['float', 1, 0.1131102172492009], ['int', 1, 0]]
#     [x] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [rx] -> [1]   -----------  [['float', 1, 0.9825118298112585], ['int', 1, 1]]
#     [z] -> [2]   -----------  [['int', 1, 2]]
#     [rz] -> [0]   -----------  [['float', 1, 1.6736409857069796], ['int', 1, 0]]
#  Profundidade:
#     [rv] -> [1]   -----------  [['float', 1, 0.8102727929270006], ['float', 1, 0.501848694998912], ['float', 1, 1.1535045294428412], ['int', 1, 1]]
#     [z] -> [2]   -----------  [['int', 1, 2]]
#     [ms] -> [0]   -----------  [['float', 1, 1.8819055138411742], ['list[int]', 1, [0]]]
#  Profundidade:
#     [ry] -> [1]   -----------  [['float', 1, 1.0009616198056832], ['int', 1, 1]]
#     [tdg] -> [2]   -----------  [['int', 1, 2]]
#     [p] -> [0]   -----------  [['float', 1, 0.6946540547227116], ['int', 1, 0]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.16477158+0.1016832j , -0.02444851+0.04200418j,
#              -0.13785978-0.34504826j, -0.07134048-0.06007928j,
#              -0.34400027+0.21228811j, -0.05104215+0.08769383j,
#              -0.28781543-0.72037116j, -0.1489404 -0.12542993j],
#             dims=(2, 2, 2))
# Circuito = 3 x 0:
# Construindo Circuito:
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# Circuito = 3 x 10:
#     Depth 0:
#         [s] -> [0]   -----------  [['int', 1, 0]]
#         [u] -> [2]   -----------  [['float', 1, 0.207201856588912], ['float', 1, 1.498784846919768], ['float', 1, 1.2970631452608337], ['int', 1, 2]]
#         [t] -> [1]   -----------  [['int', 1, 1]]
#     Depth 1:
#         [p] -> [0]   -----------  [['float', 1, 0.9836565814380642], ['int', 1, 0]]
#         [t] -> [1]   -----------  [['int', 1, 1]]
#         [x] -> [2]   -----------  [['int', 1, 2]]
#     Depth 2:
#         [t] -> [2]   -----------  [['int', 1, 2]]
#         [sx] -> [1]   -----------  [['int', 1, 1]]
#         [ms] -> [0]   -----------  [['float', 1, 0.020483263904618854], ['list[int]', 1, [0]]]
#     Depth 3:
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#         [u] -> [2]   -----------  [['float', 1, 1.9363070433525769], ['float', 1, 0.5689187060116596], ['float', 1, 1.4743281521750973], ['int', 1, 2]]
#         [h] -> [1]   -----------  [['int', 1, 1]]
#     Depth 4:
#         [p] -> [0]   -----------  [['float', 1, 1.463680247515195], ['int', 1, 0]]
#         [z] -> [1]   -----------  [['int', 1, 1]]
#         [sx] -> [2]   -----------  [['int', 1, 2]]
#     Depth 5:
#         [u] -> [1]   -----------  [['float', 1, 1.3178598358900502], ['float', 1, 0.29459782510051635], ['float', 1, 1.1027621401749101], ['int', 1, 1]]
#         [sx] -> [2]   -----------  [['int', 1, 2]]
#         [p] -> [0]   -----------  [['float', 1, 1.026688122772716], ['int', 1, 0]]
#     Depth 6:
#         [ry] -> [2]   -----------  [['float', 1, 0.872198696095394], ['int', 1, 2]]
#         [r] -> [0]   -----------  [['float', 1, 0.6708508875705137], ['float', 1, 1.9171362973127413], ['int', 1, 0]]
#         [x] -> [1]   -----------  [['int', 1, 1]]
#     Depth 7:
#         [p] -> [0]   -----------  [['float', 1, 0.8691993437061458], ['int', 1, 0]]
#         [sxdg] -> [1]   -----------  [['int', 1, 1]]
#         [rx] -> [2]   -----------  [['float', 1, 1.4157087669762705], ['int', 1, 2]]
#     Depth 8:
#         [rv] -> [1]   -----------  [['float', 1, 1.937252170914944], ['float', 1, 0.20931498755982414], ['float', 1, 0.1508668328099143], ['int', 1, 1]]
#         [sdg] -> [2]   -----------  [['int', 1, 2]]
#         [y] -> [0]   -----------  [['int', 1, 0]]
#     Depth 9:
#         [sxdg] -> [1]   -----------  [['int', 1, 1]]
#         [rv] -> [2]   -----------  [['float', 1, 0.6339268775435731], ['float', 1, 0.6733772557422231], ['float', 1, 1.9757108488381403], ['int', 1, 2]]
#         [ms] -> [0]   -----------  [['float', 1, 1.4340194711260281], ['list[int]', 1, [0]]]
# Construindo Circuito:
#  Profundidade:
#     [s] -> [0]   -----------  [['int', 1, 0]]
#     [u] -> [2]   -----------  [['float', 1, 0.207201856588912], ['float', 1, 1.498784846919768], ['float', 1, 1.2970631452608337], ['int', 1, 2]]
#     [t] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [p] -> [0]   -----------  [['float', 1, 0.9836565814380642], ['int', 1, 0]]
#     [t] -> [1]   -----------  [['int', 1, 1]]
#     [x] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [t] -> [2]   -----------  [['int', 1, 2]]
#     [sx] -> [1]   -----------  [['int', 1, 1]]
#     [ms] -> [0]   -----------  [['float', 1, 0.020483263904618854], ['list[int]', 1, [0]]]
#  Profundidade:
#     [sdg] -> [0]   -----------  [['int', 1, 0]]
#     [u] -> [2]   -----------  [['float', 1, 1.9363070433525769], ['float', 1, 0.5689187060116596], ['float', 1, 1.4743281521750973], ['int', 1, 2]]
#     [h] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [p] -> [0]   -----------  [['float', 1, 1.463680247515195], ['int', 1, 0]]
#     [z] -> [1]   -----------  [['int', 1, 1]]
#     [sx] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [u] -> [1]   -----------  [['float', 1, 1.3178598358900502], ['float', 1, 0.29459782510051635], ['float', 1, 1.1027621401749101], ['int', 1, 1]]
#     [sx] -> [2]   -----------  [['int', 1, 2]]
#     [p] -> [0]   -----------  [['float', 1, 1.026688122772716], ['int', 1, 0]]
#  Profundidade:
#     [ry] -> [2]   -----------  [['float', 1, 0.872198696095394], ['int', 1, 2]]
#     [r] -> [0]   -----------  [['float', 1, 0.6708508875705137], ['float', 1, 1.9171362973127413], ['int', 1, 0]]
#     [x] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [p] -> [0]   -----------  [['float', 1, 0.8691993437061458], ['int', 1, 0]]
#     [sxdg] -> [1]   -----------  [['int', 1, 1]]
#     [rx] -> [2]   -----------  [['float', 1, 1.4157087669762705], ['int', 1, 2]]
#  Profundidade:
#     [rv] -> [1]   -----------  [['float', 1, 1.937252170914944], ['float', 1, 0.20931498755982414], ['float', 1, 0.1508668328099143], ['int', 1, 1]]
#     [sdg] -> [2]   -----------  [['int', 1, 2]]
#     [y] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [sxdg] -> [1]   -----------  [['int', 1, 1]]
#     [rv] -> [2]   -----------  [['float', 1, 0.6339268775435731], ['float', 1, 0.6733772557422231], ['float', 1, 1.9757108488381403], ['int', 1, 2]]
#     [ms] -> [0]   -----------  [['float', 1, 1.4340194711260281], ['list[int]', 1, [0]]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.34239686-0.24077246j, -0.01388673+0.23760593j,
#              -0.11030403+0.60790888j, -0.231665  -0.26410672j,
#              -0.08352738-0.23568395j,  0.13448003+0.04616095j,
#               0.33205132+0.16112492j, -0.18917519+0.09086441j],
#             dims=(2, 2, 2))
# Circuito = 3 x 2:
#     Depth 0:
#         [z] -> [2]   -----------  [['int', 1, 2]]
#         [sxdg] -> [1]   -----------  [['int', 1, 1]]
#         [u] -> [0]   -----------  [['float', 1, 1.0796925450229808], ['float', 1, 1.8924570113582482], ['float', 1, 0.3787122137064196], ['int', 1, 0]]
#     Depth 1:
#         [rz] -> [2]   -----------  [['float', 1, 0.01032952500265849], ['int', 1, 2]]
#         [rv] -> [1]   -----------  [['float', 1, 0.8804303205070048], ['float', 1, 0.18395925784369505], ['float', 1, 0.15159070654684115], ['int', 1, 1]]
#         [id] -> [0]   -----------  [['int', 1, 0]]
# Construindo Circuito:
#  Profundidade:
#     [z] -> [2]   -----------  [['int', 1, 2]]
#     [sxdg] -> [1]   -----------  [['int', 1, 1]]
#     [u] -> [0]   -----------  [['float', 1, 1.0796925450229808], ['float', 1, 1.8924570113582482], ['float', 1, 0.3787122137064196], ['int', 1, 0]]
#  Profundidade:
#     [rz] -> [2]   -----------  [['float', 1, 0.01032952500265849], ['int', 1, 2]]
#     [rv] -> [1]   -----------  [['float', 1, 0.8804303205070048], ['float', 1, 0.18395925784369505], ['float', 1, 0.15159070654684115], ['int', 1, 1]]
#     [id] -> [0]   -----------  [['int', 1, 0]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.04404408+0.09174752j,  0.08855013-0.80388493j,
#               0.04975903+0.05248897j, -0.51132339-0.26246476j,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ],
#             dims=(2, 2, 2))
# Circuito = 3 x 7:
#     Depth 0:
#         [rz] -> [1]   -----------  [['float', 1, 1.0388711132053468], ['int', 1, 1]]
#         [ry] -> [0]   -----------  [['float', 1, 0.5570065093633096], ['int', 1, 0]]
#         [r] -> [2]   -----------  [['float', 1, 0.5073931325001004], ['float', 1, 0.4972576092262484], ['int', 1, 2]]
#     Depth 1:
#         [ry] -> [1]   -----------  [['float', 1, 1.473710296126428], ['int', 1, 1]]
#         [r] -> [0]   -----------  [['float', 1, 0.5667439300273645], ['float', 1, 0.7565984031859556], ['int', 1, 0]]
#         [id] -> [2]   -----------  [['int', 1, 2]]
#     Depth 2:
#         [y] -> [2]   -----------  [['int', 1, 2]]
#         [h] -> [1]   -----------  [['int', 1, 1]]
#         [rx] -> [0]   -----------  [['float', 1, 1.7276668864083338], ['int', 1, 0]]
#     Depth 3:
#         [s] -> [1]   -----------  [['int', 1, 1]]
#         [rv] -> [2]   -----------  [['float', 1, 0.4702491677455438], ['float', 1, 1.0978566708648583], ['float', 1, 0.5760763409625469], ['int', 1, 2]]
#         [ms] -> [0]   -----------  [['float', 1, 0.43999633790639625], ['list[int]', 1, [0]]]
#     Depth 4:
#         [h] -> [1]   -----------  [['int', 1, 1]]
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#         [rx] -> [2]   -----------  [['float', 1, 0.023343844723617835], ['int', 1, 2]]
#     Depth 5:
#         [id] -> [0]   -----------  [['int', 1, 0]]
#         [u] -> [1]   -----------  [['float', 1, 0.8305005886695878], ['float', 1, 1.706452553633202], ['float', 1, 0.6843045838268109], ['int', 1, 1]]
#         [rx] -> [2]   -----------  [['float', 1, 0.3893237718644911], ['int', 1, 2]]
#     Depth 6:
#         [r] -> [1]   -----------  [['float', 1, 0.8504688554951627], ['float', 1, 0.17503717893002246], ['int', 1, 1]]
#         [rv] -> [0]   -----------  [['float', 1, 1.011575028949873], ['float', 1, 0.28773618992316874], ['float', 1, 0.8830965079008382], ['int', 1, 0]]
#         [z] -> [2]   -----------  [['int', 1, 2]]
# Construindo Circuito:
#  Profundidade:
#     [rz] -> [1]   -----------  [['float', 1, 1.0388711132053468], ['int', 1, 1]]
#     [ry] -> [0]   -----------  [['float', 1, 0.5570065093633096], ['int', 1, 0]]
#     [r] -> [2]   -----------  [['float', 1, 0.5073931325001004], ['float', 1, 0.4972576092262484], ['int', 1, 2]]
#  Profundidade:
#     [ry] -> [1]   -----------  [['float', 1, 1.473710296126428], ['int', 1, 1]]
#     [r] -> [0]   -----------  [['float', 1, 0.5667439300273645], ['float', 1, 0.7565984031859556], ['int', 1, 0]]
#     [id] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [y] -> [2]   -----------  [['int', 1, 2]]
#     [h] -> [1]   -----------  [['int', 1, 1]]
#     [rx] -> [0]   -----------  [['float', 1, 1.7276668864083338], ['int', 1, 0]]
#  Profundidade:
#     [s] -> [1]   -----------  [['int', 1, 1]]
#     [rv] -> [2]   -----------  [['float', 1, 0.4702491677455438], ['float', 1, 1.0978566708648583], ['float', 1, 0.5760763409625469], ['int', 1, 2]]
#     [ms] -> [0]   -----------  [['float', 1, 0.43999633790639625], ['list[int]', 1, [0]]]
#  Profundidade:
#     [h] -> [1]   -----------  [['int', 1, 1]]
#     [sdg] -> [0]   -----------  [['int', 1, 0]]
#     [rx] -> [2]   -----------  [['float', 1, 0.023343844723617835], ['int', 1, 2]]
#  Profundidade:
#     [id] -> [0]   -----------  [['int', 1, 0]]
#     [u] -> [1]   -----------  [['float', 1, 0.8305005886695878], ['float', 1, 1.706452553633202], ['float', 1, 0.6843045838268109], ['int', 1, 1]]
#     [rx] -> [2]   -----------  [['float', 1, 0.3893237718644911], ['int', 1, 2]]
#  Profundidade:
#     [r] -> [1]   -----------  [['float', 1, 0.8504688554951627], ['float', 1, 0.17503717893002246], ['int', 1, 1]]
#     [rv] -> [0]   -----------  [['float', 1, 1.011575028949873], ['float', 1, 0.28773618992316874], ['float', 1, 0.8830965079008382], ['int', 1, 0]]
#     [z] -> [2]   -----------  [['int', 1, 2]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.08557665-0.18725428j,  0.4153516 +0.13539183j,
#              -0.04337711+0.1341978j , -0.14723695-0.26053388j,
#              -0.20629692+0.1968433j , -0.01099785-0.60494153j,
#               0.19528687-0.00403397j, -0.27426452+0.31074452j],
#             dims=(2, 2, 2))
# Circuito = 3 x 3:
#     Depth 0:
#         [x] -> [0]   -----------  [['int', 1, 0]]
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
#         [t] -> [2]   -----------  [['int', 1, 2]]
#     Depth 1:
#         [rz] -> [1]   -----------  [['float', 1, 1.5311040570280658], ['int', 1, 1]]
#         [z] -> [0]   -----------  [['int', 1, 0]]
#         [ry] -> [2]   -----------  [['float', 1, 0.09643819773452078], ['int', 1, 2]]
#     Depth 2:
#         [s] -> [1]   -----------  [['int', 1, 1]]
#         [x] -> [2]   -----------  [['int', 1, 2]]
#         [s] -> [0]   -----------  [['int', 1, 0]]
# Construindo Circuito:
#  Profundidade:
#     [x] -> [0]   -----------  [['int', 1, 0]]
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
#     [t] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [rz] -> [1]   -----------  [['float', 1, 1.5311040570280658], ['int', 1, 1]]
#     [z] -> [0]   -----------  [['int', 1, 0]]
#     [ry] -> [2]   -----------  [['float', 1, 0.09643819773452078], ['int', 1, 2]]
#  Profundidade:
#     [s] -> [1]   -----------  [['int', 1, 1]]
#     [x] -> [2]   -----------  [['int', 1, 2]]
#     [s] -> [0]   -----------  [['int', 1, 0]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.        +0.j        , -0.10136795+0.11179078j,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        , -0.66403623+0.73231362j,
#               0.        +0.j        ,  0.        +0.j        ],
#             dims=(2, 2, 2))
# Circuito = 3 x 8:
#     Depth 0:
#         [r] -> [1]   -----------  [['float', 1, 0.027061445248158345], ['float', 1, 0.40682330799177513], ['int', 1, 1]]
#         [rx] -> [2]   -----------  [['float', 1, 0.04481130205077499], ['int', 1, 2]]
#         [s] -> [0]   -----------  [['int', 1, 0]]
#     Depth 1:
#         [x] -> [2]   -----------  [['int', 1, 2]]
#         [ry] -> [1]   -----------  [['float', 1, 0.690841678155468], ['int', 1, 1]]
#         [sxdg] -> [0]   -----------  [['int', 1, 0]]
#     Depth 2:
#         [ms] -> [0]   -----------  [['float', 1, 0.07827617388106267], ['list[int]', 1, [0]]]
#         [rz] -> [2]   -----------  [['float', 1, 0.7127380005377371], ['int', 1, 2]]
#         [h] -> [1]   -----------  [['int', 1, 1]]
#     Depth 3:
#         [x] -> [2]   -----------  [['int', 1, 2]]
#         [r] -> [1]   -----------  [['float', 1, 1.5721954927068256], ['float', 1, 0.23647297562312608], ['int', 1, 1]]
#         [sx] -> [0]   -----------  [['int', 1, 0]]
#     Depth 4:
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#         [h] -> [1]   -----------  [['int', 1, 1]]
#         [ms] -> [2]   -----------  [['float', 1, 0.6826944668148809], ['list[int]', 1, [2]]]
#     Depth 5:
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
#         [r] -> [0]   -----------  [['float', 1, 1.8045417866790876], ['float', 1, 1.8157008144793458], ['int', 1, 0]]
#         [rv] -> [2]   -----------  [['float', 1, 1.6820293216697189], ['float', 1, 1.862795255399778], ['float', 1, 0.6143561983457901], ['int', 1, 2]]
#     Depth 6:
#         [t] -> [2]   -----------  [['int', 1, 2]]
#         [ms] -> [0, 1]   -----------  [['float', 1, 1.8259811855232642], ['list[int]', 2, [1, 0]]]
#     Depth 7:
#         [y] -> [2]   -----------  [['int', 1, 2]]
#         [sxdg] -> [1]   -----------  [['int', 1, 1]]
#         [rx] -> [0]   -----------  [['float', 1, 1.574877149587034], ['int', 1, 0]]
# Construindo Circuito:
#  Profundidade:
#     [r] -> [1]   -----------  [['float', 1, 0.027061445248158345], ['float', 1, 0.40682330799177513], ['int', 1, 1]]
#     [rx] -> [2]   -----------  [['float', 1, 0.04481130205077499], ['int', 1, 2]]
#     [s] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [x] -> [2]   -----------  [['int', 1, 2]]
#     [ry] -> [1]   -----------  [['float', 1, 0.690841678155468], ['int', 1, 1]]
#     [sxdg] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [ms] -> [0]   -----------  [['float', 1, 0.07827617388106267], ['list[int]', 1, [0]]]
#     [rz] -> [2]   -----------  [['float', 1, 0.7127380005377371], ['int', 1, 2]]
#     [h] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [x] -> [2]   -----------  [['int', 1, 2]]
#     [r] -> [1]   -----------  [['float', 1, 1.5721954927068256], ['float', 1, 0.23647297562312608], ['int', 1, 1]]
#     [sx] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [sdg] -> [0]   -----------  [['int', 1, 0]]
#     [h] -> [1]   -----------  [['int', 1, 1]]
#     [ms] -> [2]   -----------  [['float', 1, 0.6826944668148809], ['list[int]', 1, [2]]]
#  Profundidade:
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
#     [r] -> [0]   -----------  [['float', 1, 1.8045417866790876], ['float', 1, 1.8157008144793458], ['int', 1, 0]]
#     [rv] -> [2]   -----------  [['float', 1, 1.6820293216697189], ['float', 1, 1.862795255399778], ['float', 1, 0.6143561983457901], ['int', 1, 2]]
#  Profundidade:
#     [t] -> [2]   -----------  [['int', 1, 2]]
#     [ms] -> [0, 1]   -----------  [['float', 1, 1.8259811855232642], ['list[int]', 2, [1, 0]]]
#  Profundidade:
#     [y] -> [2]   -----------  [['int', 1, 2]]
#     [sxdg] -> [1]   -----------  [['int', 1, 1]]
#     [rx] -> [0]   -----------  [['float', 1, 1.574877149587034], ['int', 1, 0]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.37293446+0.10583633j, -0.34521492-0.21452024j,
#               0.30669073+0.09571961j, -0.16399586+0.28956879j,
#               0.30609852-0.19968004j,  0.3708282 +0.09647511j,
#              -0.30288932-0.00031187j,  0.06656958-0.30658953j],
#             dims=(2, 2, 2))
# Circuito = 3 x 10:
#     Depth 0:
#         [ms] -> [1, 2, 0]   -----------  [['float', 1, 0.21291450232766795], ['list[int]', 3, [1, 0, 2]]]
#     Depth 1:
#         [sx] -> [1]   -----------  [['int', 1, 1]]
#         [sx] -> [2]   -----------  [['int', 1, 2]]
#         [p] -> [0]   -----------  [['float', 1, 0.5520088239810035], ['int', 1, 0]]
#     Depth 2:
#         [s] -> [0]   -----------  [['int', 1, 0]]
#         [rv] -> [2]   -----------  [['float', 1, 1.2785170180167658], ['float', 1, 0.28483350919341177], ['float', 1, 1.0253917075891086], ['int', 1, 2]]
#         [s] -> [1]   -----------  [['int', 1, 1]]
#     Depth 3:
#         [ms] -> [1, 0]   -----------  [['float', 1, 1.3279127272372406], ['list[int]', 2, [1, 0]]]
#         [p] -> [2]   -----------  [['float', 1, 0.4048654354385812], ['int', 1, 2]]
#     Depth 4:
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#         [tdg] -> [2]   -----------  [['int', 1, 2]]
#         [u] -> [0]   -----------  [['float', 1, 0.19434906067727664], ['float', 1, 1.2493602607390393], ['float', 1, 0.19966425824444345], ['int', 1, 0]]
#     Depth 5:
#         [rv] -> [1]   -----------  [['float', 1, 0.716428174403752], ['float', 1, 0.06990484110677886], ['float', 1, 0.2346362638177859], ['int', 1, 1]]
#         [ms] -> [0, 2]   -----------  [['float', 1, 1.3293817025935357], ['list[int]', 2, [2, 0]]]
#     Depth 6:
#         [rx] -> [1]   -----------  [['float', 1, 0.9341909824258603], ['int', 1, 1]]
#         [s] -> [0]   -----------  [['int', 1, 0]]
#         [tdg] -> [2]   -----------  [['int', 1, 2]]
#     Depth 7:
#         [id] -> [1]   -----------  [['int', 1, 1]]
#         [s] -> [0]   -----------  [['int', 1, 0]]
#         [r] -> [2]   -----------  [['float', 1, 0.25087327058449005], ['float', 1, 1.4943445942239144], ['int', 1, 2]]
#     Depth 8:
#         [ms] -> [0]   -----------  [['float', 1, 1.044037924292356], ['list[int]', 1, [0]]]
#         [rz] -> [1]   -----------  [['float', 1, 0.6029853448702172], ['int', 1, 1]]
#         [x] -> [2]   -----------  [['int', 1, 2]]
#     Depth 9:
#         [rz] -> [1]   -----------  [['float', 1, 0.9862217340588211], ['int', 1, 1]]
#         [r] -> [2]   -----------  [['float', 1, 1.599542913743466], ['float', 1, 1.5673439737331902], ['int', 1, 2]]
#         [ry] -> [0]   -----------  [['float', 1, 1.3364257351565196], ['int', 1, 0]]
# Construindo Circuito:
#  Profundidade:
#     [ms] -> [1, 2, 0]   -----------  [['float', 1, 0.21291450232766795], ['list[int]', 3, [1, 0, 2]]]
#  Profundidade:
#     [sx] -> [1]   -----------  [['int', 1, 1]]
#     [sx] -> [2]   -----------  [['int', 1, 2]]
#     [p] -> [0]   -----------  [['float', 1, 0.5520088239810035], ['int', 1, 0]]
#  Profundidade:
#     [s] -> [0]   -----------  [['int', 1, 0]]
#     [rv] -> [2]   -----------  [['float', 1, 1.2785170180167658], ['float', 1, 0.28483350919341177], ['float', 1, 1.0253917075891086], ['int', 1, 2]]
#     [s] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [ms] -> [1, 0]   -----------  [['float', 1, 1.3279127272372406], ['list[int]', 2, [1, 0]]]
#     [p] -> [2]   -----------  [['float', 1, 0.4048654354385812], ['int', 1, 2]]
#  Profundidade:
#     [sdg] -> [1]   -----------  [['int', 1, 1]]
#     [tdg] -> [2]   -----------  [['int', 1, 2]]
#     [u] -> [0]   -----------  [['float', 1, 0.19434906067727664], ['float', 1, 1.2493602607390393], ['float', 1, 0.19966425824444345], ['int', 1, 0]]
#  Profundidade:
#     [rv] -> [1]   -----------  [['float', 1, 0.716428174403752], ['float', 1, 0.06990484110677886], ['float', 1, 0.2346362638177859], ['int', 1, 1]]
#     [ms] -> [0, 2]   -----------  [['float', 1, 1.3293817025935357], ['list[int]', 2, [2, 0]]]
#  Profundidade:
#     [rx] -> [1]   -----------  [['float', 1, 0.9341909824258603], ['int', 1, 1]]
#     [s] -> [0]   -----------  [['int', 1, 0]]
#     [tdg] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [id] -> [1]   -----------  [['int', 1, 1]]
#     [s] -> [0]   -----------  [['int', 1, 0]]
#     [r] -> [2]   -----------  [['float', 1, 0.25087327058449005], ['float', 1, 1.4943445942239144], ['int', 1, 2]]
#  Profundidade:
#     [ms] -> [0]   -----------  [['float', 1, 1.044037924292356], ['list[int]', 1, [0]]]
#     [rz] -> [1]   -----------  [['float', 1, 0.6029853448702172], ['int', 1, 1]]
#     [x] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [rz] -> [1]   -----------  [['float', 1, 0.9862217340588211], ['int', 1, 1]]
#     [r] -> [2]   -----------  [['float', 1, 1.599542913743466], ['float', 1, 1.5673439737331902], ['int', 1, 2]]
#     [ry] -> [0]   -----------  [['float', 1, 1.3364257351565196], ['int', 1, 0]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.08474168-0.31903863j,  0.04985885-0.45302344j,
#              -0.20138416+0.09556265j, -0.10441215+0.26705218j,
#               0.03340439+0.2822513j , -0.52131399+0.13615171j,
#               0.17900833+0.21245381j,  0.2488241 +0.20304987j],
#             dims=(2, 2, 2))
# Circuito = 3 x 1:
#     Depth 0:
#         [ry] -> [2]   -----------  [['float', 1, 0.35469583172708274], ['int', 1, 2]]
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#         [sxdg] -> [1]   -----------  [['int', 1, 1]]
# Construindo Circuito:
#  Profundidade:
#     [ry] -> [2]   -----------  [['float', 1, 0.35469583172708274], ['int', 1, 2]]
#     [sdg] -> [0]   -----------  [['int', 1, 0]]
#     [sxdg] -> [1]   -----------  [['int', 1, 1]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([0.42438148-0.42438148j, 0.        +0.j        ,
#              0.42438148+0.42438148j, 0.        +0.j        ,
#              0.26438677-0.26438677j, 0.        +0.j        ,
#              0.26438677+0.26438677j, 0.        +0.j        ],
#             dims=(2, 2, 2))
# Circuito = 3 x 8:
#     Depth 0:
#         [y] -> [2]   -----------  [['int', 1, 2]]
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#         [ry] -> [1]   -----------  [['float', 1, 1.0789322920296682], ['int', 1, 1]]
#     Depth 1:
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#         [id] -> [1]   -----------  [['int', 1, 1]]
#         [id] -> [2]   -----------  [['int', 1, 2]]
#     Depth 2:
#         [h] -> [2]   -----------  [['int', 1, 2]]
#         [y] -> [1]   -----------  [['int', 1, 1]]
#         [sx] -> [0]   -----------  [['int', 1, 0]]
#     Depth 3:
#         [y] -> [2]   -----------  [['int', 1, 2]]
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#         [ry] -> [0]   -----------  [['float', 1, 0.5205821551653651], ['int', 1, 0]]
#     Depth 4:
#         [rv] -> [2]   -----------  [['float', 1, 1.820395648622082], ['float', 1, 1.0199663548843505], ['float', 1, 1.6290900130741044], ['int', 1, 2]]
#         [r] -> [0]   -----------  [['float', 1, 0.4454204870082936], ['float', 1, 1.8527876542661377], ['int', 1, 0]]
#         [rv] -> [1]   -----------  [['float', 1, 0.09399087151714158], ['float', 1, 1.4114489685127758], ['float', 1, 0.040851567712796744], ['int', 1, 1]]
#     Depth 5:
#         [t] -> [0]   -----------  [['int', 1, 0]]
#         [s] -> [2]   -----------  [['int', 1, 2]]
#         [id] -> [1]   -----------  [['int', 1, 1]]
#     Depth 6:
#         [sxdg] -> [0]   -----------  [['int', 1, 0]]
#         [sdg] -> [1]   -----------  [['int', 1, 1]]
#         [h] -> [2]   -----------  [['int', 1, 2]]
#     Depth 7:
#         [rv] -> [0]   -----------  [['float', 1, 0.6621720591250806], ['float', 1, 1.7158705456914893], ['float', 1, 1.9743173490856858], ['int', 1, 0]]
#         [rv] -> [2]   -----------  [['float', 1, 1.7391802218286212], ['float', 1, 1.409954341936041], ['float', 1, 0.0817778793169146], ['int', 1, 2]]
#         [sx] -> [1]   -----------  [['int', 1, 1]]
# Construindo Circuito:
#  Profundidade:
#     [y] -> [2]   -----------  [['int', 1, 2]]
#     [sdg] -> [0]   -----------  [['int', 1, 0]]
#     [ry] -> [1]   -----------  [['float', 1, 1.0789322920296682], ['int', 1, 1]]
#  Profundidade:
#     [sdg] -> [0]   -----------  [['int', 1, 0]]
#     [id] -> [1]   -----------  [['int', 1, 1]]
#     [id] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [h] -> [2]   -----------  [['int', 1, 2]]
#     [y] -> [1]   -----------  [['int', 1, 1]]
#     [sx] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [y] -> [2]   -----------  [['int', 1, 2]]
#     [sdg] -> [1]   -----------  [['int', 1, 1]]
#     [ry] -> [0]   -----------  [['float', 1, 0.5205821551653651], ['int', 1, 0]]
#  Profundidade:
#     [rv] -> [2]   -----------  [['float', 1, 1.820395648622082], ['float', 1, 1.0199663548843505], ['float', 1, 1.6290900130741044], ['int', 1, 2]]
#     [r] -> [0]   -----------  [['float', 1, 0.4454204870082936], ['float', 1, 1.8527876542661377], ['int', 1, 0]]
#     [rv] -> [1]   -----------  [['float', 1, 0.09399087151714158], ['float', 1, 1.4114489685127758], ['float', 1, 0.040851567712796744], ['int', 1, 1]]
#  Profundidade:
#     [t] -> [0]   -----------  [['int', 1, 0]]
#     [s] -> [2]   -----------  [['int', 1, 2]]
#     [id] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [sxdg] -> [0]   -----------  [['int', 1, 0]]
#     [sdg] -> [1]   -----------  [['int', 1, 1]]
#     [h] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [rv] -> [0]   -----------  [['float', 1, 0.6621720591250806], ['float', 1, 1.7158705456914893], ['float', 1, 1.9743173490856858], ['int', 1, 0]]
#     [rv] -> [2]   -----------  [['float', 1, 1.7391802218286212], ['float', 1, 1.409954341936041], ['float', 1, 0.0817778793169146], ['int', 1, 2]]
#     [sx] -> [1]   -----------  [['int', 1, 1]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.00504314-0.03524276j,  0.18019545-0.06868409j,
#               0.0048326 +0.0019986j , -0.00479556+0.02791778j,
#               0.16281039+0.06700022j, -0.15980542+0.94015393j,
#              -0.02064831+0.01557082j, -0.10690045-0.0905258j ],
#             dims=(2, 2, 2))
# Circuito = 3 x 5:
#     Depth 0:
#         [x] -> [0]   -----------  [['int', 1, 0]]
#         [z] -> [1]   -----------  [['int', 1, 1]]
#         [t] -> [2]   -----------  [['int', 1, 2]]
#     Depth 1:
#         [y] -> [1]   -----------  [['int', 1, 1]]
#         [s] -> [2]   -----------  [['int', 1, 2]]
#         [s] -> [0]   -----------  [['int', 1, 0]]
#     Depth 2:
#         [tdg] -> [0]   -----------  [['int', 1, 0]]
#         [tdg] -> [2]   -----------  [['int', 1, 2]]
#         [rv] -> [1]   -----------  [['float', 1, 0.9271598377243471], ['float', 1, 0.3667325844115956], ['float', 1, 1.2151776298919001], ['int', 1, 1]]
#     Depth 3:
#         [rz] -> [2]   -----------  [['float', 1, 1.8596401758387304], ['int', 1, 2]]
#         [rv] -> [0]   -----------  [['float', 1, 0.2521992024689408], ['float', 1, 0.5232909459785577], ['float', 1, 0.351317839644691], ['int', 1, 0]]
#         [s] -> [1]   -----------  [['int', 1, 1]]
#     Depth 4:
#         [y] -> [2]   -----------  [['int', 1, 2]]
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
#         [rx] -> [0]   -----------  [['float', 1, 1.270838935618297], ['int', 1, 0]]
# Construindo Circuito:
#  Profundidade:
#     [x] -> [0]   -----------  [['int', 1, 0]]
#     [z] -> [1]   -----------  [['int', 1, 1]]
#     [t] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [y] -> [1]   -----------  [['int', 1, 1]]
#     [s] -> [2]   -----------  [['int', 1, 2]]
#     [s] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [tdg] -> [0]   -----------  [['int', 1, 0]]
#     [tdg] -> [2]   -----------  [['int', 1, 2]]
#     [rv] -> [1]   -----------  [['float', 1, 0.9271598377243471], ['float', 1, 0.3667325844115956], ['float', 1, 1.2151776298919001], ['int', 1, 1]]
#  Profundidade:
#     [rz] -> [2]   -----------  [['float', 1, 1.8596401758387304], ['int', 1, 2]]
#     [rv] -> [0]   -----------  [['float', 1, 0.2521992024689408], ['float', 1, 0.5232909459785577], ['float', 1, 0.351317839644691], ['int', 1, 0]]
#     [s] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [y] -> [2]   -----------  [['int', 1, 2]]
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
#     [rx] -> [0]   -----------  [['float', 1, 1.270838935618297], ['int', 1, 0]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.06297147-0.29196766j,  0.02135796+0.25781992j,
#              -0.47236665-0.50893699j,  0.51965308+0.30278007j],
#             dims=(2, 2, 2))
# Circuito = 3 x 10:
#     Depth 0:
#         [id] -> [2]   -----------  [['int', 1, 2]]
#         [sxdg] -> [1]   -----------  [['int', 1, 1]]
#         [sxdg] -> [0]   -----------  [['int', 1, 0]]
#     Depth 1:
#         [sdg] -> [2]   -----------  [['int', 1, 2]]
#         [h] -> [1]   -----------  [['int', 1, 1]]
#         [h] -> [0]   -----------  [['int', 1, 0]]
#     Depth 2:
#         [ms] -> [1, 0, 2]   -----------  [['float', 1, 1.1577874439055869], ['list[int]', 3, [1, 0, 2]]]
#     Depth 3:
#         [t] -> [2]   -----------  [['int', 1, 2]]
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#         [p] -> [1]   -----------  [['float', 1, 1.9423681710302225], ['int', 1, 1]]
#     Depth 4:
#         [rz] -> [1]   -----------  [['float', 1, 1.6264446255614955], ['int', 1, 1]]
#         [h] -> [0]   -----------  [['int', 1, 0]]
#         [sdg] -> [2]   -----------  [['int', 1, 2]]
#     Depth 5:
#         [r] -> [2]   -----------  [['float', 1, 0.9934533093372895], ['float', 1, 1.1863524834041064], ['int', 1, 2]]
#         [t] -> [1]   -----------  [['int', 1, 1]]
# ...
#     [u] -> [2]   -----------  [['float', 1, 1.5858030846103441], ['float', 1, 0.5720683434772078], ['float', 1, 0.26517255043280263], ['int', 1, 2]]
#     [rz] -> [1]   -----------  [['float', 1, 1.0887549666474845], ['int', 1, 1]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.02265869+0.01710766j, -0.11012904-0.78539844j,
#              -0.03714014-0.00344422j,  0.01707496+0.02268334j,
#              -0.02858382+0.02396285j, -0.60139115-0.05251227j,
#              -0.0089009 +0.02696038j, -0.03407521+0.01517014j],
#             dims=(2, 2, 2))
# Circuito = 3 x 4:
#     Depth 0:
#         [y] -> [2]   -----------  [['int', 1, 2]]
#         [ms] -> [1, 0]   -----------  [['float', 1, 1.6632441904425366], ['list[int]', 2, [1, 0]]]
#     Depth 1:
#         [r] -> [1]   -----------  [['float', 1, 1.2152929359951854], ['float', 1, 0.478612225694071], ['int', 1, 1]]
#         [tdg] -> [0]   -----------  [['int', 1, 0]]
#         [rz] -> [2]   -----------  [['float', 1, 1.4178515220695875], ['int', 1, 2]]
#     Depth 2:
#         [x] -> [2]   -----------  [['int', 1, 2]]
#         [h] -> [1]   -----------  [['int', 1, 1]]
#         [u] -> [0]   -----------  [['float', 1, 1.2005720291630522], ['float', 1, 1.8587218658149833], ['float', 1, 1.4323026473407483], ['int', 1, 0]]
#     Depth 3:
#         [rz] -> [0]   -----------  [['float', 1, 0.6589564062474167], ['int', 1, 0]]
#         [z] -> [1]   -----------  [['int', 1, 1]]
#         [u] -> [2]   -----------  [['float', 1, 1.0436015145984083], ['float', 1, 0.9143713701590102], ['float', 1, 1.0039641534221508], ['int', 1, 2]]
# Construindo Circuito:
#  Profundidade:
#     [y] -> [2]   -----------  [['int', 1, 2]]
#     [ms] -> [1, 0]   -----------  [['float', 1, 1.6632441904425366], ['list[int]', 2, [1, 0]]]
#  Profundidade:
#     [r] -> [1]   -----------  [['float', 1, 1.2152929359951854], ['float', 1, 0.478612225694071], ['int', 1, 1]]
#     [tdg] -> [0]   -----------  [['int', 1, 0]]
#     [rz] -> [2]   -----------  [['float', 1, 1.4178515220695875], ['int', 1, 2]]
#  Profundidade:
#     [x] -> [2]   -----------  [['int', 1, 2]]
#     [h] -> [1]   -----------  [['int', 1, 1]]
#     [u] -> [0]   -----------  [['float', 1, 1.2005720291630522], ['float', 1, 1.8587218658149833], ['float', 1, 1.4323026473407483], ['int', 1, 0]]
#  Profundidade:
#     [rz] -> [0]   -----------  [['float', 1, 0.6589564062474167], ['int', 1, 0]]
#     [z] -> [1]   -----------  [['int', 1, 1]]
#     [u] -> [2]   -----------  [['float', 1, 1.0436015145984083], ['float', 1, 0.9143713701590102], ['float', 1, 1.0039641534221508], ['int', 1, 2]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-1.13525647e-04+0.02504034j, -1.92903744e-02-0.02499934j,
#               1.91798281e-02-0.02045686j, -1.40939136e-02-0.04554473j,
#               9.54236064e-02+0.35234978j, -3.67961740e-01-0.27659302j,
#               1.90287590e-01-0.36180747j, -3.74535436e-01-0.58546579j],
#             dims=(2, 2, 2))
# Circuito = 3 x 10:
#     Depth 0:
#         [tdg] -> [2]   -----------  [['int', 1, 2]]
#         [p] -> [0]   -----------  [['float', 1, 1.3291032995701912], ['int', 1, 0]]
#         [r] -> [1]   -----------  [['float', 1, 0.02273115144557658], ['float', 1, 1.184689368839497], ['int', 1, 1]]
#     Depth 1:
#         [h] -> [1]   -----------  [['int', 1, 1]]
#         [id] -> [2]   -----------  [['int', 1, 2]]
#         [rz] -> [0]   -----------  [['float', 1, 1.856229607895664], ['int', 1, 0]]
#     Depth 2:
#         [h] -> [0]   -----------  [['int', 1, 0]]
#         [rv] -> [2]   -----------  [['float', 1, 0.6251277368302806], ['float', 1, 1.0850522306005037], ['float', 1, 0.8605230966743376], ['int', 1, 2]]
#         [r] -> [1]   -----------  [['float', 1, 0.3630717857336878], ['float', 1, 0.08202170924339103], ['int', 1, 1]]
#     Depth 3:
#         [z] -> [1]   -----------  [['int', 1, 1]]
#         [u] -> [0]   -----------  [['float', 1, 0.5713551543000313], ['float', 1, 0.8380986591450674], ['float', 1, 1.443838436411763], ['int', 1, 0]]
#         [s] -> [2]   -----------  [['int', 1, 2]]
#     Depth 4:
#         [y] -> [0]   -----------  [['int', 1, 0]]
#         [rv] -> [1]   -----------  [['float', 1, 1.706520778087997], ['float', 1, 0.21808097038019558], ['float', 1, 1.4301866035293387], ['int', 1, 1]]
#         [rv] -> [2]   -----------  [['float', 1, 0.0003333031350061244], ['float', 1, 0.5415844326267749], ['float', 1, 1.0353682826641157], ['int', 1, 2]]
#     Depth 5:
#         [id] -> [2]   -----------  [['int', 1, 2]]
#         [r] -> [1]   -----------  [['float', 1, 1.3348060435416718], ['float', 1, 0.2445286746005193], ['int', 1, 1]]
#         [ry] -> [0]   -----------  [['float', 1, 1.4397088282964543], ['int', 1, 0]]
#     Depth 6:
#         [rv] -> [1]   -----------  [['float', 1, 1.8925046202391955], ['float', 1, 1.1781947181463557], ['float', 1, 1.4122471098770457], ['int', 1, 1]]
#         [s] -> [0]   -----------  [['int', 1, 0]]
#         [rz] -> [2]   -----------  [['float', 1, 1.7642180637126386], ['int', 1, 2]]
#     Depth 7:
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
#         [r] -> [2]   -----------  [['float', 1, 1.1470615207343984], ['float', 1, 0.5623001482704817], ['int', 1, 2]]
#         [u] -> [0]   -----------  [['float', 1, 0.22866700276474328], ['float', 1, 1.2140212796205538], ['float', 1, 1.0924755382025748], ['int', 1, 0]]
#     Depth 8:
#         [tdg] -> [1]   -----------  [['int', 1, 1]]
#         [tdg] -> [2]   -----------  [['int', 1, 2]]
#         [rx] -> [0]   -----------  [['float', 1, 0.8954760369346875], ['int', 1, 0]]
#     Depth 9:
#         [sx] -> [1]   -----------  [['int', 1, 1]]
#         [id] -> [0]   -----------  [['int', 1, 0]]
#         [y] -> [2]   -----------  [['int', 1, 2]]
# Construindo Circuito:
#  Profundidade:
#     [tdg] -> [2]   -----------  [['int', 1, 2]]
#     [p] -> [0]   -----------  [['float', 1, 1.3291032995701912], ['int', 1, 0]]
#     [r] -> [1]   -----------  [['float', 1, 0.02273115144557658], ['float', 1, 1.184689368839497], ['int', 1, 1]]
#  Profundidade:
#     [h] -> [1]   -----------  [['int', 1, 1]]
#     [id] -> [2]   -----------  [['int', 1, 2]]
#     [rz] -> [0]   -----------  [['float', 1, 1.856229607895664], ['int', 1, 0]]
#  Profundidade:
#     [h] -> [0]   -----------  [['int', 1, 0]]
#     [rv] -> [2]   -----------  [['float', 1, 0.6251277368302806], ['float', 1, 1.0850522306005037], ['float', 1, 0.8605230966743376], ['int', 1, 2]]
#     [r] -> [1]   -----------  [['float', 1, 0.3630717857336878], ['float', 1, 0.08202170924339103], ['int', 1, 1]]
#  Profundidade:
#     [z] -> [1]   -----------  [['int', 1, 1]]
#     [u] -> [0]   -----------  [['float', 1, 0.5713551543000313], ['float', 1, 0.8380986591450674], ['float', 1, 1.443838436411763], ['int', 1, 0]]
#     [s] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [y] -> [0]   -----------  [['int', 1, 0]]
#     [rv] -> [1]   -----------  [['float', 1, 1.706520778087997], ['float', 1, 0.21808097038019558], ['float', 1, 1.4301866035293387], ['int', 1, 1]]
#     [rv] -> [2]   -----------  [['float', 1, 0.0003333031350061244], ['float', 1, 0.5415844326267749], ['float', 1, 1.0353682826641157], ['int', 1, 2]]
#  Profundidade:
#     [id] -> [2]   -----------  [['int', 1, 2]]
#     [r] -> [1]   -----------  [['float', 1, 1.3348060435416718], ['float', 1, 0.2445286746005193], ['int', 1, 1]]
#     [ry] -> [0]   -----------  [['float', 1, 1.4397088282964543], ['int', 1, 0]]
#  Profundidade:
#     [rv] -> [1]   -----------  [['float', 1, 1.8925046202391955], ['float', 1, 1.1781947181463557], ['float', 1, 1.4122471098770457], ['int', 1, 1]]
#     [s] -> [0]   -----------  [['int', 1, 0]]
#     [rz] -> [2]   -----------  [['float', 1, 1.7642180637126386], ['int', 1, 2]]
#  Profundidade:
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
#     [r] -> [2]   -----------  [['float', 1, 1.1470615207343984], ['float', 1, 0.5623001482704817], ['int', 1, 2]]
#     [u] -> [0]   -----------  [['float', 1, 0.22866700276474328], ['float', 1, 1.2140212796205538], ['float', 1, 1.0924755382025748], ['int', 1, 0]]
#  Profundidade:
#     [tdg] -> [1]   -----------  [['int', 1, 1]]
#     [tdg] -> [2]   -----------  [['int', 1, 2]]
#     [rx] -> [0]   -----------  [['float', 1, 0.8954760369346875], ['int', 1, 0]]
#  Profundidade:
#     [sx] -> [1]   -----------  [['int', 1, 1]]
#     [id] -> [0]   -----------  [['int', 1, 0]]
#     [y] -> [2]   -----------  [['int', 1, 2]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.08056943-0.25227618j,  0.0634476 +0.07102737j,
#               0.21334104+0.09636801j, -0.0688125 +0.0485j    ,
#               0.60877488-0.23735425j, -0.03762564+0.23194987j,
#               0.14659578+0.55866902j, -0.19985373-0.05659487j],
#             dims=(2, 2, 2))
# Circuito = 3 x 4:
#     Depth 0:
#         [u] -> [0]   -----------  [['float', 1, 1.0214453242016246], ['float', 1, 1.422870649402807], ['float', 1, 0.5104406485382906], ['int', 1, 0]]
#         [t] -> [1]   -----------  [['int', 1, 1]]
#         [u] -> [2]   -----------  [['float', 1, 0.13867652112652995], ['float', 1, 0.33631095475177175], ['float', 1, 1.1389847490790839], ['int', 1, 2]]
#     Depth 1:
#         [r] -> [1]   -----------  [['float', 1, 0.9805983011742001], ['float', 1, 0.222374754813784], ['int', 1, 1]]
#         [x] -> [0]   -----------  [['int', 1, 0]]
#         [sdg] -> [2]   -----------  [['int', 1, 2]]
#     Depth 2:
#         [sxdg] -> [1]   -----------  [['int', 1, 1]]
#         [sdg] -> [2]   -----------  [['int', 1, 2]]
#         [h] -> [0]   -----------  [['int', 1, 0]]
#     Depth 3:
#         [ms] -> [0, 1, 2]   -----------  [['float', 1, 0.7838383303707004], ['list[int]', 3, [2, 1, 0]]]
# Construindo Circuito:
#  Profundidade:
#     [u] -> [0]   -----------  [['float', 1, 1.0214453242016246], ['float', 1, 1.422870649402807], ['float', 1, 0.5104406485382906], ['int', 1, 0]]
#     [t] -> [1]   -----------  [['int', 1, 1]]
#     [u] -> [2]   -----------  [['float', 1, 0.13867652112652995], ['float', 1, 0.33631095475177175], ['float', 1, 1.1389847490790839], ['int', 1, 2]]
#  Profundidade:
#     [r] -> [1]   -----------  [['float', 1, 0.9805983011742001], ['float', 1, 0.222374754813784], ['int', 1, 1]]
#     [x] -> [0]   -----------  [['int', 1, 0]]
#     [sdg] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [sxdg] -> [1]   -----------  [['int', 1, 1]]
#     [sdg] -> [2]   -----------  [['int', 1, 2]]
#     [h] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [ms] -> [0, 1, 2]   -----------  [['float', 1, 0.7838383303707004], ['list[int]', 3, [2, 1, 0]]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.54700533-0.20992313j,  0.55546009-0.19450104j,
#              -0.13996922-0.26611258j, -0.10443312-0.26386431j,
#               0.05734647+0.07042814j,  0.06766047+0.07926571j,
#               0.12957414+0.22108344j,  0.11787604+0.20184423j],
#             dims=(2, 2, 2))
# Circuito = 3 x 7:
#     Depth 0:
#         [r] -> [2]   -----------  [['float', 1, 1.608627959825496], ['float', 1, 1.7915686248314258], ['int', 1, 2]]
#         [sxdg] -> [0]   -----------  [['int', 1, 0]]
#         [ms] -> [1]   -----------  [['float', 1, 0.6817235316032701], ['list[int]', 1, [1]]]
#     Depth 1:
#         [rv] -> [0]   -----------  [['float', 1, 1.9285544450820167], ['float', 1, 1.5760310467260392], ['float', 1, 0.794399391855255], ['int', 1, 0]]
#         [r] -> [2]   -----------  [['float', 1, 0.03952067416834071], ['float', 1, 0.3288564586166711], ['int', 1, 2]]
#         [h] -> [1]   -----------  [['int', 1, 1]]
#     Depth 2:
#         [sxdg] -> [2]   -----------  [['int', 1, 2]]
#         [x] -> [0]   -----------  [['int', 1, 0]]
#         [ry] -> [1]   -----------  [['float', 1, 0.2724683066393201], ['int', 1, 1]]
#     Depth 3:
#         [r] -> [0]   -----------  [['float', 1, 0.317586345180779], ['float', 1, 1.1646715720163847], ['int', 1, 0]]
#         [r] -> [1]   -----------  [['float', 1, 1.8310939623706917], ['float', 1, 0.7511039593451181], ['int', 1, 1]]
#         [h] -> [2]   -----------  [['int', 1, 2]]
#     Depth 4:
#         [rx] -> [2]   -----------  [['float', 1, 0.35755688349985437], ['int', 1, 2]]
#         [h] -> [1]   -----------  [['int', 1, 1]]
#         [sdg] -> [0]   -----------  [['int', 1, 0]]
#     Depth 5:
#         [rv] -> [1]   -----------  [['float', 1, 0.5735772140935405], ['float', 1, 0.9364135256287947], ['float', 1, 1.8764914713792336], ['int', 1, 1]]
#         [sxdg] -> [2]   -----------  [['int', 1, 2]]
#         [ms] -> [0]   -----------  [['float', 1, 0.6833113229381638], ['list[int]', 1, [0]]]
#     Depth 6:
#         [t] -> [0]   -----------  [['int', 1, 0]]
#         [r] -> [1]   -----------  [['float', 1, 1.6157300722968224], ['float', 1, 0.7617733522850063], ['int', 1, 1]]
#         [t] -> [2]   -----------  [['int', 1, 2]]
# Construindo Circuito:
#  Profundidade:
#     [r] -> [2]   -----------  [['float', 1, 1.608627959825496], ['float', 1, 1.7915686248314258], ['int', 1, 2]]
#     [sxdg] -> [0]   -----------  [['int', 1, 0]]
#     [ms] -> [1]   -----------  [['float', 1, 0.6817235316032701], ['list[int]', 1, [1]]]
#  Profundidade:
#     [rv] -> [0]   -----------  [['float', 1, 1.9285544450820167], ['float', 1, 1.5760310467260392], ['float', 1, 0.794399391855255], ['int', 1, 0]]
#     [r] -> [2]   -----------  [['float', 1, 0.03952067416834071], ['float', 1, 0.3288564586166711], ['int', 1, 2]]
#     [h] -> [1]   -----------  [['int', 1, 1]]
#  Profundidade:
#     [sxdg] -> [2]   -----------  [['int', 1, 2]]
#     [x] -> [0]   -----------  [['int', 1, 0]]
#     [ry] -> [1]   -----------  [['float', 1, 0.2724683066393201], ['int', 1, 1]]
#  Profundidade:
#     [r] -> [0]   -----------  [['float', 1, 0.317586345180779], ['float', 1, 1.1646715720163847], ['int', 1, 0]]
#     [r] -> [1]   -----------  [['float', 1, 1.8310939623706917], ['float', 1, 0.7511039593451181], ['int', 1, 1]]
#     [h] -> [2]   -----------  [['int', 1, 2]]
#  Profundidade:
#     [rx] -> [2]   -----------  [['float', 1, 0.35755688349985437], ['int', 1, 2]]
#     [h] -> [1]   -----------  [['int', 1, 1]]
#     [sdg] -> [0]   -----------  [['int', 1, 0]]
#  Profundidade:
#     [rv] -> [1]   -----------  [['float', 1, 0.5735772140935405], ['float', 1, 0.9364135256287947], ['float', 1, 1.8764914713792336], ['int', 1, 1]]
#     [sxdg] -> [2]   -----------  [['int', 1, 2]]
#     [ms] -> [0]   -----------  [['float', 1, 0.6833113229381638], ['list[int]', 1, [0]]]
#  Profundidade:
#     [t] -> [0]   -----------  [['int', 1, 0]]
#     [r] -> [1]   -----------  [['float', 1, 1.6157300722968224], ['float', 1, 0.7617733522850063], ['int', 1, 1]]
#     [t] -> [2]   -----------  [['int', 1, 2]]
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.01993385+3.84768612e-01j,  0.51099172-2.59277588e-04j,
#               0.36497134-1.54949922e-01j, -0.230514  -4.72653235e-01j,
#               0.12691129-1.07123155e-01j, -0.15067405-1.60666250e-01j,
#              -0.15630196-6.91443102e-02j, -0.08074859+2.11806687e-01j],
#             dims=(2, 2, 2))

# %%
generations(population, 1, svTarget)
# Out:
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.28260467+0.09899587j, -0.25273124-0.08853126j,
#              -0.0386243 +0.0266162j ,  0.03454142-0.02380266j,
#               0.22242756-0.63496657j, -0.1989153 +0.56784585j,
#               0.05980225+0.0867825j , -0.0534807 -0.07760894j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([0.42438148-0.42438148j, 0.        +0.j        ,
#              0.42438148+0.42438148j, 0.        +0.j        ,
#              0.26438677-0.26438677j, 0.        +0.j        ,
#              0.26438677+0.26438677j, 0.        +0.j        ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.13865971+0.76711342j,  0.37672381+0.02900057j,
#               0.13369293-0.42918763j, -0.21354022-0.04328248j,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.1739449 -0.0178421j ,  0.08447631-0.11109274j,
#              -0.09641182-0.09860543j, -0.06326595+0.11505451j,
#               0.29119755-0.59768723j,  0.00204132-0.13128578j,
#              -0.15440042+0.64117478j, -0.12665584+0.05861862j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.26717322-0.26838555j, -0.07151732-0.07272964j,
#               0.26838555-0.26717322j,  0.07272964-0.07151732j,
#              -0.23188121+0.22982335j,  0.34714564-0.34508778j,
#              -0.22982335-0.23188121j,  0.34508778+0.34714564j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.49971935+0.19401622j,  0.        +0.j        ,
#              -0.60964252+0.58393002j,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        ,  0.        +0.j        ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.06241832-0.00975792j, -0.00975792+0.06241832j,
#               0.02835463-0.18137561j, -0.18137561-0.02835463j,
#               0.21246582-0.06174358j, -0.06174358-0.21246582j,
#               0.17941494+0.61738475j,  0.61738475-0.17941494j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([0.32182364+0.01525903j, 0.01525903-0.32182364j,
#              0.28311318+0.25698956j, 0.25698956-0.28311318j,
#              0.29684117+0.1252542j , 0.1252542 -0.29684117j,
#              0.17718027+0.33882718j, 0.33882718-0.17718027j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.28260467+0.09899587j, -0.25273124-0.08853126j,
#              -0.0386243 +0.0266162j ,  0.03454142-0.02380266j,
#               0.22242756-0.63496657j, -0.1989153 +0.56784585j,
#               0.05980225+0.0867825j , -0.0534807 -0.07760894j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.08557665-0.18725428j,  0.4153516 +0.13539183j,
#              -0.04337711+0.1341978j , -0.14723695-0.26053388j,
#              -0.20629692+0.1968433j , -0.01099785-0.60494153j,
#               0.19528687-0.00403397j, -0.27426452+0.31074452j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.30382107-0.67179853j, -0.37117428+0.1247318j ,
#               0.23008128-0.40336762j, -0.20087675-0.14307575j,
#               0.05101128+0.1106588j ,  0.06119139-0.02105618j,
#              -0.0375418 +0.06693514j,  0.03336766+0.02340494j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.        +0.j        , -0.10136795+0.11179078j,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        , -0.66403623+0.73231362j,
#               0.        +0.j        ,  0.        +0.j        ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.10815108+0.31985212j, -0.19681666+0.42057545j,
#              -0.16323226+0.27670055j, -0.42533102+0.11957595j,
#               0.17922639-0.18814234j,  0.35698174-0.01639929j,
#               0.24693678+0.01220226j,  0.23367082+0.24700475j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.        +0.j        , -0.10136795+0.11179078j,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        , -0.66403623+0.73231362j,
#               0.        +0.j        ,  0.        +0.j        ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.08034684+0.18497338j, -0.0898517 -0.08440989j,
#              -0.05135763-0.21927341j,  0.08187398+0.11067857j,
#              -0.19525605+0.49514565j, -0.01015561-0.3252103j ,
#               0.31336764-0.5050568j , -0.05375568+0.35934525j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.00836674-0.00882336j, -0.01957323-0.00900464j,
#              -0.23899125-0.25203448j, -0.55909876-0.2572126j ,
#              -0.00882336+0.00836674j, -0.00900464+0.01957323j,
#              -0.25203448+0.23899125j, -0.2572126 +0.55909876j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.07984995+0.03592114j, -0.06577586-0.14621469j,
#               0.00878617-0.32729183j,  0.59931   +0.01608852j,
#              -0.03592114-0.07984995j,  0.14621469-0.06577586j,
#               0.32729183+0.00878617j, -0.01608852+0.59931j   ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.48203804-0.19223147j,  0.24779979+0.14417592j,
#               0.4687676 -0.1268363j ,  0.21483713+0.16067913j,
#              -0.01654421+0.37268174j, -0.16772664+0.11974748j,
#              -0.055471  +0.34465384j, -0.16879567+0.09327008j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.05787737+0.18143075j, -0.00353608+0.10695312j,
#               0.09910842-0.24678175j,  0.0158311 -0.14859602j,
#               0.41805731-0.21584055j,  0.19301819-0.18066354j,
#              -0.60424993+0.2579767j , -0.28724457+0.23193256j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.51441149-0.21744084j, -0.33230012+0.24047457j,
#              -0.09154587+0.06717845j,  0.00738145+0.0830713j ,
#               0.53512147-0.15982713j,  0.10315073-0.39700291j,
#               0.02782522-0.11008791j, -0.05858037-0.05936049j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.1460256 -0.09240159j, -0.12261609+0.33596715j,
#              -0.03767233+0.29169294j, -0.30680004-0.52574152j,
#              -0.13653566-0.00820079j,  0.23417076-0.15906935j,
#               0.15913094-0.16992633j, -0.04614625+0.47960413j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.        +0.j        , -0.10136795+0.11179078j,
#               0.        +0.j        ,  0.        +0.j        ,
#               0.        +0.j        , -0.66403623+0.73231362j,
#               0.        +0.j        ,  0.        +0.j        ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.34092832-0.30787315j, -0.18672065-0.11979121j,
#              -0.53459031-0.31787352j, -0.08027848+0.28943674j,
#               0.23408488+0.14281911j,  0.03684335-0.12719832j,
#               0.09112342-0.35991332j, -0.17926956+0.00321234j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.01538524-0.72081811j, -0.01882833-0.37461887j,
#              -0.28526226+0.10396696j, -0.14416093+0.06456129j,
#              -0.3826866 -0.11445681j, -0.16531144+0.04456827j,
#               0.01347936+0.16766836j,  0.04272114+0.05808152j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.09391985+0.14986359j,  0.1574062 -0.19212371j,
#              -0.14986359-0.09391985j,  0.19212371+0.1574062j ,
#               0.18585412+0.32001225j, -0.20218081-0.47875365j,
#              -0.32001225+0.18585412j,  0.47875365-0.20218081j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.41461305-0.30567166j, -0.30529911-0.23415908j,
#               0.1218918 +0.20185138j,  0.11957968-0.12931334j,
#              -0.30567166-0.41461305j, -0.23415908+0.30529911j,
#               0.20185138-0.1218918j , -0.12931334-0.11957968j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.24494269-0.19783464j,  0.0150907 -0.29774113j,
#              -0.13040083+0.5756036j ,  0.3237688 +0.45547243j,
#              -0.12648603+0.04105705j, -0.0509032 +0.11516676j,
#               0.13833719-0.20736198j, -0.05894809-0.22854278j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.26380272+0.01147837j,  0.33163788-0.17603517j,
#              -0.25702334+0.36520041j,  0.10665466-0.62597995j,
#              -0.08691896+0.09189693j,  0.05539248-0.17111833j,
#               0.03333953+0.21131389j, -0.17200556-0.25088863j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.52943828-0.36936496j, -0.42535495-0.45319451j,
#               0.06188384+0.2197821j ,  0.19941159+0.20686245j,
#               0.14709275+0.07767315j,  0.05360093-0.1509184j ,
#              -0.04303744+0.04011524j, -0.02384593+0.07009135j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.24958142-0.06152831j,  0.11771098+0.12645763j,
#              -0.15613244+0.57957668j,  0.30111155-0.26847067j,
#               0.06090032+0.11658918j,  0.02922781-0.20223047j,
#               0.27522973-0.13633818j, -0.47065104-0.07835571j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.29994734+0.44488839j,  0.35157578-0.40532525j,
#              -0.16139651+0.10460466j,  0.17286798-0.08430675j,
#              -0.3736478 +0.12475544j,  0.38599799-0.07862664j,
#              -0.14074833-0.01132501j,  0.1383438 +0.02827262j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.00603358-0.17877572j,  0.31221841+0.03803577j,
#               0.15606312+0.08741547j, -0.19421768+0.24739957j,
#              -0.25207698-0.16327064j,  0.35205535-0.39361493j,
#               0.27020977-0.13109837j,  0.15442086+0.50500483j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.08540888-0.2605211j , -0.11073633+0.09335636j,
#              -0.15120579+0.07315573j,  0.26522828-0.03763249j,
#               0.31626524-0.45634774j, -0.24684763-0.2530593j ,
#              -0.23624812-0.40114956j, -0.13476032+0.36842195j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([ 0.        +0.j        ,  0.        +0.j        ,
#               0.00313959-0.21713422j,  0.02862919+0.2145588j ,
#               0.        +0.j        ,  0.        +0.j        ,
#              -0.00974634+0.67405798j, -0.08887466-0.66606299j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([0.49510478+0.49510478j, 0.        +0.j        ,
#              0.49510478-0.49510478j, 0.        +0.j        ,
#              0.09869986+0.00092745j, 0.        +0.j        ,
#              0.00092745-0.09869986j, 0.        +0.j        ],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.13300027+0.07050395j,  0.0112058 +0.20223131j,
#              -0.13300027+0.07050395j,  0.0112058 +0.20223131j,
#               0.18454529+0.34813046j,  0.52934387-0.02933138j,
#               0.18454529+0.34813046j,  0.52934387-0.02933138j],
#             dims=(2, 2, 2))
# Qubits 3 X 3  --- 0
# Statevector([0.12326532+0.02339834j, 0.31240731+0.3491073j ,
#              0.34856749+0.14856804j, 0.30346707+0.17924934j,
#              0.40183258+0.21338023j, 0.00811082+0.06710992j,
#              0.3409797 +0.05027734j, 0.28561199+0.29163394j],
#             dims=(2, 2, 2))
# Statevector([-0.37293446+0.10583633j, -0.34521492-0.21452024j,
#               0.30669073+0.09571961j, -0.16399586+0.28956879j,
#               0.30609852-0.19968004j,  0.3708282 +0.09647511j,
#              -0.30288932-0.00031187j,  0.06656958-0.30658953j],
#             dims=(2, 2, 2))
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# CROSSOVER!!!
# ([<__main__.Circuit at 0x2597c269f70>,
#   <__main__.Circuit at 0x2597c26ff80>,
#   <__main__.Circuit at 0x2597c1c3ef0>,
#   <__main__.Circuit at 0x2597c281ac0>,
#   <__main__.Circuit at 0x2597c1503b0>,
#   <__main__.Circuit at 0x2597bf495b0>,
#   <__main__.Circuit at 0x2597c276fc0>,
#   <__main__.Circuit at 0x2597c1c6630>,
#   <__main__.Circuit at 0x2597c28f980>,
#   <__main__.Circuit at 0x2597c283860>,
#   <__main__.Circuit at 0x2597c900b00>,
#   <__main__.Circuit at 0x2597c269370>,
#   <__main__.Circuit at 0x2597bf65550>,
#   <__main__.Circuit at 0x2597c283620>,
#   <__main__.Circuit at 0x25979e1c650>,
#   <__main__.Circuit at 0x2597c150200>,
#   <__main__.Circuit at 0x2597c17f740>,
#   <__main__.Circuit at 0x25979e1ca10>,
#   <__main__.Circuit at 0x2597bf668d0>,
#   <__main__.Circuit at 0x25979ddd370>,
#   <__main__.Circuit at 0x2597bef39b0>,
#   <__main__.Circuit at 0x2597c903fb0>,
#   <__main__.Circuit at 0x2597c280c20>,
#   <__main__.Circuit at 0x2597bf1eba0>,
#   <__main__.Circuit at 0x2597c150110>,
#   <__main__.Circuit at 0x25979e88890>,
#   <__main__.Circuit at 0x2597c901c10>,
#   <__main__.Circuit at 0x2597bf9e870>,
#   <__main__.Circuit at 0x25979e89d90>,
#   <__main__.Circuit at 0x2597c283b60>,
#   <__main__.Circuit at 0x25979e1f5f0>,
#   <__main__.Circuit at 0x2597bf9dbb0>,
#   <__main__.Circuit at 0x2597bf282f0>,
#   <__main__.Circuit at 0x2597c150560>,
#   <__main__.Circuit at 0x25979e55760>,
#   <__main__.Circuit at 0x2597c280860>,
#   <__main__.Circuit at 0x2597c26e8d0>,
#   <__main__.Circuit at 0x2597c2759d0>,
#   <__main__.Circuit at 0x2597c287a40>,
#   <__main__.Circuit at 0x2597c150080>,
#   <__main__.Circuit at 0x2597c275ca0>,
#   <__main__.Circuit at 0x2597c26c710>,
#   <__main__.Circuit at 0x25979e55a00>,
#   <__main__.Circuit at 0x2597c26af30>,
#   <__main__.Circuit at 0x2597c275730>,
#   <__main__.Circuit at 0x2597c27faa0>,
#   <__main__.Circuit at 0x2597c282f00>,
#   <__main__.Circuit at 0x2597bf2b140>,
#   <__main__.Circuit at 0x2597bf9ee70>,
#   <__main__.Circuit at 0x2597bf48a10>],
#  50)

# %%
population[0].circuit.draw()
# Out:
#      ┌──────────────────────────┐    ┌───┐          ┌────────────┐      »
# q_0: ┤ Rv(0.5914,1.9063,0.5697) ├────┤ X ├──────────┤ Rz(3.2225) ├──────»
#      └──────────┬───┬───────────┘┌───┴───┴───┐      ├────────────┤      »
# q_1: ───────────┤ Y ├────────────┤ Rx(4.889) ├──────┤ Ms(5.3192) ├──────»
#                ┌┴───┴─┐          └──┬─────┬──┘┌─────┴────────────┴─────┐»
# q_2: ──────────┤ √Xdg ├─────────────┤ Tdg ├───┤ U(0.534,4.1142,2.5559) ├»
#                └──────┘             └─────┘   └────────────────────────┘»
# «     ┌─────────────┐   ┌──────┐          ┌───────────┐           ┌───┐
# «q_0: ┤0            ├───┤ √Xdg ├──────────┤ P(2.9213) ├───────────┤ H ├─────
# «     │             │┌──┴──────┴──┐       └──┬──────┬─┘       ┌───┴───┴────┐
# «q_1: ┤2 Ms(5.8248) ├┤ Rz(1.9554) ├──────────┤ √Xdg ├─────────┤ Rx(5.4308) ├
# «     │             │└───┬───┬────┘┌─────────┴──────┴────────┐└───┬───┬────┘
# «q_2: ┤1            ├────┤ T ├─────┤ Rv(3.1973,6.1907,4.835) ├────┤ Z ├─────
# «     └─────────────┘    └───┘     └─────────────────────────┘    └───┘

# %%
gatesParameters
# Out:
# {'barrier': {'qargs': ['int'],
#   'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'ccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'ccz': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'ch': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cp': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'crx': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cry': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'crz': {'theta': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cs': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'csdg': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cswap': {'control_qubit': ['int'],
#   'target_qubit1': ['int'],
#   'target_qubit2': ['int'],
#   'info': {'combinations': []}},
#  'csx': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cu': {'theta': ['float'],
#   'phi': ['float'],
#   'lam': ['float'],
#   'gamma': ['float'],
#   'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cx': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cy': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'cz': {'control_qubit': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'dcx': {'qubit1': ['int'], 'qubit2': ['int'], 'info': {'combinations': []}},
#  'ecr': {'qubit1': ['int'], 'qubit2': ['int'], 'info': {'combinations': []}},
#  'h': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'id': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'iswap': {'qubit1': ['int'], 'qubit2': ['int'], 'info': {'combinations': []}},
#  'mcp': {'lam': ['float'],
#   'control_qubits': ['list[int]'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'mcrx': {'theta': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int'],
#   'info': {'combinations': []}},
#  'mcry': {'theta': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int'],
#   'q_ancillae': ['int', 'list[int]', 'None'],
#   'info': {'combinations': []}},
#  'mcrz': {'lam': ['float'],
#   'q_controls': ['int', 'list[int]'],
#   'q_target': ['int'],
#   'info': {'combinations': []}},
#  'mcx': {'control_qubits': ['list[int]'],
#   'target_qubit': ['int'],
#   'ancilla_qubits': ['int', 'list[int]', 'None'],
#   'info': {'combinations': []}},
#  'ms': {'theta': ['float'],
#   'qubits': ['list[int]'],
#   'info': {'combinations': [(('float', 'list[int]'), 1, 1, 0)]}},
#  'p': {'theta': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'pauli': {'pauli_string': ['str'],
#   'qubits': ['list[int]'],
#   'info': {'combinations': [(('str', 'list[int]'), 1, 0, 1)]}},
#  'r': {'theta': ['float'],
#   'phi': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'float', 'int'), 1, 2, 0)]}},
#  'rcccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'control_qubit3': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'rccx': {'control_qubit1': ['int'],
#   'control_qubit2': ['int'],
#   'target_qubit': ['int'],
#   'info': {'combinations': []}},
#  'rv': {'vx': ['float'],
#   'vy': ['float'],
#   'vz': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'float', 'float', 'int'), 1, 3, 0)]}},
#  'rx': {'theta': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'rxx': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': []}},
#  'ry': {'theta': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'ryy': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': []}},
#  'rz': {'phi': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'int'), 1, 1, 0)]}},
#  'rzx': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': []}},
#  'rzz': {'theta': ['float'],
#   'qubit1': ['int'],
#   'qubit2': ['int'],
#   'info': {'combinations': []}},
#  's': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'sdg': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'swap': {'qubit1': ['int'], 'qubit2': ['int'], 'info': {'combinations': []}},
#  'sx': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'sxdg': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  't': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'tdg': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'u': {'theta': ['float'],
#   'phi': ['float'],
#   'lam': ['float'],
#   'qubit': ['int'],
#   'info': {'combinations': [(('float', 'float', 'float', 'int'), 1, 3, 0)]}},
#  'x': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'y': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}},
#  'z': {'qubit': ['int'], 'info': {'combinations': [(('int',), 1, 0, 0)]}}}

# %%
def criar_circuito(num_qubits, num_gates_por_qubit):
    qc = QuantumCircuit(num_qubits)
    for qubit in range(num_qubits):
        for _ in range(num_gates_por_qubit):
            qc.h(qubit)  # Aplicando a porta de Hadamard como exemplo

    #qc.measure_all()
    return qc
def simular_circuito(qc, simulador):
    qc_simulator = transpile(qc, backend=simulador)
    job = simulador.run(qc_simulator, shots=1024)
    return job

# %%
qc_1 = criar_circuito(10, 9)
qc_2 = criar_circuito(9, 7)

# %%
qc_1.draw()
# Out:
#      ┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐
# q_0: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_1: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_2: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_3: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_4: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_5: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_6: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_7: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_8: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_9: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      └───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘└───┘

# %%
qc_2.draw()
# Out:
#      ┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐
# q_0: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_1: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_2: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_3: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_4: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_5: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_6: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_7: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      ├───┤├───┤├───┤├───┤├───┤├───┤├───┤
# q_8: ┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├┤ H ├
#      └───┘└───┘└───┘└───┘└───┘└───┘└───┘

# %%
#job_1 = simular_circuito(qc_1, simulator)
sv2 = Statevector.from_label("0"*10)
sv2 = sv2.evolve(qc_2)
#job_1 = simular_circuito(qc_1, simulator)
sv1 = Statevector.from_label("0"*10)
sv1 = sv1.evolve(qc_1)

print(sv1)
print(sv2)
state_fidelity(sv1, sv2)
# Out:
# Statevector([0.03125+0.j, 0.03125+0.j, 0.03125+0.j, ..., 0.03125+0.j,
#              0.03125+0.j, 0.03125+0.j],
#             dims=(2, 2, 2, 2, 2, 2, 2, 2, 2, 2))
# Statevector([0.04419417+0.j, 0.04419417+0.j, 0.04419417+0.j, ...,
#              0.        +0.j, 0.        +0.j, 0.        +0.j],
#             dims=(2, 2, 2, 2, 2, 2, 2, 2, 2, 2))
# 0.49999999999998795

# %%
#job_2 = simular_circuito(qc_2, simulator)

# %%
result = job_1.result()

# %%
result.get_statevector()
# Out:
# Statevector([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2, 2))

# %%
result1 = job_2.result()

# %%
result1.get_statevector()
# Out:
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2, 2))

# %%
import matplotlib.pyplot as plt
import numpy as np

# Supondo que o statevector já esteja calculado e armazenado em uma lista


# Calculando as probabilidades
probabilities = np.abs(statevector)**2

# Criando os rótulos dos estados computacionais (ajuste conforme necessário)
states = ['0', '1']

# Criando o gráfico de barras
plt.bar(states, probabilities)
plt.xlabel('Computational basis states')
plt.ylabel('Amplitude')
plt.title('Probabilities')
plt.show()

# %%
statevector = result.get_statevector() # Substitua pelos seus valores
statevector2 = result1.get_statevector()
state_fidelity(statevector, statevector2)
# Out:
# 0.0
