# %%
from qiskit import QuantumCircuit, transpile
from qiskit.quantum_info import Statevector, state_fidelity
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from qiskit_aer import Aer
import time
import numpy
import json
import random
import math

# %%
def openFile(gate):
    with open(gate, 'r') as f:
        data = dict(json.load(f))
    return data

# %%
PI = math.pi
SEED = 11
random.seed(SEED)
TARGET = []
STRUCTS_GATES = openFile("./configuration/gate.json")

# %%
class Circuit:
    def __init__(self, n_qubits, m_gates) -> None:
        self.n_qubits = n_qubits
        self.m_gates = m_gates
        self.matrix = [[None for _ in range(m_gates)] for _ in range(n_qubits)]
        self.fitness = None
        self.circuit = None

class Gate:
    def __init__(self, name:str, affected_qubits:list, control_qubits:list = [], target_qubits:list = [], parameters:list = []) -> None:
        self.name =  name
        self.affected_qubits = affected_qubits
        self.parameters = parameters
        self.control_qubits= control_qubits
        self.target_qubits= target_qubits

# %%
def createGateToListQubits(qubitsFree, structLocal):
    structLocal = {gateName: gateInfo for gateName, gateInfo in structLocal.items() if (gateName == "") or (gateInfo['affected_qubits'] <= len(qubitsFree))}
    gateName, gateInfo = random.choice(list(structLocal.items()))
    y = random.choice(qubitsFree)
    qubitsFree.remove(y)
    qubitsChoice = [y]
    qubitsTarget = []
    qubitsControl = []
    parameters = []
    if gateName:
        qubitsChoice = [y] + random.sample(qubitsFree, gateInfo['affected_qubits'] - 1)
        qubitsFree = list(set(qubitsFree).difference(qubitsChoice))
        qubitsControl = random.sample(qubitsChoice, gateInfo['control_qubits'])
        qubitsTarget = list(set(qubitsChoice).difference(qubitsControl))
        parameters = [random.uniform(0, 2) for _ in range(gateInfo['parameters'])]
    gate = Gate(gateName, qubitsChoice, qubitsControl, qubitsTarget, parameters)
    return gate, qubitsFree

def createCircuit(numQubits, maxDepth, minDepth):
    depth = random.randint(minDepth, maxDepth)
    circuit = Circuit(numQubits, depth)
    for y in range(depth):
        structLocal = STRUCTS_GATES.copy()
        qubitsFree = list(range(numQubits))
        while qubitsFree:
            gate, qubitsFree = createGateToListQubits(qubitsFree, structLocal)
            for x in gate.affected_qubits:
                circuit.matrix[x][y] = gate
    return circuit

def initialPopulation(numPopulation:int, numQubits:int, maxDepth:int, minDepth:int=0):
    population = []
    for _ in range(numPopulation):
        circuit = createCircuit(numQubits, maxDepth, minDepth)
        population.append(circuit)
    return population

def fidelityFitnessFunction(circuit):
    #job_1 = simular_circuito(qc_1, simulator)
    sv2 = Statevector.from_label("000")
    sv2 = sv2.evolve(qc_2)
    #job_1 = simular_circuito(qc_1, simulator)
    sv1 = Statevector.from_label("000")
    sv1 = sv1.evolve(qc_1)
    state_fidelity(sv1, sv2)

def parentSelection():
    pass
def crossover():
    pass
def mutation():
    pass
def survivorSelection():
    pass

# %%
#createPopulation(10,2, 5)
initialPopulation(10000, 10, 10)
# Out:
# [<__main__.Circuit at 0x153f363fa40>,
#  <__main__.Circuit at 0x153f363c770>,
#  <__main__.Circuit at 0x153f4913e30>,
#  <__main__.Circuit at 0x153f49345c0>,
#  <__main__.Circuit at 0x153f4934920>,
#  <__main__.Circuit at 0x153f4934ce0>,
#  <__main__.Circuit at 0x153f4934e30>,
#  <__main__.Circuit at 0x153f49355e0>,
#  <__main__.Circuit at 0x153f4935a60>,
#  <__main__.Circuit at 0x153f4936210>,
#  <__main__.Circuit at 0x153f4936330>,
#  <__main__.Circuit at 0x153f4936c60>,
#  <__main__.Circuit at 0x153f4936ed0>,
#  <__main__.Circuit at 0x153f4937320>,
#  <__main__.Circuit at 0x153f4937b90>,
#  <__main__.Circuit at 0x153f49600b0>,
#  <__main__.Circuit at 0x153f49605f0>,
#  <__main__.Circuit at 0x153f4960ce0>,
#  <__main__.Circuit at 0x153f4960fb0>,
#  <__main__.Circuit at 0x153f4960fe0>,
#  <__main__.Circuit at 0x153f4961280>,
#  <__main__.Circuit at 0x153f4961df0>,
#  <__main__.Circuit at 0x153f4962420>,
#  <__main__.Circuit at 0x153f4962630>,
#  <__main__.Circuit at 0x153f4963110>,
#  <__main__.Circuit at 0x153f49635c0>,
#  <__main__.Circuit at 0x153f4963c80>,
#  <__main__.Circuit at 0x153f49848c0>,
#  <__main__.Circuit at 0x153f49848f0>,
#  <__main__.Circuit at 0x153f4985430>,
#  <__main__.Circuit at 0x153f4985cd0>,
#  <__main__.Circuit at 0x153f4986540>,
#  <__main__.Circuit at 0x153f4986570>,
#  <__main__.Circuit at 0x153f49866c0>,
#  <__main__.Circuit at 0x153f4986c00>,
#  <__main__.Circuit at 0x153f49877d0>,
#  <__main__.Circuit at 0x153f49ac0b0>,
#  <__main__.Circuit at 0x153f49ac6b0>,
#  <__main__.Circuit at 0x153f49ac6e0>,
#  <__main__.Circuit at 0x153f49acf50>,
#  <__main__.Circuit at 0x153f49ad8b0>,
#  <__main__.Circuit at 0x153f49ada00>,
#  <__main__.Circuit at 0x153f49adc70>,
#  <__main__.Circuit at 0x153f49ae300>,
#  <__main__.Circuit at 0x153f49ae330>,
#  <__main__.Circuit at 0x153f49aee70>,
#  <__main__.Circuit at 0x153f49af710>,
#  <__main__.Circuit at 0x153f49afe60>,
#  <__main__.Circuit at 0x153f49d4620>,
#  <__main__.Circuit at 0x153f49d4a40>,
#  <__main__.Circuit at 0x153f49d5490>,
#  <__main__.Circuit at 0x153f49d5a60>,
#  <__main__.Circuit at 0x153f49d64b0>,
#  <__main__.Circuit at 0x153f49d6840>,
#  <__main__.Circuit at 0x153f49d6ea0>,
#  <__main__.Circuit at 0x153f49d7410>,
#  <__main__.Circuit at 0x153f49d7440>,
#  <__main__.Circuit at 0x153f49d7a10>,
#  <__main__.Circuit at 0x153f49d7d10>,
#  <__main__.Circuit at 0x153f49f8320>,
#  <__main__.Circuit at 0x153f49f8800>,
#  <__main__.Circuit at 0x153f49f8bc0>,
#  <__main__.Circuit at 0x153f49f8d10>,
#  <__main__.Circuit at 0x153f49f8ec0>,
#  <__main__.Circuit at 0x153f49f9040>,
#  <__main__.Circuit at 0x153f49f97c0>,
#  <__main__.Circuit at 0x153f49f9a30>,
#  <__main__.Circuit at 0x153f49f9df0>,
#  <__main__.Circuit at 0x153f49fa900>,
#  <__main__.Circuit at 0x153f49fab70>,
#  <__main__.Circuit at 0x153f49facf0>,
#  <__main__.Circuit at 0x153f49faf90>,
#  <__main__.Circuit at 0x153f49fb710>,
#  <__main__.Circuit at 0x153f49fbec0>,
#  <__main__.Circuit at 0x153f4a241d0>,
#  <__main__.Circuit at 0x153f4a24b00>,
#  <__main__.Circuit at 0x153f4a25490>,
#  <__main__.Circuit at 0x153f4a25f10>,
#  <__main__.Circuit at 0x153f4a26720>,
#  <__main__.Circuit at 0x153f4a26990>,
#  <__main__.Circuit at 0x153f4a27080>,
#  <__main__.Circuit at 0x153f4a277a0>,
#  <__main__.Circuit at 0x153f4a4c350>,
#  <__main__.Circuit at 0x153f4a4cfb0>,
#  <__main__.Circuit at 0x153f4a4d5b0>,
#  <__main__.Circuit at 0x153f4a4d850>,
#  <__main__.Circuit at 0x153f4a4daf0>,
#  <__main__.Circuit at 0x153f4a4dc40>,
#  <__main__.Circuit at 0x153f4a4e300>,
#  <__main__.Circuit at 0x153f4a4e840>,
#  <__main__.Circuit at 0x153f4a4e9c0>,
#  <__main__.Circuit at 0x153f4a4f3e0>,
#  <__main__.Circuit at 0x153f4a4fa70>,
#  <__main__.Circuit at 0x153f4a70770>,
#  <__main__.Circuit at 0x153f4a70fb0>,
#  <__main__.Circuit at 0x153f4a71640>,
#  <__main__.Circuit at 0x153f4a719a0>,
#  <__main__.Circuit at 0x153f4a720f0>,
#  <__main__.Circuit at 0x153f4a728a0>,
#  <__main__.Circuit at 0x153f4a72c00>,
#  <__main__.Circuit at 0x153f4a731a0>,
#  <__main__.Circuit at 0x153f4a73980>,
#  <__main__.Circuit at 0x153f4a98140>,
#  <__main__.Circuit at 0x153f4a98170>,
#  <__main__.Circuit at 0x153f4a98740>,
#  <__main__.Circuit at 0x153f4a99160>,
#  <__main__.Circuit at 0x153f4a99190>,
#  <__main__.Circuit at 0x153f4a998b0>,
#  <__main__.Circuit at 0x153f4a99ca0>,
#  <__main__.Circuit at 0x153f4a99e20>,
#  <__main__.Circuit at 0x153f4a9a2a0>,
#  <__main__.Circuit at 0x153f4a9aa50>,
#  <__main__.Circuit at 0x153f4a9b1d0>,
#  <__main__.Circuit at 0x153f4a9b6b0>,
#  <__main__.Circuit at 0x153f4a9b7d0>,
#  <__main__.Circuit at 0x153f4a9baa0>,
#  <__main__.Circuit at 0x153f4a9bad0>,
#  <__main__.Circuit at 0x153f4ac0530>,
#  <__main__.Circuit at 0x153f4ac0bf0>,
#  <__main__.Circuit at 0x153f4ac1370>,
#  <__main__.Circuit at 0x153f4ac1b20>,
#  <__main__.Circuit at 0x153f4ac2180>,
#  <__main__.Circuit at 0x153f4ac2720>,
#  <__main__.Circuit at 0x153f4ac2750>,
#  <__main__.Circuit at 0x153f4ac2ba0>,
#  <__main__.Circuit at 0x153f4ac36e0>,
#  <__main__.Circuit at 0x153f4ae8050>,
#  <__main__.Circuit at 0x153f4ae8b60>,
#  <__main__.Circuit at 0x153f4ae9400>,
#  <__main__.Circuit at 0x153f4ae9b50>,
#  <__main__.Circuit at 0x153f4ae9ca0>,
#  <__main__.Circuit at 0x153f4aea030>,
#  <__main__.Circuit at 0x153f4aea3c0>,
#  <__main__.Circuit at 0x153f4aea510>,
#  <__main__.Circuit at 0x153f4aeaa20>,
#  <__main__.Circuit at 0x153f4aeae10>,
#  <__main__.Circuit at 0x153f4aeaf60>,
#  <__main__.Circuit at 0x153f4aeb200>,
#  <__main__.Circuit at 0x153f4aebce0>,
#  <__main__.Circuit at 0x153f4b0c1a0>,
#  <__main__.Circuit at 0x153f4b0ce30>,
#  <__main__.Circuit at 0x153f4b0ce60>,
#  <__main__.Circuit at 0x153f4b0d880>,
#  <__main__.Circuit at 0x153f4b0dc70>,
#  <__main__.Circuit at 0x153f4b0e3c0>,
#  <__main__.Circuit at 0x153f4b0e990>,
#  <__main__.Circuit at 0x153f4b0ef90>,
#  <__main__.Circuit at 0x153f4b0fa70>,
#  <__main__.Circuit at 0x153f4b0faa0>,
#  <__main__.Circuit at 0x153f4b3c4d0>,
#  <__main__.Circuit at 0x153f4b3cb60>,
#  <__main__.Circuit at 0x153f4b3cce0>,
#  <__main__.Circuit at 0x153f4b3d910>,
#  <__main__.Circuit at 0x153f4b3dc10>,
#  <__main__.Circuit at 0x153f4b3e450>,
#  <__main__.Circuit at 0x153f4b3ec30>,
#  <__main__.Circuit at 0x153f4b3f020>,
#  <__main__.Circuit at 0x153f4b3f4a0>,
#  <__main__.Circuit at 0x153f4b3fec0>,
#  <__main__.Circuit at 0x153f4b609b0>,
#  <__main__.Circuit at 0x153f4b61010>,
#  <__main__.Circuit at 0x153f4b61040>,
#  <__main__.Circuit at 0x153f4b61310>,
#  <__main__.Circuit at 0x153f4b61580>,
#  <__main__.Circuit at 0x153f4b61b80>,
#  <__main__.Circuit at 0x153f4b624b0>,
#  <__main__.Circuit at 0x153f4b62750>,
#  <__main__.Circuit at 0x153f4b62ed0>,
#  <__main__.Circuit at 0x153f4b637a0>,
#  <__main__.Circuit at 0x153f4b63c20>,
#  <__main__.Circuit at 0x153f4b63da0>,
#  <__main__.Circuit at 0x153f4b84050>,
#  <__main__.Circuit at 0x153f4b844d0>,
#  <__main__.Circuit at 0x153f4b84e90>,
#  <__main__.Circuit at 0x153f4b859a0>,
#  <__main__.Circuit at 0x153f4b86540>,
#  <__main__.Circuit at 0x153f4b868a0>,
#  <__main__.Circuit at 0x153f4b872c0>,
#  <__main__.Circuit at 0x153f4b87f50>,
#  <__main__.Circuit at 0x153f4bac140>,
#  <__main__.Circuit at 0x153f4bac170>,
#  <__main__.Circuit at 0x153f4bac4a0>,
#  <__main__.Circuit at 0x153f4bacb00>,
#  <__main__.Circuit at 0x153f4bacfb0>,
#  <__main__.Circuit at 0x153f4badb50>,
#  <__main__.Circuit at 0x153f4badb80>,
#  <__main__.Circuit at 0x153f4bae330>,
#  <__main__.Circuit at 0x153f4bae360>,
#  <__main__.Circuit at 0x153f4baecc0>,
#  <__main__.Circuit at 0x153f4baecf0>,
#  <__main__.Circuit at 0x153f4baf110>,
#  <__main__.Circuit at 0x153f4baf740>,
#  <__main__.Circuit at 0x153f4baf860>,
#  <__main__.Circuit at 0x153f4bd40e0>,
#  <__main__.Circuit at 0x153f4bd4560>,
#  <__main__.Circuit at 0x153f4bd4ad0>,
#  <__main__.Circuit at 0x153f4bd5010>,
#  <__main__.Circuit at 0x153f4bd5c70>,
#  <__main__.Circuit at 0x153f4bd65a0>,
#  <__main__.Circuit at 0x153f4bd6840>,
#  <__main__.Circuit at 0x153f4bd6b70>,
#  <__main__.Circuit at 0x153f4bd6ff0>,
#  <__main__.Circuit at 0x153f4bd7b60>,
#  <__main__.Circuit at 0x153f4bd7f80>,
#  <__main__.Circuit at 0x153f4bfc440>,
#  <__main__.Circuit at 0x153f4bfd190>,
#  <__main__.Circuit at 0x153f4bfd4c0>,
#  <__main__.Circuit at 0x153f4bfde80>,
#  <__main__.Circuit at 0x153f4bfe9f0>,
#  <__main__.Circuit at 0x153f4bff3b0>,
#  <__main__.Circuit at 0x153f4bff980>,
#  <__main__.Circuit at 0x153f4bfffe0>,
#  <__main__.Circuit at 0x153f4c249b0>,
#  <__main__.Circuit at 0x153f4c25220>,
#  <__main__.Circuit at 0x153f4c25700>,
#  <__main__.Circuit at 0x153f4c25cd0>,
#  <__main__.Circuit at 0x153f4c25e50>,
#  <__main__.Circuit at 0x153f4c26000>,
#  <__main__.Circuit at 0x153f4c26360>,
#  <__main__.Circuit at 0x153f4c26900>,
#  <__main__.Circuit at 0x153f4c26ed0>,
#  <__main__.Circuit at 0x153f4c27020>,
#  <__main__.Circuit at 0x153f4c27170>,
#  <__main__.Circuit at 0x153f4c278c0>,
#  <__main__.Circuit at 0x153f4c27dd0>,
#  <__main__.Circuit at 0x153f4c4ca40>,
#  <__main__.Circuit at 0x153f4c4d0d0>,
#  <__main__.Circuit at 0x153f4c4d9a0>,
#  <__main__.Circuit at 0x153f4c4dfd0>,
#  <__main__.Circuit at 0x153f4c4e5d0>,
#  <__main__.Circuit at 0x153f4c4ef90>,
#  <__main__.Circuit at 0x153f4c4efc0>,
#  <__main__.Circuit at 0x153f4c4f8c0>,
#  <__main__.Circuit at 0x153f4c70080>,
#  <__main__.Circuit at 0x153f4c70d10>,
#  <__main__.Circuit at 0x153f4c70fb0>,
#  <__main__.Circuit at 0x153f4c71370>,
#  <__main__.Circuit at 0x153f4c713a0>,
#  <__main__.Circuit at 0x153f4c71eb0>,
#  <__main__.Circuit at 0x153f4c72150>,
#  <__main__.Circuit at 0x153f4c722a0>,
#  <__main__.Circuit at 0x153f4c723c0>,
#  <__main__.Circuit at 0x153f4c72c30>,
#  <__main__.Circuit at 0x153f4c72ed0>,
#  <__main__.Circuit at 0x153f4c738c0>,
#  <__main__.Circuit at 0x153f4c9c380>,
#  <__main__.Circuit at 0x153f4c9c650>,
#  <__main__.Circuit at 0x153f4c9d3a0>,
#  <__main__.Circuit at 0x153f4c9dc40>,
#  <__main__.Circuit at 0x153f4c9e540>,
#  <__main__.Circuit at 0x153f4c9ec60>,
#  <__main__.Circuit at 0x153f4c9f4d0>,
#  <__main__.Circuit at 0x153f4cc40b0>,
#  <__main__.Circuit at 0x153f4cc4bc0>,
#  <__main__.Circuit at 0x153f4cc5850>,
#  <__main__.Circuit at 0x153f4cc61b0>,
#  <__main__.Circuit at 0x153f4cc6450>,
#  <__main__.Circuit at 0x153f4cc6de0>,
#  <__main__.Circuit at 0x153f4cc7500>,
#  <__main__.Circuit at 0x153f4cec0b0>,
#  <__main__.Circuit at 0x153f4cec0e0>,
#  <__main__.Circuit at 0x153f4cec440>,
#  <__main__.Circuit at 0x153f4ceca40>,
#  <__main__.Circuit at 0x153f4ced5b0>,
#  <__main__.Circuit at 0x153f4cee240>,
#  <__main__.Circuit at 0x153f4cee450>,
#  <__main__.Circuit at 0x153f4ceef60>,
#  <__main__.Circuit at 0x153f4cef890>,
#  <__main__.Circuit at 0x153f4d10290>,
#  <__main__.Circuit at 0x153f4d103e0>,
#  <__main__.Circuit at 0x153f4d10fe0>,
#  <__main__.Circuit at 0x153f4d11b80>,
#  <__main__.Circuit at 0x153f4d12660>,
#  <__main__.Circuit at 0x153f4d12f00>,
#  <__main__.Circuit at 0x153f4d13830>,
#  <__main__.Circuit at 0x153f4d13ec0>,
#  <__main__.Circuit at 0x153f4d3c170>,
#  <__main__.Circuit at 0x153f4d3c320>,
#  <__main__.Circuit at 0x153f4d3c920>,
#  <__main__.Circuit at 0x153f4d3d340>,
#  <__main__.Circuit at 0x153f4d3d5e0>,
#  <__main__.Circuit at 0x153f4d3d730>,
#  <__main__.Circuit at 0x153f4d3dd90>,
#  <__main__.Circuit at 0x153f4d3e0f0>,
#  <__main__.Circuit at 0x153f4d3ec00>,
#  <__main__.Circuit at 0x153f4d3f3e0>,
#  <__main__.Circuit at 0x153f4d3f800>,
#  <__main__.Circuit at 0x153f4d60410>,
#  <__main__.Circuit at 0x153f4d60860>,
#  <__main__.Circuit at 0x153f4d60d10>,
#  <__main__.Circuit at 0x153f4d61100>,
#  <__main__.Circuit at 0x153f4d61460>,
#  <__main__.Circuit at 0x153f4d615e0>,
#  <__main__.Circuit at 0x153f4d61b50>,
#  <__main__.Circuit at 0x153f4d620c0>,
#  <__main__.Circuit at 0x153f4d62c00>,
#  <__main__.Circuit at 0x153f4d63800>,
#  <__main__.Circuit at 0x153f4d63d40>,
#  <__main__.Circuit at 0x153f4d84170>,
#  <__main__.Circuit at 0x153f4d846b0>,
#  <__main__.Circuit at 0x153f4d84ce0>,
#  <__main__.Circuit at 0x153f4d85910>,
#  <__main__.Circuit at 0x153f4d85940>,
#  <__main__.Circuit at 0x153f4d85bb0>,
#  <__main__.Circuit at 0x153f4d85fa0>,
#  <__main__.Circuit at 0x153f4d86ae0>,
#  <__main__.Circuit at 0x153f4d86d20>,
#  <__main__.Circuit at 0x153f4d87260>,
#  <__main__.Circuit at 0x153f4d87e60>,
#  <__main__.Circuit at 0x153f4db0a10>,
#  <__main__.Circuit at 0x153f4db0e60>,
#  <__main__.Circuit at 0x153f4db1100>,
#  <__main__.Circuit at 0x153f4db1130>,
#  <__main__.Circuit at 0x153f4db15b0>,
#  <__main__.Circuit at 0x153f4db1fd0>,
#  <__main__.Circuit at 0x153f4db26c0>,
#  <__main__.Circuit at 0x153f4db3320>,
#  <__main__.Circuit at 0x153f4db3cb0>,
#  <__main__.Circuit at 0x153f4db3ce0>,
#  <__main__.Circuit at 0x153f4db3fb0>,
#  <__main__.Circuit at 0x153f4dd83b0>,
#  <__main__.Circuit at 0x153f4dd83e0>,
#  <__main__.Circuit at 0x153f4dd9130>,
#  <__main__.Circuit at 0x153f4dd9b50>,
#  <__main__.Circuit at 0x153f4dda030>,
#  <__main__.Circuit at 0x153f4dda5d0>,
#  <__main__.Circuit at 0x153f4ddae10>,
#  <__main__.Circuit at 0x153f4ddb980>,
#  <__main__.Circuit at 0x153f4ddbf50>,
#  <__main__.Circuit at 0x153f4dfc9e0>,
#  <__main__.Circuit at 0x153f4dfca10>,
#  <__main__.Circuit at 0x153f4dfcdd0>,
#  <__main__.Circuit at 0x153f4dfd8e0>,
#  <__main__.Circuit at 0x153f4dfe300>,
#  <__main__.Circuit at 0x153f4dfe330>,
#  <__main__.Circuit at 0x153f4dfec60>,
#  <__main__.Circuit at 0x153f4dff860>,
#  <__main__.Circuit at 0x153f4dff9b0>,
#  <__main__.Circuit at 0x153f4e240e0>,
#  <__main__.Circuit at 0x153f4e24110>,
#  <__main__.Circuit at 0x153f4e24bc0>,
#  <__main__.Circuit at 0x153f4e25250>,
#  <__main__.Circuit at 0x153f4e253a0>,
#  <__main__.Circuit at 0x153f4e255e0>,
#  <__main__.Circuit at 0x153f4e25be0>,
#  <__main__.Circuit at 0x153f4e25d30>,
#  <__main__.Circuit at 0x153f4e26210>,
#  <__main__.Circuit at 0x153f4e26de0>,
#  <__main__.Circuit at 0x153f4e27560>,
#  <__main__.Circuit at 0x153f4e27ad0>,
#  <__main__.Circuit at 0x153f4e50140>,
#  <__main__.Circuit at 0x153f4e50290>,
#  <__main__.Circuit at 0x153f4e505c0>,
#  <__main__.Circuit at 0x153f4e50e60>,
#  <__main__.Circuit at 0x153f4e51250>,
#  <__main__.Circuit at 0x153f4e51b50>,
#  <__main__.Circuit at 0x153f4e51d30>,
#  <__main__.Circuit at 0x153f4e52480>,
#  <__main__.Circuit at 0x153f4e524b0>,
#  <__main__.Circuit at 0x153f4e52810>,
#  <__main__.Circuit at 0x153f4e52cf0>,
#  <__main__.Circuit at 0x153f4e535c0>,
#  <__main__.Circuit at 0x153f4e536e0>,
#  <__main__.Circuit at 0x153f4e70230>,
#  <__main__.Circuit at 0x153f4e70e00>,
#  <__main__.Circuit at 0x153f4e71580>,
#  <__main__.Circuit at 0x153f4e71a00>,
#  <__main__.Circuit at 0x153f4e71a30>,
#  <__main__.Circuit at 0x153f4e71ca0>,
#  <__main__.Circuit at 0x153f4e721e0>,
#  <__main__.Circuit at 0x153f4e72c90>,
#  <__main__.Circuit at 0x153f4e73260>,
#  <__main__.Circuit at 0x153f4e73770>,
#  <__main__.Circuit at 0x153f4e98410>,
#  <__main__.Circuit at 0x153f4e98680>,
#  <__main__.Circuit at 0x153f4e98a70>,
#  <__main__.Circuit at 0x153f4e98d70>,
#  <__main__.Circuit at 0x153f4e993d0>,
#  <__main__.Circuit at 0x153f4e99d00>,
#  <__main__.Circuit at 0x153f4e9a870>,
#  <__main__.Circuit at 0x153f4e9ac00>,
#  <__main__.Circuit at 0x153f4e9ad80>,
#  <__main__.Circuit at 0x153f4e9aed0>,
#  <__main__.Circuit at 0x153f4e9b110>,
#  <__main__.Circuit at 0x153f4e9b890>,
#  <__main__.Circuit at 0x153f4e9bec0>,
#  <__main__.Circuit at 0x153f4ec42c0>,
#  <__main__.Circuit at 0x153f4ec4b30>,
#  <__main__.Circuit at 0x153f4ec53a0>,
#  <__main__.Circuit at 0x153f4ec57f0>,
#  <__main__.Circuit at 0x153f4ec5820>,
#  <__main__.Circuit at 0x153f4ec60c0>,
#  <__main__.Circuit at 0x153f4ec60f0>,
#  <__main__.Circuit at 0x153f4ec6c30>,
#  <__main__.Circuit at 0x153f4ec6f30>,
#  <__main__.Circuit at 0x153f4ec7a10>,
#  <__main__.Circuit at 0x153f4ec7e00>,
#  <__main__.Circuit at 0x153f4ef0560>,
#  <__main__.Circuit at 0x153f4ef0b00>,
#  <__main__.Circuit at 0x153f4ef0b30>,
#  <__main__.Circuit at 0x153f4ef1730>,
#  <__main__.Circuit at 0x153f4ef1760>,
#  <__main__.Circuit at 0x153f4ef1940>,
#  <__main__.Circuit at 0x153f4ef2120>,
#  <__main__.Circuit at 0x153f4ef2c00>,
#  <__main__.Circuit at 0x153f4ef3350>,
#  <__main__.Circuit at 0x153f4ef3b00>,
#  <__main__.Circuit at 0x153f4f143e0>,
#  <__main__.Circuit at 0x153f4f147d0>,
#  <__main__.Circuit at 0x153f4f14a70>,
#  <__main__.Circuit at 0x153f4f15400>,
#  <__main__.Circuit at 0x153f4f156d0>,
#  <__main__.Circuit at 0x153f4f15e50>,
#  <__main__.Circuit at 0x153f4f16330>,
#  <__main__.Circuit at 0x153f4f16810>,
#  <__main__.Circuit at 0x153f4f16a20>,
#  <__main__.Circuit at 0x153f4f17590>,
#  <__main__.Circuit at 0x153f4f179b0>,
#  <__main__.Circuit at 0x153f4f3c410>,
#  <__main__.Circuit at 0x153f4f3c980>,
#  <__main__.Circuit at 0x153f4f3d670>,
#  <__main__.Circuit at 0x153f4f3d6a0>,
#  <__main__.Circuit at 0x153f4f3ddc0>,
#  <__main__.Circuit at 0x153f4f3ddf0>,
#  <__main__.Circuit at 0x153f4f3e240>,
#  <__main__.Circuit at 0x153f4f3e450>,
#  <__main__.Circuit at 0x153f4f3ea80>,
#  <__main__.Circuit at 0x153f4f3f140>,
#  <__main__.Circuit at 0x153f4f3f170>,
#  <__main__.Circuit at 0x153f4f3f2f0>,
#  <__main__.Circuit at 0x153f4f3f590>,
#  <__main__.Circuit at 0x153f4f3fe60>,
#  <__main__.Circuit at 0x153f4f64200>,
#  <__main__.Circuit at 0x153f4f64da0>,
#  <__main__.Circuit at 0x153f4f658b0>,
#  <__main__.Circuit at 0x153f4f66150>,
#  <__main__.Circuit at 0x153f4f66870>,
#  <__main__.Circuit at 0x153f4f66c90>,
#  <__main__.Circuit at 0x153f4f67320>,
#  <__main__.Circuit at 0x153f4f67e60>,
#  <__main__.Circuit at 0x153f4f883e0>,
#  <__main__.Circuit at 0x153f4f88560>,
#  <__main__.Circuit at 0x153f4f89070>,
#  <__main__.Circuit at 0x153f4f89580>,
#  <__main__.Circuit at 0x153f4f89c70>,
#  <__main__.Circuit at 0x153f4f8a270>,
#  <__main__.Circuit at 0x153f4f8a2a0>,
#  <__main__.Circuit at 0x153f4f8adb0>,
#  <__main__.Circuit at 0x153f4f8b920>,
#  <__main__.Circuit at 0x153f4fb00b0>,
#  <__main__.Circuit at 0x153f4fb0b60>,
#  <__main__.Circuit at 0x153f4fb1700>,
#  <__main__.Circuit at 0x153f4fb1f10>,
#  <__main__.Circuit at 0x153f4fb1f40>,
#  <__main__.Circuit at 0x153f4fb29c0>,
#  <__main__.Circuit at 0x153f4fb3470>,
#  <__main__.Circuit at 0x153f4fb34a0>,
#  <__main__.Circuit at 0x153f4fb3c50>,
#  <__main__.Circuit at 0x153f4fd8320>,
#  <__main__.Circuit at 0x153f4fd8a10>,
#  <__main__.Circuit at 0x153f4fd9310>,
#  <__main__.Circuit at 0x153f4fd9340>,
#  <__main__.Circuit at 0x153f4fd9c70>,
#  <__main__.Circuit at 0x153f4fda090>,
#  <__main__.Circuit at 0x153f4fda960>,
#  <__main__.Circuit at 0x153f4fdaab0>,
#  <__main__.Circuit at 0x153f4fdad50>,
#  <__main__.Circuit at 0x153f4fdb8c0>,
#  <__main__.Circuit at 0x153f4fdbb60>,
#  <__main__.Circuit at 0x153f4ffc470>,
#  <__main__.Circuit at 0x153f4ffcda0>,
#  <__main__.Circuit at 0x153f4ffd3d0>,
#  <__main__.Circuit at 0x153f4ffdb50>,
#  <__main__.Circuit at 0x153f4ffdd00>,
#  <__main__.Circuit at 0x153f4ffe3c0>,
#  <__main__.Circuit at 0x153f4ffe750>,
#  <__main__.Circuit at 0x153f4ffed50>,
#  <__main__.Circuit at 0x153f4fff7a0>,
#  <__main__.Circuit at 0x153f50282c0>,
#  <__main__.Circuit at 0x153f50287a0>,
#  <__main__.Circuit at 0x153f5028bc0>,
#  <__main__.Circuit at 0x153f5028fe0>,
#  <__main__.Circuit at 0x153f5029820>,
#  <__main__.Circuit at 0x153f5029d60>,
#  <__main__.Circuit at 0x153f502a5d0>,
#  <__main__.Circuit at 0x153f502ab10>,
#  <__main__.Circuit at 0x153f502ab40>,
#  <__main__.Circuit at 0x153f502b2c0>,
#  <__main__.Circuit at 0x153f502b980>,
#  <__main__.Circuit at 0x153f504c590>,
#  <__main__.Circuit at 0x153f504ce90>,
#  <__main__.Circuit at 0x153f504d700>,
#  <__main__.Circuit at 0x153f504dac0>,
#  <__main__.Circuit at 0x153f504dc10>,
#  <__main__.Circuit at 0x153f504e690>,
#  <__main__.Circuit at 0x153f504f230>,
#  <__main__.Circuit at 0x153f504f9e0>,
#  <__main__.Circuit at 0x153f504fe90>,
#  <__main__.Circuit at 0x153f50707a0>,
#  <__main__.Circuit at 0x153f50710a0>,
#  <__main__.Circuit at 0x153f5071a60>,
#  <__main__.Circuit at 0x153f5071a90>,
#  <__main__.Circuit at 0x153f5071ac0>,
#  <__main__.Circuit at 0x153f50726c0>,
#  <__main__.Circuit at 0x153f5072a50>,
#  <__main__.Circuit at 0x153f5072d20>,
#  <__main__.Circuit at 0x153f5073170>,
#  <__main__.Circuit at 0x153f5073b00>,
#  <__main__.Circuit at 0x153f5098170>,
#  <__main__.Circuit at 0x153f50981a0>,
#  <__main__.Circuit at 0x153f50981d0>,
#  <__main__.Circuit at 0x153f5098920>,
#  <__main__.Circuit at 0x153f5099520>,
#  <__main__.Circuit at 0x153f5099f10>,
#  <__main__.Circuit at 0x153f509a1b0>,
#  <__main__.Circuit at 0x153f509ae10>,
#  <__main__.Circuit at 0x153f509ba70>,
#  <__main__.Circuit at 0x153f509bc20>,
#  <__main__.Circuit at 0x153f50c4710>,
#  <__main__.Circuit at 0x153f50c53d0>,
#  <__main__.Circuit at 0x153f50c56d0>,
#  <__main__.Circuit at 0x153f50c5700>,
#  <__main__.Circuit at 0x153f50c5e50>,
#  <__main__.Circuit at 0x153f50c6210>,
#  <__main__.Circuit at 0x153f50c6810>,
#  <__main__.Circuit at 0x153f50c6840>,
#  <__main__.Circuit at 0x153f50c6990>,
#  <__main__.Circuit at 0x153f50c7440>,
#  <__main__.Circuit at 0x153f50c7e60>,
#  <__main__.Circuit at 0x153f50ec5f0>,
#  <__main__.Circuit at 0x153f50ece30>,
#  <__main__.Circuit at 0x153f50ed6a0>,
#  <__main__.Circuit at 0x153f50edd90>,
#  <__main__.Circuit at 0x153f50eddc0>,
#  <__main__.Circuit at 0x153f50ee360>,
#  <__main__.Circuit at 0x153f50ee990>,
#  <__main__.Circuit at 0x153f50eef60>,
#  <__main__.Circuit at 0x153f50ef6e0>,
#  <__main__.Circuit at 0x153f50eff80>,
#  <__main__.Circuit at 0x153f510cc20>,
#  <__main__.Circuit at 0x153f510cf20>,
#  <__main__.Circuit at 0x153f510d760>,
#  <__main__.Circuit at 0x153f510e060>,
#  <__main__.Circuit at 0x153f510e4b0>,
#  <__main__.Circuit at 0x153f510ec60>,
#  <__main__.Circuit at 0x153f510ed80>,
#  <__main__.Circuit at 0x153f510f170>,
#  <__main__.Circuit at 0x153f510f1a0>,
#  <__main__.Circuit at 0x153f510f530>,
#  <__main__.Circuit at 0x153f510fc20>,
#  <__main__.Circuit at 0x153f5134140>,
#  <__main__.Circuit at 0x153f5134950>,
#  <__main__.Circuit at 0x153f5134ad0>,
#  <__main__.Circuit at 0x153f51350a0>,
#  <__main__.Circuit at 0x153f51358e0>,
#  <__main__.Circuit at 0x153f5135910>,
#  <__main__.Circuit at 0x153f5135940>,
#  <__main__.Circuit at 0x153f5135970>,
#  <__main__.Circuit at 0x153f5135a60>,
#  <__main__.Circuit at 0x153f5136330>,
#  <__main__.Circuit at 0x153f5136480>,
#  <__main__.Circuit at 0x153f5136d50>,
#  <__main__.Circuit at 0x153f5137830>,
#  <__main__.Circuit at 0x153f5137cb0>,
#  <__main__.Circuit at 0x153f51600e0>,
#  <__main__.Circuit at 0x153f5160650>,
#  <__main__.Circuit at 0x153f5160da0>,
#  <__main__.Circuit at 0x153f5161670>,
#  <__main__.Circuit at 0x153f51622a0>,
#  <__main__.Circuit at 0x153f5162d20>,
#  <__main__.Circuit at 0x153f5163680>,
#  <__main__.Circuit at 0x153f51637d0>,
#  <__main__.Circuit at 0x153f5163980>,
#  <__main__.Circuit at 0x153f5188440>,
#  <__main__.Circuit at 0x153f5188c80>,
#  <__main__.Circuit at 0x153f5188cb0>,
#  <__main__.Circuit at 0x153f5188e00>,
#  <__main__.Circuit at 0x153f5189880>,
#  <__main__.Circuit at 0x153f5189ca0>,
#  <__main__.Circuit at 0x153f518a7b0>,
#  <__main__.Circuit at 0x153f518aea0>,
#  <__main__.Circuit at 0x153f518b380>,
#  <__main__.Circuit at 0x153f518b740>,
#  <__main__.Circuit at 0x153f518bdd0>,
#  <__main__.Circuit at 0x153f51b0950>,
#  <__main__.Circuit at 0x153f51b12b0>,
#  <__main__.Circuit at 0x153f51b12e0>,
#  <__main__.Circuit at 0x153f51b1c10>,
#  <__main__.Circuit at 0x153f51b28d0>,
#  <__main__.Circuit at 0x153f51b2e70>,
#  <__main__.Circuit at 0x153f51b2ea0>,
#  <__main__.Circuit at 0x153f51b3380>,
#  <__main__.Circuit at 0x153f51b3ef0>,
#  <__main__.Circuit at 0x153f51b3f20>,
#  <__main__.Circuit at 0x153f51b3f50>,
#  <__main__.Circuit at 0x153f51d40e0>,
#  <__main__.Circuit at 0x153f51d4ce0>,
#  <__main__.Circuit at 0x153f51d51c0>,
#  <__main__.Circuit at 0x153f51d5730>,
#  <__main__.Circuit at 0x153f51d5940>,
#  <__main__.Circuit at 0x153f51d6600>,
#  <__main__.Circuit at 0x153f51d71a0>,
#  <__main__.Circuit at 0x153f51d7c50>,
#  <__main__.Circuit at 0x153f51f8050>,
#  <__main__.Circuit at 0x153f51f8230>,
#  <__main__.Circuit at 0x153f51f8590>,
#  <__main__.Circuit at 0x153f51f8b00>,
#  <__main__.Circuit at 0x153f51f96a0>,
#  <__main__.Circuit at 0x153f51fa1e0>,
#  <__main__.Circuit at 0x153f51fa810>,
#  <__main__.Circuit at 0x153f51faa80>,
#  <__main__.Circuit at 0x153f51fb2f0>,
#  <__main__.Circuit at 0x153f51fbec0>,
#  <__main__.Circuit at 0x153f5224170>,
#  <__main__.Circuit at 0x153f5224710>,
#  <__main__.Circuit at 0x153f52249e0>,
#  <__main__.Circuit at 0x153f5224fe0>,
#  <__main__.Circuit at 0x153f5225010>,
#  <__main__.Circuit at 0x153f52253d0>,
#  <__main__.Circuit at 0x153f5225bb0>,
#  <__main__.Circuit at 0x153f5226360>,
#  <__main__.Circuit at 0x153f5226b70>,
#  <__main__.Circuit at 0x153f52274d0>,
#  <__main__.Circuit at 0x153f52275c0>,
#  <__main__.Circuit at 0x153f5227d40>,
#  <__main__.Circuit at 0x153f524c3b0>,
#  <__main__.Circuit at 0x153f524c3e0>,
#  <__main__.Circuit at 0x153f524c7d0>,
#  <__main__.Circuit at 0x153f524cd70>,
#  <__main__.Circuit at 0x153f524d6d0>,
#  <__main__.Circuit at 0x153f524db50>,
#  <__main__.Circuit at 0x153f524df10>,
#  <__main__.Circuit at 0x153f524e330>,
#  <__main__.Circuit at 0x153f524eab0>,
#  <__main__.Circuit at 0x153f524f6e0>,
#  <__main__.Circuit at 0x153f524fb00>,
#  <__main__.Circuit at 0x153f524fda0>,
#  <__main__.Circuit at 0x153f52701d0>,
#  <__main__.Circuit at 0x153f5270ce0>,
#  <__main__.Circuit at 0x153f5271970>,
#  <__main__.Circuit at 0x153f5271eb0>,
#  <__main__.Circuit at 0x153f52727b0>,
#  <__main__.Circuit at 0x153f5272ae0>,
#  <__main__.Circuit at 0x153f5272b10>,
#  <__main__.Circuit at 0x153f5272db0>,
#  <__main__.Circuit at 0x153f5272ff0>,
#  <__main__.Circuit at 0x153f5273b00>,
#  <__main__.Circuit at 0x153f5294080>,
#  <__main__.Circuit at 0x153f5294ce0>,
#  <__main__.Circuit at 0x153f5295940>,
#  <__main__.Circuit at 0x153f5295fa0>,
#  <__main__.Circuit at 0x153f5296450>,
#  <__main__.Circuit at 0x153f52967b0>,
#  <__main__.Circuit at 0x153f52967e0>,
#  <__main__.Circuit at 0x153f5296a80>,
#  <__main__.Circuit at 0x153f5296ab0>,
#  <__main__.Circuit at 0x153f52976e0>,
#  <__main__.Circuit at 0x153f52c0140>,
#  <__main__.Circuit at 0x153f52c0740>,
#  <__main__.Circuit at 0x153f52c0770>,
#  <__main__.Circuit at 0x153f52c0f50>,
#  <__main__.Circuit at 0x153f52c14c0>,
#  <__main__.Circuit at 0x153f52c1df0>,
#  <__main__.Circuit at 0x153f52c2780>,
#  <__main__.Circuit at 0x153f52c2a20>,
#  <__main__.Circuit at 0x153f52c3710>,
#  <__main__.Circuit at 0x153f52e40b0>,
#  <__main__.Circuit at 0x153f52e4d70>,
#  <__main__.Circuit at 0x153f52e5910>,
#  <__main__.Circuit at 0x153f52e6480>,
#  <__main__.Circuit at 0x153f52e6600>,
#  <__main__.Circuit at 0x153f52e6b70>,
#  <__main__.Circuit at 0x153f52e7200>,
#  <__main__.Circuit at 0x153f52e7e30>,
#  <__main__.Circuit at 0x153f52e7e60>,
#  <__main__.Circuit at 0x153f530c9e0>,
#  <__main__.Circuit at 0x153f530d070>,
#  <__main__.Circuit at 0x153f530d730>,
#  <__main__.Circuit at 0x153f530e0c0>,
#  <__main__.Circuit at 0x153f530e7e0>,
#  <__main__.Circuit at 0x153f530eb70>,
#  <__main__.Circuit at 0x153f530ef30>,
#  <__main__.Circuit at 0x153f530ef60>,
#  <__main__.Circuit at 0x153f530f2f0>,
#  <__main__.Circuit at 0x153f530fad0>,
#  <__main__.Circuit at 0x153f530fd10>,
#  <__main__.Circuit at 0x153f5338560>,
#  <__main__.Circuit at 0x153f53388c0>,
#  <__main__.Circuit at 0x153f5338ce0>,
#  <__main__.Circuit at 0x153f5339580>,
#  <__main__.Circuit at 0x153f5339c70>,
#  <__main__.Circuit at 0x153f533a270>,
#  <__main__.Circuit at 0x153f533a9c0>,
#  <__main__.Circuit at 0x153f533b080>,
#  <__main__.Circuit at 0x153f533b680>,
#  <__main__.Circuit at 0x153f53641a0>,
#  <__main__.Circuit at 0x153f5364680>,
#  <__main__.Circuit at 0x153f5364c20>,
#  <__main__.Circuit at 0x153f5365040>,
#  <__main__.Circuit at 0x153f53654f0>,
#  <__main__.Circuit at 0x153f5365a90>,
#  <__main__.Circuit at 0x153f5365ac0>,
#  <__main__.Circuit at 0x153f5366300>,
#  <__main__.Circuit at 0x153f5366750>,
#  <__main__.Circuit at 0x153f53668a0>,
#  <__main__.Circuit at 0x153f5366d80>,
#  <__main__.Circuit at 0x153f5367650>,
#  <__main__.Circuit at 0x153f53841d0>,
#  <__main__.Circuit at 0x153f5384d40>,
#  <__main__.Circuit at 0x153f5385130>,
#  <__main__.Circuit at 0x153f5385c70>,
#  <__main__.Circuit at 0x153f5385df0>,
#  <__main__.Circuit at 0x153f53866f0>,
#  <__main__.Circuit at 0x153f5386ae0>,
#  <__main__.Circuit at 0x153f5387320>,
#  <__main__.Circuit at 0x153f5387e90>,
#  <__main__.Circuit at 0x153f53ac4d0>,
#  <__main__.Circuit at 0x153f53ac8f0>,
#  <__main__.Circuit at 0x153f53acad0>,
#  <__main__.Circuit at 0x153f53ad250>,
#  <__main__.Circuit at 0x153f53ad3d0>,
#  <__main__.Circuit at 0x153f53adb20>,
#  <__main__.Circuit at 0x153f53add30>,
#  <__main__.Circuit at 0x153f53ae450>,
#  <__main__.Circuit at 0x153f53ae630>,
#  <__main__.Circuit at 0x153f53ae660>,
#  <__main__.Circuit at 0x153f53aee70>,
#  <__main__.Circuit at 0x153f53af740>,
#  <__main__.Circuit at 0x153f53afc20>,
#  <__main__.Circuit at 0x153f53d4650>,
#  <__main__.Circuit at 0x153f53d4680>,
#  <__main__.Circuit at 0x153f53d4800>,
#  <__main__.Circuit at 0x153f53d4b60>,
#  <__main__.Circuit at 0x153f53d57c0>,
#  <__main__.Circuit at 0x153f53d5e20>,
#  <__main__.Circuit at 0x153f53d6330>,
#  <__main__.Circuit at 0x153f53d6ab0>,
#  <__main__.Circuit at 0x153f53d7200>,
#  <__main__.Circuit at 0x153f53d78f0>,
#  <__main__.Circuit at 0x153f53d7a70>,
#  <__main__.Circuit at 0x153f53d7f50>,
#  <__main__.Circuit at 0x153f53f8110>,
#  <__main__.Circuit at 0x153f53f8650>,
#  <__main__.Circuit at 0x153f53f8d70>,
#  <__main__.Circuit at 0x153f53f93a0>,
#  <__main__.Circuit at 0x153f53f9fd0>,
#  <__main__.Circuit at 0x153f53fa9c0>,
#  <__main__.Circuit at 0x153f53faf00>,
#  <__main__.Circuit at 0x153f53fb1a0>,
#  <__main__.Circuit at 0x153f53fb860>,
#  <__main__.Circuit at 0x153f53fb9b0>,
#  <__main__.Circuit at 0x153f53fbd40>,
#  <__main__.Circuit at 0x153f5428380>,
#  <__main__.Circuit at 0x153f5428fb0>,
#  <__main__.Circuit at 0x153f5429760>,
#  <__main__.Circuit at 0x153f5429790>,
#  <__main__.Circuit at 0x153f5429eb0>,
#  <__main__.Circuit at 0x153f542aae0>,
#  <__main__.Circuit at 0x153f542b800>,
#  <__main__.Circuit at 0x153f542ba40>,
#  <__main__.Circuit at 0x153f5450650>,
#  <__main__.Circuit at 0x153f5450a40>,
#  <__main__.Circuit at 0x153f5450a70>,
#  <__main__.Circuit at 0x153f5450bf0>,
#  <__main__.Circuit at 0x153f5451640>,
#  <__main__.Circuit at 0x153f5451790>,
#  <__main__.Circuit at 0x153f54517c0>,
#  <__main__.Circuit at 0x153f5452330>,
#  <__main__.Circuit at 0x153f5452f90>,
#  <__main__.Circuit at 0x153f5453980>,
#  <__main__.Circuit at 0x153f5453ec0>,
#  <__main__.Circuit at 0x153f54705f0>,
#  <__main__.Circuit at 0x153f5470fb0>,
#  <__main__.Circuit at 0x153f5471490>,
#  <__main__.Circuit at 0x153f5471730>,
#  <__main__.Circuit at 0x153f5471a00>,
#  <__main__.Circuit at 0x153f5471a30>,
#  <__main__.Circuit at 0x153f5471f40>,
#  <__main__.Circuit at 0x153f5472810>,
#  <__main__.Circuit at 0x153f5472b10>,
#  <__main__.Circuit at 0x153f5473200>,
#  <__main__.Circuit at 0x153f5473590>,
#  <__main__.Circuit at 0x153f54735c0>,
#  <__main__.Circuit at 0x153f5473ef0>,
#  <__main__.Circuit at 0x153f54989b0>,
#  <__main__.Circuit at 0x153f5498dd0>,
#  <__main__.Circuit at 0x153f54997f0>,
#  <__main__.Circuit at 0x153f5499a90>,
#  <__main__.Circuit at 0x153f5499e50>,
#  <__main__.Circuit at 0x153f5499e80>,
#  <__main__.Circuit at 0x153f549aa80>,
#  <__main__.Circuit at 0x153f549aab0>,
#  <__main__.Circuit at 0x153f549af90>,
#  <__main__.Circuit at 0x153f549afc0>,
#  <__main__.Circuit at 0x153f549b6e0>,
#  <__main__.Circuit at 0x153f549b950>,
#  <__main__.Circuit at 0x153f54c44a0>,
#  <__main__.Circuit at 0x153f54c4f80>,
#  <__main__.Circuit at 0x153f54c5700>,
#  <__main__.Circuit at 0x153f54c5ca0>,
#  <__main__.Circuit at 0x153f54c61b0>,
#  <__main__.Circuit at 0x153f54c6510>,
#  <__main__.Circuit at 0x153f54c7020>,
#  <__main__.Circuit at 0x153f54c74d0>,
#  <__main__.Circuit at 0x153f54c7cb0>,
#  <__main__.Circuit at 0x153f54e83b0>,
#  <__main__.Circuit at 0x153f54e8980>,
#  <__main__.Circuit at 0x153f54e9610>,
#  <__main__.Circuit at 0x153f54e9640>,
#  <__main__.Circuit at 0x153f54e9e80>,
#  <__main__.Circuit at 0x153f54ea9f0>,
#  <__main__.Circuit at 0x153f54eab40>,
#  <__main__.Circuit at 0x153f54eb080>,
#  <__main__.Circuit at 0x153f54eb230>,
#  <__main__.Circuit at 0x153f54ebda0>,
#  <__main__.Circuit at 0x153f54ebf20>,
#  <__main__.Circuit at 0x153f5510710>,
#  <__main__.Circuit at 0x153f5510da0>,
#  <__main__.Circuit at 0x153f5511700>,
#  <__main__.Circuit at 0x153f5512180>,
#  <__main__.Circuit at 0x153f5512510>,
#  <__main__.Circuit at 0x153f5512cf0>,
#  <__main__.Circuit at 0x153f5513590>,
#  <__main__.Circuit at 0x153f5513ad0>,
#  <__main__.Circuit at 0x153f5538230>,
#  <__main__.Circuit at 0x153f5538e00>,
#  <__main__.Circuit at 0x153f55395e0>,
#  <__main__.Circuit at 0x153f5539af0>,
#  <__main__.Circuit at 0x153f553a750>,
#  <__main__.Circuit at 0x153f553a9c0>,
#  <__main__.Circuit at 0x153f553af00>,
#  <__main__.Circuit at 0x153f553af30>,
#  <__main__.Circuit at 0x153f553ba40>,
#  <__main__.Circuit at 0x153f553bb90>,
#  <__main__.Circuit at 0x153f553bf80>,
#  <__main__.Circuit at 0x153f5564b90>,
#  <__main__.Circuit at 0x153f5564bc0>,
#  <__main__.Circuit at 0x153f5565910>,
#  <__main__.Circuit at 0x153f5565940>,
#  <__main__.Circuit at 0x153f5565ac0>,
#  <__main__.Circuit at 0x153f5566630>,
#  <__main__.Circuit at 0x153f5567020>,
#  <__main__.Circuit at 0x153f5567bc0>,
#  <__main__.Circuit at 0x153f5584440>,
#  <__main__.Circuit at 0x153f55848c0>,
#  <__main__.Circuit at 0x153f5584d70>,
#  <__main__.Circuit at 0x153f5585640>,
#  <__main__.Circuit at 0x153f5585a90>,
#  <__main__.Circuit at 0x153f5585ee0>,
#  <__main__.Circuit at 0x153f5586060>,
#  <__main__.Circuit at 0x153f5586840>,
#  <__main__.Circuit at 0x153f5586d20>,
#  <__main__.Circuit at 0x153f5586fc0>,
#  <__main__.Circuit at 0x153f5587710>,
#  <__main__.Circuit at 0x153f5587a10>,
#  <__main__.Circuit at 0x153f5587f80>,
#  <__main__.Circuit at 0x153f55ac890>,
#  <__main__.Circuit at 0x153f55ad1f0>,
#  <__main__.Circuit at 0x153f55ad5b0>,
#  <__main__.Circuit at 0x153f55adb50>,
#  <__main__.Circuit at 0x153f55ae270>,
#  <__main__.Circuit at 0x153f55ae960>,
#  <__main__.Circuit at 0x153f55af3e0>,
#  <__main__.Circuit at 0x153f55afbc0>,
#  <__main__.Circuit at 0x153f55afbf0>,
#  <__main__.Circuit at 0x153f55d4200>,
#  <__main__.Circuit at 0x153f55d4920>,
#  <__main__.Circuit at 0x153f55d4a40>,
#  <__main__.Circuit at 0x153f55d5310>,
#  <__main__.Circuit at 0x153f55d5d60>,
#  <__main__.Circuit at 0x153f55d6210>,
#  <__main__.Circuit at 0x153f55d6720>,
#  <__main__.Circuit at 0x153f55d6a20>,
#  <__main__.Circuit at 0x153f55d7350>,
#  <__main__.Circuit at 0x153f55d7c20>,
#  <__main__.Circuit at 0x153f55fc770>,
#  <__main__.Circuit at 0x153f55fd3d0>,
#  <__main__.Circuit at 0x153f55fda00>,
#  <__main__.Circuit at 0x153f55fe480>,
#  <__main__.Circuit at 0x153f55feea0>,
#  <__main__.Circuit at 0x153f55ff290>,
#  <__main__.Circuit at 0x153f55ffd40>,
#  <__main__.Circuit at 0x153f5624860>,
#  <__main__.Circuit at 0x153f5624d70>,
#  <__main__.Circuit at 0x153f5624e90>,
#  <__main__.Circuit at 0x153f5625550>,
#  <__main__.Circuit at 0x153f5625e20>,
#  <__main__.Circuit at 0x153f56266f0>,
#  <__main__.Circuit at 0x153f56269c0>,
#  <__main__.Circuit at 0x153f5627290>,
#  <__main__.Circuit at 0x153f5627410>,
#  <__main__.Circuit at 0x153f5627d40>,
#  <__main__.Circuit at 0x153f5650770>,
#  <__main__.Circuit at 0x153f5650d40>,
#  <__main__.Circuit at 0x153f56516d0>,
#  <__main__.Circuit at 0x153f5651d30>,
#  <__main__.Circuit at 0x153f5652330>,
#  <__main__.Circuit at 0x153f56526f0>,
#  <__main__.Circuit at 0x153f5653020>,
#  <__main__.Circuit at 0x153f5653c50>,
#  <__main__.Circuit at 0x153f5670170>,
#  <__main__.Circuit at 0x153f5670920>,
#  <__main__.Circuit at 0x153f5670fb0>,
#  <__main__.Circuit at 0x153f56710d0>,
#  <__main__.Circuit at 0x153f5671550>,
#  <__main__.Circuit at 0x153f56716a0>,
#  <__main__.Circuit at 0x153f56716d0>,
#  <__main__.Circuit at 0x153f56718e0>,
#  <__main__.Circuit at 0x153f5671ca0>,
#  <__main__.Circuit at 0x153f5672960>,
#  <__main__.Circuit at 0x153f5672ea0>,
#  <__main__.Circuit at 0x153f5672ff0>,
#  <__main__.Circuit at 0x153f5673cb0>,
#  <__main__.Circuit at 0x153f5698320>,
#  <__main__.Circuit at 0x153f56987d0>,
#  <__main__.Circuit at 0x153f5698f20>,
#  <__main__.Circuit at 0x153f5699a00>,
#  <__main__.Circuit at 0x153f569a390>,
#  <__main__.Circuit at 0x153f569aba0>,
#  <__main__.Circuit at 0x153f569af30>,
#  <__main__.Circuit at 0x153f569b0b0>,
#  <__main__.Circuit at 0x153f569bc20>,
#  <__main__.Circuit at 0x153f56c48f0>,
#  <__main__.Circuit at 0x153f56c5220>,
#  <__main__.Circuit at 0x153f56c5a30>,
#  <__main__.Circuit at 0x153f56c6630>,
#  <__main__.Circuit at 0x153f56c68a0>,
#  <__main__.Circuit at 0x153f56c7020>,
#  <__main__.Circuit at 0x153f56c73b0>,
#  <__main__.Circuit at 0x153f56c7530>,
#  <__main__.Circuit at 0x153f56c7a40>,
#  <__main__.Circuit at 0x153f56e8560>,
#  <__main__.Circuit at 0x153f56e89e0>,
#  <__main__.Circuit at 0x153f56e9070>,
#  <__main__.Circuit at 0x153f56e9520>,
#  <__main__.Circuit at 0x153f56e9910>,
#  <__main__.Circuit at 0x153f56ea3f0>,
#  <__main__.Circuit at 0x153f56ea420>,
#  <__main__.Circuit at 0x153f56ea5a0>,
#  <__main__.Circuit at 0x153f56eafc0>,
#  <__main__.Circuit at 0x153f56eb500>,
#  <__main__.Circuit at 0x153f56eb830>,
#  <__main__.Circuit at 0x153f56ebb90>,
#  <__main__.Circuit at 0x153f5710410>,
#  <__main__.Circuit at 0x153f5710f50>,
#  <__main__.Circuit at 0x153f5711b50>,
#  <__main__.Circuit at 0x153f5712720>,
#  <__main__.Circuit at 0x153f5712b40>,
#  <__main__.Circuit at 0x153f57136b0>,
#  <__main__.Circuit at 0x153f5713920>,
#  <__main__.Circuit at 0x153f573c200>,
#  <__main__.Circuit at 0x153f573c6e0>,
#  <__main__.Circuit at 0x153f573cd70>,
#  <__main__.Circuit at 0x153f573d0a0>,
#  <__main__.Circuit at 0x153f573d4c0>,
#  <__main__.Circuit at 0x153f573dee0>,
#  <__main__.Circuit at 0x153f573e540>,
#  <__main__.Circuit at 0x153f573ebd0>,
#  <__main__.Circuit at 0x153f573f620>,
#  <__main__.Circuit at 0x153f573fda0>,
#  <__main__.Circuit at 0x153f5760170>,
#  <__main__.Circuit at 0x153f5760cb0>,
#  <__main__.Circuit at 0x153f5760ce0>,
#  <__main__.Circuit at 0x153f5760d10>,
#  <__main__.Circuit at 0x153f57616d0>,
#  <__main__.Circuit at 0x153f57622d0>,
#  <__main__.Circuit at 0x153f5762d20>,
#  <__main__.Circuit at 0x153f5762d50>,
#  <__main__.Circuit at 0x153f5763890>,
#  <__main__.Circuit at 0x153f5763b00>,
#  <__main__.Circuit at 0x153f5763d40>,
#  <__main__.Circuit at 0x153f5763e60>,
#  <__main__.Circuit at 0x153f5784500>,
#  <__main__.Circuit at 0x153f5784c50>,
#  <__main__.Circuit at 0x153f5784f20>,
#  <__main__.Circuit at 0x153f5785a60>,
#  <__main__.Circuit at 0x153f5785a90>,
#  <__main__.Circuit at 0x153f5785eb0>,
#  <__main__.Circuit at 0x153f5786840>,
#  <__main__.Circuit at 0x153f57869c0>,
#  <__main__.Circuit at 0x153f5787260>,
#  <__main__.Circuit at 0x153f5787b00>,
#  <__main__.Circuit at 0x153f57ac680>,
#  <__main__.Circuit at 0x153f57acbf0>,
#  <__main__.Circuit at 0x153f57acf80>,
#  <__main__.Circuit at 0x153f57ad400>,
#  <__main__.Circuit at 0x153f57add60>,
#  <__main__.Circuit at 0x153f57ae6c0>,
#  <__main__.Circuit at 0x153f57aedb0>,
#  <__main__.Circuit at 0x153f57af6b0>,
#  <__main__.Circuit at 0x153f57af800>,
#  <__main__.Circuit at 0x153f57afdd0>,
#  <__main__.Circuit at 0x153f57d8ad0>,
#  <__main__.Circuit at 0x153f57d9280>,
#  <__main__.Circuit at 0x153f57d9d60>,
#  <__main__.Circuit at 0x153f57da7e0>,
#  <__main__.Circuit at 0x153f57db140>,
#  <__main__.Circuit at 0x153f57dbc80>,
#  <__main__.Circuit at 0x153f57fc890>,
#  <__main__.Circuit at 0x153f57fce90>,
#  ...]

# %%
simulator = Aer.get_backend('statevector_simulator')
def criar_circuito(num_qubits, num_gates_por_qubit):
    qc = QuantumCircuit(num_qubits, num_gates_por_qubit)
    for qubit in range(num_qubits):
        for _ in range(num_gates_por_qubit):
            qc.h(qubit)  # Aplicando a porta de Hadamard como exemplo
    #qc.measure_all()
    return qc
def simular_circuito(qc, simulador):
    qc_simulator = transpile(qc, backend=simulador)
    job = simulador.run(qc_simulator, shots=1024)
    return job

# %%
qc_1 = criar_circuito(3, 0)
qc_2 = criar_circuito(3, 0)

# %%
qc_1.draw()
qc_1.r()
# Out:
#
# q_0:
#
# q_1:
#
# q_2:

# %%
qc_2.draw()
# Out:
#
# q_0:
#
# q_1:
#
# q_2:

# %%
#job_1 = simular_circuito(qc_1, simulator)
sv2 = Statevector.from_label("000")
sv2 = sv2.evolve(qc_2)
#job_1 = simular_circuito(qc_1, simulator)
sv1 = Statevector.from_label("000")
sv1 = sv1.evolve(qc_1)
state_fidelity(sv1, sv2)
# Out:
# 1.0

# %%
#job_2 = simular_circuito(qc_2, simulator)

# %%
result = job_1.result()

# %%
result.get_statevector()
# Out:
# Statevector([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2, 2))

# %%
result1 = job_2.result()

# %%
result1.get_statevector()
# Out:
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2, 2))

# %%
import matplotlib.pyplot as plt
import numpy as np

# Supondo que o statevector já esteja calculado e armazenado em uma lista


# Calculando as probabilidades
probabilities = np.abs(statevector)**2

# Criando os rótulos dos estados computacionais (ajuste conforme necessário)
states = ['0', '1']

# Criando o gráfico de barras
plt.bar(states, probabilities)
plt.xlabel('Computational basis states')
plt.ylabel('Amplitude')
plt.title('Probabilities')
plt.show()

# %%
statevector = result.get_statevector() # Substitua pelos seus valores
statevector2 = result1.get_statevector()
state_fidelity(statevector, statevector2)
# Out:
# 0.0
