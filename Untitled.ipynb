# %%
from qiskit import QuantumCircuit, transpile
from qiskit.quantum_info import Statevector, state_fidelity
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from qiskit_aer import Aer
import time
import numpy
import json
import random
import math

# %%
def openFile(gate):
    with open(gate, 'r') as f:
        data = dict(json.load(f))
    return data

# %%
PI = math.pi
SEED = 11
random.seed(SEED)
TARGET = []
STRUCTS_GATES = openFile("./configuration/gate.json")

# %%
class Circuit:
    def __init__(self, n_qubits, m_gates) -> None:
        self.n_qubits = n_qubits
        self.m_gates = m_gates
        self.matrix = [[None for _ in range(m_gates)] for _ in range(n_qubits)]
        self.fitness = None
        self.circuit = None

class Gate:
    def __init__(self, name:str, affected_qubits:list, control_qubits:list = [], target_qubits:list = [], parameters:list = []) -> None:
        self.name =  name
        self.affected_qubits = affected_qubits
        self.parameters = parameters
        self.control_qubits= control_qubits
        self.target_qubits= target_qubits

# %%
def createGateToListQubits(qubitsFree, structLocal):
    structLocal = {gateName: gateInfo for gateName, gateInfo in structLocal.items() if (gateName == "") or (gateInfo['affected_qubits'] <= len(qubitsFree))}
    gateName, gateInfo = random.choice(list(structLocal.items()))
    y = random.choice(qubitsFree)
    qubitsFree.remove(y)
    qubitsChoice = [y]
    qubitsTarget = []
    qubitsControl = []
    parameters = []
    if gateName:
        qubitsChoice = [y] + random.sample(qubitsFree, gateInfo['affected_qubits'] - 1)
        qubitsFree = list(set(qubitsFree).difference(qubitsChoice))
        qubitsControl = random.sample(qubitsChoice, gateInfo['control_qubits'])
        qubitsTarget = list(set(qubitsChoice).difference(qubitsControl))
        parameters = [random.uniform(0, 2) for _ in range(gateInfo['parameters'])]
    gate = Gate(gateName, qubitsChoice, qubitsControl, qubitsTarget, parameters)
    return gate, qubitsFree

def createCircuit(numQubits, maxDepth, minDepth):
    depth = random.randint(minDepth, maxDepth)
    circuit = Circuit(numQubits, depth)
    for x in range(depth):
        structLocal = STRUCTS_GATES.copy()
        qubitsFree = list(range(numQubits))
        while qubitsFree:
            gate, qubitsFree = createGateToListQubits(qubitsFree, structLocal)
            circuit.matrix[gate.affected_qubits[0]][x] = gate
    return circuit

def initialPopulation(numPopulation:int, numQubits:int, maxDepth:int, minDepth:int=0):
    population = []
    for _ in range(numPopulation):
        circuit = createCircuit(numQubits, maxDepth, minDepth)
        population.append(circuit)
    return population

def fidelityFitnessFunction(circuit):
    #job_1 = simular_circuito(qc_1, simulator)
    sv2 = Statevector.from_label("000")
    sv2 = sv2.evolve(qc_2)
    #job_1 = simular_circuito(qc_1, simulator)
    sv1 = Statevector.from_label("000")
    sv1 = sv1.evolve(qc_1)
    state_fidelity(sv1, sv2)

def parentSelection():
    pass
def crossover():
    pass
def mutation():
    pass
def survivorSelection():
    pass

# %%
#createPopulation(10,2, 5)
initialPopulation(10000, 3, 2)
# Out:
# [<__main__.Circuit at 0x23a948c7c50>,
#  <__main__.Circuit at 0x23a9488b950>,
#  <__main__.Circuit at 0x23acd9ec080>,
#  <__main__.Circuit at 0x23acd9ec380>,
#  <__main__.Circuit at 0x23acd9ec4a0>,
#  <__main__.Circuit at 0x23acd9ec500>,
#  <__main__.Circuit at 0x23acd9ec5f0>,
#  <__main__.Circuit at 0x23acd9ec620>,
#  <__main__.Circuit at 0x23acd9ec6e0>,
#  <__main__.Circuit at 0x23acd9ec7a0>,
#  <__main__.Circuit at 0x23acd9ec860>,
#  <__main__.Circuit at 0x23acd9ec890>,
#  <__main__.Circuit at 0x23acd9ec980>,
#  <__main__.Circuit at 0x23acd9eca10>,
#  <__main__.Circuit at 0x23acd9ecaa0>,
#  <__main__.Circuit at 0x23acd9ecad0>,
#  <__main__.Circuit at 0x23acd9ecb00>,
#  <__main__.Circuit at 0x23acd9ecb30>,
#  <__main__.Circuit at 0x23acd9ecbc0>,
#  <__main__.Circuit at 0x23acd9ecc50>,
#  <__main__.Circuit at 0x23acd9ecd10>,
#  <__main__.Circuit at 0x23acd9ecd40>,
#  <__main__.Circuit at 0x23acd9ecd70>,
#  <__main__.Circuit at 0x23acd9ecda0>,
#  <__main__.Circuit at 0x23acd9ecdd0>,
#  <__main__.Circuit at 0x23acd9ece30>,
#  <__main__.Circuit at 0x23acd9ece00>,
#  <__main__.Circuit at 0x23acd9ecef0>,
#  <__main__.Circuit at 0x23acd9ecfe0>,
#  <__main__.Circuit at 0x23acd9ed040>,
#  <__main__.Circuit at 0x23acd9ed0d0>,
#  <__main__.Circuit at 0x23acd9ed100>,
#  <__main__.Circuit at 0x23acd9ed220>,
#  <__main__.Circuit at 0x23acd9ed250>,
#  <__main__.Circuit at 0x23acd9ed370>,
#  <__main__.Circuit at 0x23acd9ed3a0>,
#  <__main__.Circuit at 0x23acd9ed3d0>,
#  <__main__.Circuit at 0x23acd9ed460>,
#  <__main__.Circuit at 0x23acd9ed4f0>,
#  <__main__.Circuit at 0x23acd9ed610>,
#  <__main__.Circuit at 0x23acd9ed640>,
#  <__main__.Circuit at 0x23acd9ed730>,
#  <__main__.Circuit at 0x23acd9ed7f0>,
#  <__main__.Circuit at 0x23acd9ed8b0>,
#  <__main__.Circuit at 0x23acd9eda00>,
#  <__main__.Circuit at 0x23acd9eda90>,
#  <__main__.Circuit at 0x23acd9edbb0>,
#  <__main__.Circuit at 0x23acd9edc70>,
#  <__main__.Circuit at 0x23acd9edd00>,
#  <__main__.Circuit at 0x23acd9edd30>,
#  <__main__.Circuit at 0x23acd9eddc0>,
#  <__main__.Circuit at 0x23acd9eddf0>,
#  <__main__.Circuit at 0x23acd9edee0>,
#  <__main__.Circuit at 0x23acd9edf70>,
#  <__main__.Circuit at 0x23acd9ee030>,
#  <__main__.Circuit at 0x23acd9ee090>,
#  <__main__.Circuit at 0x23acd9ee180>,
#  <__main__.Circuit at 0x23acd9ee1b0>,
#  <__main__.Circuit at 0x23acd9ee2a0>,
#  <__main__.Circuit at 0x23acd9ee2d0>,
#  <__main__.Circuit at 0x23acd9ee390>,
#  <__main__.Circuit at 0x23acd9ee420>,
#  <__main__.Circuit at 0x23acd9ee450>,
#  <__main__.Circuit at 0x23acd9ee480>,
#  <__main__.Circuit at 0x23acd9ee510>,
#  <__main__.Circuit at 0x23acd9ee540>,
#  <__main__.Circuit at 0x23acd9ee570>,
#  <__main__.Circuit at 0x23acd9ee660>,
#  <__main__.Circuit at 0x23acd9ee780>,
#  <__main__.Circuit at 0x23acd9ee810>,
#  <__main__.Circuit at 0x23acd9ee960>,
#  <__main__.Circuit at 0x23acd9eea20>,
#  <__main__.Circuit at 0x23acd9eea80>,
#  <__main__.Circuit at 0x23acd9eeba0>,
#  <__main__.Circuit at 0x23acd9eecf0>,
#  <__main__.Circuit at 0x23acd9eede0>,
#  <__main__.Circuit at 0x23acd9eee70>,
#  <__main__.Circuit at 0x23acd9eefc0>,
#  <__main__.Circuit at 0x23acd9eeff0>,
#  <__main__.Circuit at 0x23acd9ef020>,
#  <__main__.Circuit at 0x23acd9ef050>,
#  <__main__.Circuit at 0x23acd9ef0e0>,
#  <__main__.Circuit at 0x23acd9ef110>,
#  <__main__.Circuit at 0x23acd9ef140>,
#  <__main__.Circuit at 0x23acd9ef230>,
#  <__main__.Circuit at 0x23acd9ef320>,
#  <__main__.Circuit at 0x23acd9ef3b0>,
#  <__main__.Circuit at 0x23acd9ef4d0>,
#  <__main__.Circuit at 0x23acd9ef500>,
#  <__main__.Circuit at 0x23acd9ef620>,
#  <__main__.Circuit at 0x23acd9ef740>,
#  <__main__.Circuit at 0x23acd9ef800>,
#  <__main__.Circuit at 0x23acd9ef950>,
#  <__main__.Circuit at 0x23acd9efa40>,
#  <__main__.Circuit at 0x23acd9efad0>,
#  <__main__.Circuit at 0x23acd9efb00>,
#  <__main__.Circuit at 0x23a8542fef0>,
#  <__main__.Circuit at 0x23a852f8740>,
#  <__main__.Circuit at 0x23acd9ec050>,
#  <__main__.Circuit at 0x23acd9efc20>,
#  <__main__.Circuit at 0x23acd9efcb0>,
#  <__main__.Circuit at 0x23acd9efce0>,
#  <__main__.Circuit at 0x23acd9efd70>,
#  <__main__.Circuit at 0x23acd9efe30>,
#  <__main__.Circuit at 0x23acd9eff50>,
#  <__main__.Circuit at 0x23acd9effe0>,
#  <__main__.Circuit at 0x23acda0c050>,
#  <__main__.Circuit at 0x23acda0c140>,
#  <__main__.Circuit at 0x23acda0c170>,
#  <__main__.Circuit at 0x23acda0c1a0>,
#  <__main__.Circuit at 0x23acda0c260>,
#  <__main__.Circuit at 0x23acda0c380>,
#  <__main__.Circuit at 0x23acda0c410>,
#  <__main__.Circuit at 0x23acda0c4a0>,
#  <__main__.Circuit at 0x23acda0c4d0>,
#  <__main__.Circuit at 0x23acda0c560>,
#  <__main__.Circuit at 0x23acda0c620>,
#  <__main__.Circuit at 0x23acda0c6b0>,
#  <__main__.Circuit at 0x23acda0c740>,
#  <__main__.Circuit at 0x23acda0c770>,
#  <__main__.Circuit at 0x23acda0c7a0>,
#  <__main__.Circuit at 0x23acda0c7d0>,
#  <__main__.Circuit at 0x23acda0c860>,
#  <__main__.Circuit at 0x23acda0c920>,
#  <__main__.Circuit at 0x23acda0ca70>,
#  <__main__.Circuit at 0x23acda0caa0>,
#  <__main__.Circuit at 0x23acda0cb90>,
#  <__main__.Circuit at 0x23acda0cbf0>,
#  <__main__.Circuit at 0x23acda0cc50>,
#  <__main__.Circuit at 0x23acda0cd70>,
#  <__main__.Circuit at 0x23acda0cda0>,
#  <__main__.Circuit at 0x23acda0cdd0>,
#  <__main__.Circuit at 0x23acda0ce60>,
#  <__main__.Circuit at 0x23acda0cf80>,
#  <__main__.Circuit at 0x23acda0cfb0>,
#  <__main__.Circuit at 0x23acda0d0a0>,
#  <__main__.Circuit at 0x23acda0d190>,
#  <__main__.Circuit at 0x23acda0d1c0>,
#  <__main__.Circuit at 0x23acda0d1f0>,
#  <__main__.Circuit at 0x23acda0d280>,
#  <__main__.Circuit at 0x23acda0d370>,
#  <__main__.Circuit at 0x23acda0d3a0>,
#  <__main__.Circuit at 0x23acda0d3d0>,
#  <__main__.Circuit at 0x23acda0d400>,
#  <__main__.Circuit at 0x23acda0d4f0>,
#  <__main__.Circuit at 0x23acda0d520>,
#  <__main__.Circuit at 0x23acda0d5b0>,
#  <__main__.Circuit at 0x23acda0d5e0>,
#  <__main__.Circuit at 0x23acda0d610>,
#  <__main__.Circuit at 0x23acda0d6d0>,
#  <__main__.Circuit at 0x23acda0d700>,
#  <__main__.Circuit at 0x23acda0d7c0>,
#  <__main__.Circuit at 0x23acda0d850>,
#  <__main__.Circuit at 0x23acda0d940>,
#  <__main__.Circuit at 0x23acda0da60>,
#  <__main__.Circuit at 0x23acda0da90>,
#  <__main__.Circuit at 0x23acda0dbb0>,
#  <__main__.Circuit at 0x23acda0dd00>,
#  <__main__.Circuit at 0x23acda0dd90>,
#  <__main__.Circuit at 0x23acda0de50>,
#  <__main__.Circuit at 0x23acda0df10>,
#  <__main__.Circuit at 0x23acda0df40>,
#  <__main__.Circuit at 0x23acda0e000>,
#  <__main__.Circuit at 0x23acda0e030>,
#  <__main__.Circuit at 0x23acda0e060>,
#  <__main__.Circuit at 0x23acda0e120>,
#  <__main__.Circuit at 0x23acda0e240>,
#  <__main__.Circuit at 0x23acda0e360>,
#  <__main__.Circuit at 0x23acda0e390>,
#  <__main__.Circuit at 0x23acda0e4b0>,
#  <__main__.Circuit at 0x23acda0e4e0>,
#  <__main__.Circuit at 0x23acda0e570>,
#  <__main__.Circuit at 0x23acda0e6c0>,
#  <__main__.Circuit at 0x23acda0e7b0>,
#  <__main__.Circuit at 0x23acda0e870>,
#  <__main__.Circuit at 0x23acda0e990>,
#  <__main__.Circuit at 0x23acda0e9c0>,
#  <__main__.Circuit at 0x23acda0eab0>,
#  <__main__.Circuit at 0x23acda0eb40>,
#  <__main__.Circuit at 0x23acda0eb70>,
#  <__main__.Circuit at 0x23acda0ec00>,
#  <__main__.Circuit at 0x23acda0ec30>,
#  <__main__.Circuit at 0x23acda0ed20>,
#  <__main__.Circuit at 0x23acda0ed50>,
#  <__main__.Circuit at 0x23acda0ed80>,
#  <__main__.Circuit at 0x23acda0eea0>,
#  <__main__.Circuit at 0x23acda0efc0>,
#  <__main__.Circuit at 0x23acda0f050>,
#  <__main__.Circuit at 0x23acda0f0e0>,
#  <__main__.Circuit at 0x23acda0f170>,
#  <__main__.Circuit at 0x23acda0f290>,
#  <__main__.Circuit at 0x23acda0f380>,
#  <__main__.Circuit at 0x23acda0f470>,
#  <__main__.Circuit at 0x23acda0f4d0>,
#  <__main__.Circuit at 0x23acda0f530>,
#  <__main__.Circuit at 0x23acda0f590>,
#  <__main__.Circuit at 0x23acda0f650>,
#  <__main__.Circuit at 0x23acda0f740>,
#  <__main__.Circuit at 0x23acda0f830>,
#  <__main__.Circuit at 0x23acda0f860>,
#  <__main__.Circuit at 0x23acda0f890>,
#  <__main__.Circuit at 0x23acda0f920>,
#  <__main__.Circuit at 0x23acda0fa40>,
#  <__main__.Circuit at 0x23acda0fad0>,
#  <__main__.Circuit at 0x23acda0fbc0>,
#  <__main__.Circuit at 0x23acda0fce0>,
#  <__main__.Circuit at 0x23acda0fd70>,
#  <__main__.Circuit at 0x23acda0fe60>,
#  <__main__.Circuit at 0x23acda0fe90>,
#  <__main__.Circuit at 0x23acda0fec0>,
#  <__main__.Circuit at 0x23acda0fef0>,
#  <__main__.Circuit at 0x23acda34050>,
#  <__main__.Circuit at 0x23acda34110>,
#  <__main__.Circuit at 0x23acda34200>,
#  <__main__.Circuit at 0x23acda34350>,
#  <__main__.Circuit at 0x23acda34410>,
#  <__main__.Circuit at 0x23acda34500>,
#  <__main__.Circuit at 0x23acda34530>,
#  <__main__.Circuit at 0x23acda34620>,
#  <__main__.Circuit at 0x23acda34650>,
#  <__main__.Circuit at 0x23acda346e0>,
#  <__main__.Circuit at 0x23acda347a0>,
#  <__main__.Circuit at 0x23acda347d0>,
#  <__main__.Circuit at 0x23acda348f0>,
#  <__main__.Circuit at 0x23acda349b0>,
#  <__main__.Circuit at 0x23acda349e0>,
#  <__main__.Circuit at 0x23acda34a10>,
#  <__main__.Circuit at 0x23acda34ad0>,
#  <__main__.Circuit at 0x23acda34b00>,
#  <__main__.Circuit at 0x23acda34bc0>,
#  <__main__.Circuit at 0x23acda34c50>,
#  <__main__.Circuit at 0x23acda34c80>,
#  <__main__.Circuit at 0x23acda34d10>,
#  <__main__.Circuit at 0x23acda34dd0>,
#  <__main__.Circuit at 0x23acda34e60>,
#  <__main__.Circuit at 0x23acda34ec0>,
#  <__main__.Circuit at 0x23acda34f80>,
#  <__main__.Circuit at 0x23acda34fb0>,
#  <__main__.Circuit at 0x23acda34fe0>,
#  <__main__.Circuit at 0x23acda35010>,
#  <__main__.Circuit at 0x23acda350d0>,
#  <__main__.Circuit at 0x23a8542f3b0>,
#  <__main__.Circuit at 0x23acda351c0>,
#  <__main__.Circuit at 0x23acda352e0>,
#  <__main__.Circuit at 0x23acda353a0>,
#  <__main__.Circuit at 0x23acda353d0>,
#  <__main__.Circuit at 0x23acda35460>,
#  <__main__.Circuit at 0x23acda35490>,
#  <__main__.Circuit at 0x23acda354c0>,
#  <__main__.Circuit at 0x23acda35550>,
#  <__main__.Circuit at 0x23acda35640>,
#  <__main__.Circuit at 0x23acda35730>,
#  <__main__.Circuit at 0x23acda35790>,
#  <__main__.Circuit at 0x23acda357c0>,
#  <__main__.Circuit at 0x23acda35880>,
#  <__main__.Circuit at 0x23acda358e0>,
#  <__main__.Circuit at 0x23acda359a0>,
#  <__main__.Circuit at 0x23acda359d0>,
#  <__main__.Circuit at 0x23acda35a30>,
#  <__main__.Circuit at 0x23acda35a60>,
#  <__main__.Circuit at 0x23acda35b20>,
#  <__main__.Circuit at 0x23acda35b80>,
#  <__main__.Circuit at 0x23acda35c70>,
#  <__main__.Circuit at 0x23acda35ca0>,
#  <__main__.Circuit at 0x23acda35cd0>,
#  <__main__.Circuit at 0x23acda35df0>,
#  <__main__.Circuit at 0x23acda35e20>,
#  <__main__.Circuit at 0x23acda35f10>,
#  <__main__.Circuit at 0x23acda35f40>,
#  <__main__.Circuit at 0x23acda36000>,
#  <__main__.Circuit at 0x23acda36030>,
#  <__main__.Circuit at 0x23acda36090>,
#  <__main__.Circuit at 0x23acda36120>,
#  <__main__.Circuit at 0x23acda36150>,
#  <__main__.Circuit at 0x23acda361e0>,
#  <__main__.Circuit at 0x23acda36210>,
#  <__main__.Circuit at 0x23acda362a0>,
#  <__main__.Circuit at 0x23acda362d0>,
#  <__main__.Circuit at 0x23acda36360>,
#  <__main__.Circuit at 0x23acda36450>,
#  <__main__.Circuit at 0x23acda36510>,
#  <__main__.Circuit at 0x23acda36540>,
#  <__main__.Circuit at 0x23acda36600>,
#  <__main__.Circuit at 0x23acda36720>,
#  <__main__.Circuit at 0x23acda36810>,
#  <__main__.Circuit at 0x23acda36900>,
#  <__main__.Circuit at 0x23acda36930>,
#  <__main__.Circuit at 0x23acda36960>,
#  <__main__.Circuit at 0x23acda36a80>,
#  <__main__.Circuit at 0x23acda36b10>,
#  <__main__.Circuit at 0x23acda36b40>,
#  <__main__.Circuit at 0x23acda36c90>,
#  <__main__.Circuit at 0x23acda36d20>,
#  <__main__.Circuit at 0x23acda36d80>,
#  <__main__.Circuit at 0x23acda36ea0>,
#  <__main__.Circuit at 0x23acda36f00>,
#  <__main__.Circuit at 0x23acda36ff0>,
#  <__main__.Circuit at 0x23acda37020>,
#  <__main__.Circuit at 0x23acda37050>,
#  <__main__.Circuit at 0x23acda37080>,
#  <__main__.Circuit at 0x23acda370e0>,
#  <__main__.Circuit at 0x23acda37200>,
#  <__main__.Circuit at 0x23acda37230>,
#  <__main__.Circuit at 0x23acda37260>,
#  <__main__.Circuit at 0x23acda37290>,
#  <__main__.Circuit at 0x23acda373b0>,
#  <__main__.Circuit at 0x23acda373e0>,
#  <__main__.Circuit at 0x23acda374d0>,
#  <__main__.Circuit at 0x23acda37590>,
#  <__main__.Circuit at 0x23acda37650>,
#  <__main__.Circuit at 0x23acda376e0>,
#  <__main__.Circuit at 0x23acda37710>,
#  <__main__.Circuit at 0x23acda377a0>,
#  <__main__.Circuit at 0x23acda377d0>,
#  <__main__.Circuit at 0x23acda37860>,
#  <__main__.Circuit at 0x23acda37950>,
#  <__main__.Circuit at 0x23acda379e0>,
#  <__main__.Circuit at 0x23acda37a10>,
#  <__main__.Circuit at 0x23acda37aa0>,
#  <__main__.Circuit at 0x23acda37b90>,
#  <__main__.Circuit at 0x23acda37c80>,
#  <__main__.Circuit at 0x23acda37cb0>,
#  <__main__.Circuit at 0x23acda37ce0>,
#  <__main__.Circuit at 0x23acda37d10>,
#  <__main__.Circuit at 0x23acda37dd0>,
#  <__main__.Circuit at 0x23acda37e60>,
#  <__main__.Circuit at 0x23acda37f50>,
#  <__main__.Circuit at 0x23acda5c080>,
#  <__main__.Circuit at 0x23acda5c1a0>,
#  <__main__.Circuit at 0x23acda5c290>,
#  <__main__.Circuit at 0x23acda5c350>,
#  <__main__.Circuit at 0x23acda5c3e0>,
#  <__main__.Circuit at 0x23acda5c470>,
#  <__main__.Circuit at 0x23acda5c500>,
#  <__main__.Circuit at 0x23acda5c5c0>,
#  <__main__.Circuit at 0x23acda5c5f0>,
#  <__main__.Circuit at 0x23acda5c6b0>,
#  <__main__.Circuit at 0x23acda5c770>,
#  <__main__.Circuit at 0x23acda5c7a0>,
#  <__main__.Circuit at 0x23acda5c7d0>,
#  <__main__.Circuit at 0x23acda5c8f0>,
#  <__main__.Circuit at 0x23acda5c920>,
#  <__main__.Circuit at 0x23acda5ca10>,
#  <__main__.Circuit at 0x23acda5caa0>,
#  <__main__.Circuit at 0x23acda5cbf0>,
#  <__main__.Circuit at 0x23acda5ccb0>,
#  <__main__.Circuit at 0x23acda5cd40>,
#  <__main__.Circuit at 0x23acda5cd70>,
#  <__main__.Circuit at 0x23acda5ce60>,
#  <__main__.Circuit at 0x23acda5ce90>,
#  <__main__.Circuit at 0x23acda5cf20>,
#  <__main__.Circuit at 0x23acda5d040>,
#  <__main__.Circuit at 0x23acda5d0d0>,
#  <__main__.Circuit at 0x23acda5d1f0>,
#  <__main__.Circuit at 0x23acda5d220>,
#  <__main__.Circuit at 0x23acda5d2e0>,
#  <__main__.Circuit at 0x23acda5d3d0>,
#  <__main__.Circuit at 0x23acda5d4c0>,
#  <__main__.Circuit at 0x23acda5d550>,
#  <__main__.Circuit at 0x23acda5d610>,
#  <__main__.Circuit at 0x23acda5d700>,
#  <__main__.Circuit at 0x23acda5d730>,
#  <__main__.Circuit at 0x23acda5d760>,
#  <__main__.Circuit at 0x23acda5d790>,
#  <__main__.Circuit at 0x23acda5d880>,
#  <__main__.Circuit at 0x23acda5d910>,
#  <__main__.Circuit at 0x23acda5d940>,
#  <__main__.Circuit at 0x23acda5da90>,
#  <__main__.Circuit at 0x23acda5db50>,
#  <__main__.Circuit at 0x23acda5dc40>,
#  <__main__.Circuit at 0x23acda5dcd0>,
#  <__main__.Circuit at 0x23acda5dd60>,
#  <__main__.Circuit at 0x23acda5dd90>,
#  <__main__.Circuit at 0x23acda5de50>,
#  <__main__.Circuit at 0x23acda5df40>,
#  <__main__.Circuit at 0x23acda5e000>,
#  <__main__.Circuit at 0x23acda5e150>,
#  <__main__.Circuit at 0x23acda5e120>,
#  <__main__.Circuit at 0x23acda5e1e0>,
#  <__main__.Circuit at 0x23acda5e2d0>,
#  <__main__.Circuit at 0x23acda5e300>,
#  <__main__.Circuit at 0x23acda5e390>,
#  <__main__.Circuit at 0x23acda5e450>,
#  <__main__.Circuit at 0x23acda5e570>,
#  <__main__.Circuit at 0x23acda5e690>,
#  <__main__.Circuit at 0x23acda5e720>,
#  <__main__.Circuit at 0x23acda5e840>,
#  <__main__.Circuit at 0x23acda5e960>,
#  <__main__.Circuit at 0x23acda5e990>,
#  <__main__.Circuit at 0x23acda5ea20>,
#  <__main__.Circuit at 0x23acda5eb10>,
#  <__main__.Circuit at 0x23acda5ebd0>,
#  <__main__.Circuit at 0x23acda5ecf0>,
#  <__main__.Circuit at 0x23acda5edb0>,
#  <__main__.Circuit at 0x23acda5ede0>,
#  <__main__.Circuit at 0x23acda5eed0>,
#  <__main__.Circuit at 0x23acda5ef90>,
#  <__main__.Circuit at 0x23acda5f020>,
#  <__main__.Circuit at 0x23acda5f0b0>,
#  <__main__.Circuit at 0x23acda5f170>,
#  <__main__.Circuit at 0x23acda5f1a0>,
#  <__main__.Circuit at 0x23acda5f290>,
#  <__main__.Circuit at 0x23acda5f2c0>,
#  <__main__.Circuit at 0x23acda5f3e0>,
#  <__main__.Circuit at 0x23acda5f4a0>,
#  <__main__.Circuit at 0x23acda5f4d0>,
#  <__main__.Circuit at 0x23acda5f530>,
#  <__main__.Circuit at 0x23acda5f590>,
#  <__main__.Circuit at 0x23acda5f620>,
#  <__main__.Circuit at 0x23acda5f6e0>,
#  <__main__.Circuit at 0x23acda5f7d0>,
#  <__main__.Circuit at 0x23acda5f860>,
#  <__main__.Circuit at 0x23acda5f920>,
#  <__main__.Circuit at 0x23acda5f9b0>,
#  <__main__.Circuit at 0x23acda5faa0>,
#  <__main__.Circuit at 0x23acda5fbc0>,
#  <__main__.Circuit at 0x23acda5fc20>,
#  <__main__.Circuit at 0x23acda5fbf0>,
#  <__main__.Circuit at 0x23acda5fce0>,
#  <__main__.Circuit at 0x23acda5fd10>,
#  <__main__.Circuit at 0x23acda5fe00>,
#  <__main__.Circuit at 0x23acda5ff20>,
#  <__main__.Circuit at 0x23acda5ff50>,
#  <__main__.Circuit at 0x23acda5ff80>,
#  <__main__.Circuit at 0x23acda5ffb0>,
#  <__main__.Circuit at 0x23acda80080>,
#  <__main__.Circuit at 0x23acda80110>,
#  <__main__.Circuit at 0x23acda80200>,
#  <__main__.Circuit at 0x23acda80290>,
#  <__main__.Circuit at 0x23acda80380>,
#  <__main__.Circuit at 0x23acda80410>,
#  <__main__.Circuit at 0x23acda80500>,
#  <__main__.Circuit at 0x23acda80530>,
#  <__main__.Circuit at 0x23acda805f0>,
#  <__main__.Circuit at 0x23acda806e0>,
#  <__main__.Circuit at 0x23acda80710>,
#  <__main__.Circuit at 0x23acda80740>,
#  <__main__.Circuit at 0x23acda80770>,
#  <__main__.Circuit at 0x23acda80800>,
#  <__main__.Circuit at 0x23acda808f0>,
#  <__main__.Circuit at 0x23acda809e0>,
#  <__main__.Circuit at 0x23acda80a70>,
#  <__main__.Circuit at 0x23acda80aa0>,
#  <__main__.Circuit at 0x23acda80ad0>,
#  <__main__.Circuit at 0x23acda80b00>,
#  <__main__.Circuit at 0x23acda80b30>,
#  <__main__.Circuit at 0x23acda80c50>,
#  <__main__.Circuit at 0x23acda80cb0>,
#  <__main__.Circuit at 0x23acda80ce0>,
#  <__main__.Circuit at 0x23acda80d70>,
#  <__main__.Circuit at 0x23acda80e60>,
#  <__main__.Circuit at 0x23acda80f20>,
#  <__main__.Circuit at 0x23acda81010>,
#  <__main__.Circuit at 0x23acda81100>,
#  <__main__.Circuit at 0x23acda81190>,
#  <__main__.Circuit at 0x23acda811c0>,
#  <__main__.Circuit at 0x23acda812b0>,
#  <__main__.Circuit at 0x23acda81370>,
#  <__main__.Circuit at 0x23acda813a0>,
#  <__main__.Circuit at 0x23acda81490>,
#  <__main__.Circuit at 0x23acda814c0>,
#  <__main__.Circuit at 0x23acda81550>,
#  <__main__.Circuit at 0x23acda815e0>,
#  <__main__.Circuit at 0x23acda816a0>,
#  <__main__.Circuit at 0x23acda81760>,
#  <__main__.Circuit at 0x23acda81880>,
#  <__main__.Circuit at 0x23acda819a0>,
#  <__main__.Circuit at 0x23acda819d0>,
#  <__main__.Circuit at 0x23acda81a00>,
#  <__main__.Circuit at 0x23acda81b50>,
#  <__main__.Circuit at 0x23acda81c70>,
#  <__main__.Circuit at 0x23acda81d90>,
#  <__main__.Circuit at 0x23acda81dc0>,
#  <__main__.Circuit at 0x23acda81eb0>,
#  <__main__.Circuit at 0x23acda81fa0>,
#  <__main__.Circuit at 0x23acda82060>,
#  <__main__.Circuit at 0x23acda82150>,
#  <__main__.Circuit at 0x23acda821e0>,
#  <__main__.Circuit at 0x23acda822d0>,
#  <__main__.Circuit at 0x23acda82360>,
#  <__main__.Circuit at 0x23acda82480>,
#  <__main__.Circuit at 0x23acda82540>,
#  <__main__.Circuit at 0x23acda82570>,
#  <__main__.Circuit at 0x23acda82690>,
#  <__main__.Circuit at 0x23acda82720>,
#  <__main__.Circuit at 0x23acda82810>,
#  <__main__.Circuit at 0x23acda82840>,
#  <__main__.Circuit at 0x23acda828d0>,
#  <__main__.Circuit at 0x23acda829c0>,
#  <__main__.Circuit at 0x23acda82a50>,
#  <__main__.Circuit at 0x23acda82a80>,
#  <__main__.Circuit at 0x23acda82b70>,
#  <__main__.Circuit at 0x23acda82ba0>,
#  <__main__.Circuit at 0x23acda82c60>,
#  <__main__.Circuit at 0x23acda82d20>,
#  <__main__.Circuit at 0x23acda82db0>,
#  <__main__.Circuit at 0x23acda82de0>,
#  <__main__.Circuit at 0x23acda82e10>,
#  <__main__.Circuit at 0x23acda82e40>,
#  <__main__.Circuit at 0x23acda82ed0>,
#  <__main__.Circuit at 0x23acda82f00>,
#  <__main__.Circuit at 0x23acda82fc0>,
#  <__main__.Circuit at 0x23acda82ff0>,
#  <__main__.Circuit at 0x23acda83020>,
#  <__main__.Circuit at 0x23acda83170>,
#  <__main__.Circuit at 0x23acda831a0>,
#  <__main__.Circuit at 0x23acda83260>,
#  <__main__.Circuit at 0x23acda832f0>,
#  <__main__.Circuit at 0x23acda83320>,
#  <__main__.Circuit at 0x23acda833b0>,
#  <__main__.Circuit at 0x23acda83440>,
#  <__main__.Circuit at 0x23acda83590>,
#  <__main__.Circuit at 0x23acda836b0>,
#  <__main__.Circuit at 0x23acda836e0>,
#  <__main__.Circuit at 0x23acda837a0>,
#  <__main__.Circuit at 0x23acda837d0>,
#  <__main__.Circuit at 0x23acda83800>,
#  <__main__.Circuit at 0x23acda83890>,
#  <__main__.Circuit at 0x23acda83920>,
#  <__main__.Circuit at 0x23acda83a40>,
#  <__main__.Circuit at 0x23acda83ad0>,
#  <__main__.Circuit at 0x23acda83b60>,
#  <__main__.Circuit at 0x23acda83bf0>,
#  <__main__.Circuit at 0x23acda83c20>,
#  <__main__.Circuit at 0x23acda83d70>,
#  <__main__.Circuit at 0x23acda83e00>,
#  <__main__.Circuit at 0x23acda83e90>,
#  <__main__.Circuit at 0x23acda83f50>,
#  <__main__.Circuit at 0x23acdaa40b0>,
#  <__main__.Circuit at 0x23acdaa4170>,
#  <__main__.Circuit at 0x23acdaa4200>,
#  <__main__.Circuit at 0x23acdaa4290>,
#  <__main__.Circuit at 0x23acdaa4320>,
#  <__main__.Circuit at 0x23acdaa43e0>,
#  <__main__.Circuit at 0x23acdaa4530>,
#  <__main__.Circuit at 0x23acdaa45f0>,
#  <__main__.Circuit at 0x23acdaa46e0>,
#  <__main__.Circuit at 0x23acdaa4710>,
#  <__main__.Circuit at 0x23acdaa4830>,
#  <__main__.Circuit at 0x23acdaa4950>,
#  <__main__.Circuit at 0x23acdaa4a10>,
#  <__main__.Circuit at 0x23acdaa4a40>,
#  <__main__.Circuit at 0x23acdaa4b00>,
#  <__main__.Circuit at 0x23acdaa4b90>,
#  <__main__.Circuit at 0x23acdaa4bf0>,
#  <__main__.Circuit at 0x23acdaa4d10>,
#  <__main__.Circuit at 0x23acdaa4d40>,
#  <__main__.Circuit at 0x23acdaa4e60>,
#  <__main__.Circuit at 0x23acdaa4f50>,
#  <__main__.Circuit at 0x23acdaa4fe0>,
#  <__main__.Circuit at 0x23acdaa50d0>,
#  <__main__.Circuit at 0x23acdaa51c0>,
#  <__main__.Circuit at 0x23acdaa52e0>,
#  <__main__.Circuit at 0x23acdaa5400>,
#  <__main__.Circuit at 0x23acdaa5430>,
#  <__main__.Circuit at 0x23acdaa54f0>,
#  <__main__.Circuit at 0x23acdaa55b0>,
#  <__main__.Circuit at 0x23acdaa5640>,
#  <__main__.Circuit at 0x23acdaa5670>,
#  <__main__.Circuit at 0x23acdaa5730>,
#  <__main__.Circuit at 0x23acdaa5760>,
#  <__main__.Circuit at 0x23acdaa5850>,
#  <__main__.Circuit at 0x23acdaa58e0>,
#  <__main__.Circuit at 0x23acdaa5a00>,
#  <__main__.Circuit at 0x23acdaa5a90>,
#  <__main__.Circuit at 0x23acdaa5b80>,
#  <__main__.Circuit at 0x23acdaa5ca0>,
#  <__main__.Circuit at 0x23acdaa5d60>,
#  <__main__.Circuit at 0x23acdaa5e50>,
#  <__main__.Circuit at 0x23acdaa5e80>,
#  <__main__.Circuit at 0x23acdaa5eb0>,
#  <__main__.Circuit at 0x23acdaa5f40>,
#  <__main__.Circuit at 0x23acdaa5fd0>,
#  <__main__.Circuit at 0x23acdaa6000>,
#  <__main__.Circuit at 0x23acdaa6030>,
#  <__main__.Circuit at 0x23acdaa60f0>,
#  <__main__.Circuit at 0x23acdaa61b0>,
#  <__main__.Circuit at 0x23acdaa6240>,
#  <__main__.Circuit at 0x23acdaa62d0>,
#  <__main__.Circuit at 0x23acdaa63c0>,
#  <__main__.Circuit at 0x23acdaa64b0>,
#  <__main__.Circuit at 0x23acdaa6570>,
#  <__main__.Circuit at 0x23acdaa65a0>,
#  <__main__.Circuit at 0x23acdaa6630>,
#  <__main__.Circuit at 0x23acdaa6750>,
#  <__main__.Circuit at 0x23acdaa6810>,
#  <__main__.Circuit at 0x23acdaa6840>,
#  <__main__.Circuit at 0x23acdaa6960>,
#  <__main__.Circuit at 0x23acdaa6990>,
#  <__main__.Circuit at 0x23acdaa6ab0>,
#  <__main__.Circuit at 0x23acdaa6b40>,
#  <__main__.Circuit at 0x23acdaa6c00>,
#  <__main__.Circuit at 0x23acdaa6c60>,
#  <__main__.Circuit at 0x23acdaa6d80>,
#  <__main__.Circuit at 0x23acdaa6e40>,
#  <__main__.Circuit at 0x23acdaa6e70>,
#  <__main__.Circuit at 0x23acdaa6f30>,
#  <__main__.Circuit at 0x23acdaa7050>,
#  <__main__.Circuit at 0x23acdaa71a0>,
#  <__main__.Circuit at 0x23acdaa71d0>,
#  <__main__.Circuit at 0x23acdaa7200>,
#  <__main__.Circuit at 0x23acdaa7230>,
#  <__main__.Circuit at 0x23acdaa72f0>,
#  <__main__.Circuit at 0x23acdaa7410>,
#  <__main__.Circuit at 0x23acdaa7440>,
#  <__main__.Circuit at 0x23acdaa7530>,
#  <__main__.Circuit at 0x23acdaa75f0>,
#  <__main__.Circuit at 0x23acdaa7680>,
#  <__main__.Circuit at 0x23acdaa7740>,
#  <__main__.Circuit at 0x23acdaa7770>,
#  <__main__.Circuit at 0x23acdaa77a0>,
#  <__main__.Circuit at 0x23acdaa7800>,
#  <__main__.Circuit at 0x23acdaa78c0>,
#  <__main__.Circuit at 0x23acdaa78f0>,
#  <__main__.Circuit at 0x23acdaa7920>,
#  <__main__.Circuit at 0x23acdaa79e0>,
#  <__main__.Circuit at 0x23acdaa7b00>,
#  <__main__.Circuit at 0x23acdaa7b30>,
#  <__main__.Circuit at 0x23acdaa7bf0>,
#  <__main__.Circuit at 0x23acdaa7c20>,
#  <__main__.Circuit at 0x23acdaa7c50>,
#  <__main__.Circuit at 0x23acdaa7c80>,
#  <__main__.Circuit at 0x23acdaa7da0>,
#  <__main__.Circuit at 0x23acdaa7e60>,
#  <__main__.Circuit at 0x23acdaa7ef0>,
#  <__main__.Circuit at 0x23acdaa7f20>,
#  <__main__.Circuit at 0x23acdaa7fe0>,
#  <__main__.Circuit at 0x23acdacc080>,
#  <__main__.Circuit at 0x23acdacc1a0>,
#  <__main__.Circuit at 0x23acdacc230>,
#  <__main__.Circuit at 0x23acdacc2c0>,
#  <__main__.Circuit at 0x23acdacc350>,
#  <__main__.Circuit at 0x23acdacc470>,
#  <__main__.Circuit at 0x23acdacc590>,
#  <__main__.Circuit at 0x23acdacc650>,
#  <__main__.Circuit at 0x23acdacc770>,
#  <__main__.Circuit at 0x23acdacc860>,
#  <__main__.Circuit at 0x23acdacc980>,
#  <__main__.Circuit at 0x23acdaccaa0>,
#  <__main__.Circuit at 0x23acdaccb30>,
#  <__main__.Circuit at 0x23acdaccc50>,
#  <__main__.Circuit at 0x23acdaccd40>,
#  <__main__.Circuit at 0x23acdaccd70>,
#  <__main__.Circuit at 0x23acdacce60>,
#  <__main__.Circuit at 0x23acdaccef0>,
#  <__main__.Circuit at 0x23acdaccf80>,
#  <__main__.Circuit at 0x23acdacd040>,
#  <__main__.Circuit at 0x23acdacd190>,
#  <__main__.Circuit at 0x23acdacd250>,
#  <__main__.Circuit at 0x23acdacd2e0>,
#  <__main__.Circuit at 0x23acdacd3d0>,
#  <__main__.Circuit at 0x23acdacd460>,
#  <__main__.Circuit at 0x23acdacd520>,
#  <__main__.Circuit at 0x23acdacd5b0>,
#  <__main__.Circuit at 0x23acdacd5e0>,
#  <__main__.Circuit at 0x23acdacd610>,
#  <__main__.Circuit at 0x23acdacd6d0>,
#  <__main__.Circuit at 0x23acdacd760>,
#  <__main__.Circuit at 0x23acdacd7f0>,
#  <__main__.Circuit at 0x23acdacd880>,
#  <__main__.Circuit at 0x23acdacd940>,
#  <__main__.Circuit at 0x23acdacd9d0>,
#  <__main__.Circuit at 0x23acdacda00>,
#  <__main__.Circuit at 0x23acdacdac0>,
#  <__main__.Circuit at 0x23acdacdbb0>,
#  <__main__.Circuit at 0x23acdacdc10>,
#  <__main__.Circuit at 0x23acdacdca0>,
#  <__main__.Circuit at 0x23acdacdd00>,
#  <__main__.Circuit at 0x23acdacdd60>,
#  <__main__.Circuit at 0x23acdacdd90>,
#  <__main__.Circuit at 0x23acdacddc0>,
#  <__main__.Circuit at 0x23acdacde20>,
#  <__main__.Circuit at 0x23acdacdeb0>,
#  <__main__.Circuit at 0x23acdacdf40>,
#  <__main__.Circuit at 0x23acdacdf70>,
#  <__main__.Circuit at 0x23acdace060>,
#  <__main__.Circuit at 0x23acdace120>,
#  <__main__.Circuit at 0x23acdace240>,
#  <__main__.Circuit at 0x23acdace2d0>,
#  <__main__.Circuit at 0x23acdace3f0>,
#  <__main__.Circuit at 0x23acdace420>,
#  <__main__.Circuit at 0x23acdace450>,
#  <__main__.Circuit at 0x23acdace540>,
#  <__main__.Circuit at 0x23acdace570>,
#  <__main__.Circuit at 0x23acdace630>,
#  <__main__.Circuit at 0x23acdace6c0>,
#  <__main__.Circuit at 0x23acdace750>,
#  <__main__.Circuit at 0x23acdace780>,
#  <__main__.Circuit at 0x23acdace7b0>,
#  <__main__.Circuit at 0x23acdace870>,
#  <__main__.Circuit at 0x23acdace990>,
#  <__main__.Circuit at 0x23acdacea50>,
#  <__main__.Circuit at 0x23acdaceb10>,
#  <__main__.Circuit at 0x23acdaceba0>,
#  <__main__.Circuit at 0x23acdacec30>,
#  <__main__.Circuit at 0x23acdacec60>,
#  <__main__.Circuit at 0x23acdacec90>,
#  <__main__.Circuit at 0x23acdaced20>,
#  <__main__.Circuit at 0x23acdaced50>,
#  <__main__.Circuit at 0x23acdaced80>,
#  <__main__.Circuit at 0x23acdacee40>,
#  <__main__.Circuit at 0x23acdacee70>,
#  <__main__.Circuit at 0x23acdacef60>,
#  <__main__.Circuit at 0x23acdacf050>,
#  <__main__.Circuit at 0x23acdacf0e0>,
#  <__main__.Circuit at 0x23acdacf170>,
#  <__main__.Circuit at 0x23acdacf1a0>,
#  <__main__.Circuit at 0x23acdacf290>,
#  <__main__.Circuit at 0x23acdacf2f0>,
#  <__main__.Circuit at 0x23acdacf380>,
#  <__main__.Circuit at 0x23acdacf4d0>,
#  <__main__.Circuit at 0x23acdacf560>,
#  <__main__.Circuit at 0x23acdacf590>,
#  <__main__.Circuit at 0x23acdacf5f0>,
#  <__main__.Circuit at 0x23acdacf6e0>,
#  <__main__.Circuit at 0x23acdacf710>,
#  <__main__.Circuit at 0x23acdacf770>,
#  <__main__.Circuit at 0x23acdacf830>,
#  <__main__.Circuit at 0x23acdacf8c0>,
#  <__main__.Circuit at 0x23acdacf980>,
#  <__main__.Circuit at 0x23acdacfaa0>,
#  <__main__.Circuit at 0x23acdacfad0>,
#  <__main__.Circuit at 0x23acdacfb00>,
#  <__main__.Circuit at 0x23acdacfbf0>,
#  <__main__.Circuit at 0x23acdacfc20>,
#  <__main__.Circuit at 0x23acdacfc50>,
#  <__main__.Circuit at 0x23acdacfd70>,
#  <__main__.Circuit at 0x23acdacfe30>,
#  <__main__.Circuit at 0x23acdacfe90>,
#  <__main__.Circuit at 0x23acdacfec0>,
#  <__main__.Circuit at 0x23acdacff80>,
#  <__main__.Circuit at 0x23acdaec0b0>,
#  <__main__.Circuit at 0x23acdaec0e0>,
#  <__main__.Circuit at 0x23acdaec110>,
#  <__main__.Circuit at 0x23acdaec1d0>,
#  <__main__.Circuit at 0x23acdaec260>,
#  <__main__.Circuit at 0x23acdaec290>,
#  <__main__.Circuit at 0x23acdaec2c0>,
#  <__main__.Circuit at 0x23acdaec2f0>,
#  <__main__.Circuit at 0x23acdaec3e0>,
#  <__main__.Circuit at 0x23acdaec410>,
#  <__main__.Circuit at 0x23acdaec4a0>,
#  <__main__.Circuit at 0x23acdaec530>,
#  <__main__.Circuit at 0x23acdaec620>,
#  <__main__.Circuit at 0x23acdaec710>,
#  <__main__.Circuit at 0x23acdaec800>,
#  <__main__.Circuit at 0x23acdaec8f0>,
#  <__main__.Circuit at 0x23acdaec980>,
#  <__main__.Circuit at 0x23acdaeca40>,
#  <__main__.Circuit at 0x23acdaeca70>,
#  <__main__.Circuit at 0x23acdaecb00>,
#  <__main__.Circuit at 0x23acdaecc50>,
#  <__main__.Circuit at 0x23acdaecda0>,
#  <__main__.Circuit at 0x23acdaecdd0>,
#  <__main__.Circuit at 0x23acdaece00>,
#  <__main__.Circuit at 0x23acdaece30>,
#  <__main__.Circuit at 0x23acdaecec0>,
#  <__main__.Circuit at 0x23acdaecfe0>,
#  <__main__.Circuit at 0x23acdaed010>,
#  <__main__.Circuit at 0x23acdaed040>,
#  <__main__.Circuit at 0x23acdaed070>,
#  <__main__.Circuit at 0x23acdaed130>,
#  <__main__.Circuit at 0x23acdaed160>,
#  <__main__.Circuit at 0x23acdaed190>,
#  <__main__.Circuit at 0x23acdaed1f0>,
#  <__main__.Circuit at 0x23acdaed310>,
#  <__main__.Circuit at 0x23acdaed340>,
#  <__main__.Circuit at 0x23acdaed430>,
#  <__main__.Circuit at 0x23acdaed4c0>,
#  <__main__.Circuit at 0x23acdaed4f0>,
#  <__main__.Circuit at 0x23acdaed610>,
#  <__main__.Circuit at 0x23acdaed640>,
#  <__main__.Circuit at 0x23acdaed730>,
#  <__main__.Circuit at 0x23acdaed820>,
#  <__main__.Circuit at 0x23acdaed8b0>,
#  <__main__.Circuit at 0x23acdaed8e0>,
#  <__main__.Circuit at 0x23acdaed910>,
#  <__main__.Circuit at 0x23acdaed9a0>,
#  <__main__.Circuit at 0x23acdaed9d0>,
#  <__main__.Circuit at 0x23acdaedac0>,
#  <__main__.Circuit at 0x23acdaedbb0>,
#  <__main__.Circuit at 0x23acdaedc40>,
#  <__main__.Circuit at 0x23acdaedd60>,
#  <__main__.Circuit at 0x23acdaedeb0>,
#  <__main__.Circuit at 0x23acdaee000>,
#  <__main__.Circuit at 0x23acdaee030>,
#  <__main__.Circuit at 0x23acdaee090>,
#  <__main__.Circuit at 0x23acdaee150>,
#  <__main__.Circuit at 0x23acdaee210>,
#  <__main__.Circuit at 0x23acdaee240>,
#  <__main__.Circuit at 0x23acdaee270>,
#  <__main__.Circuit at 0x23acdaee2a0>,
#  <__main__.Circuit at 0x23acdaee390>,
#  <__main__.Circuit at 0x23acdaee420>,
#  <__main__.Circuit at 0x23acdaee570>,
#  <__main__.Circuit at 0x23acdaee5a0>,
#  <__main__.Circuit at 0x23acdaee630>,
#  <__main__.Circuit at 0x23acdaee780>,
#  <__main__.Circuit at 0x23acdaee7b0>,
#  <__main__.Circuit at 0x23acdaee7e0>,
#  <__main__.Circuit at 0x23acdaee8a0>,
#  <__main__.Circuit at 0x23acdaee8d0>,
#  <__main__.Circuit at 0x23acdaee960>,
#  <__main__.Circuit at 0x23acdaeea50>,
#  <__main__.Circuit at 0x23acdaeeb40>,
#  <__main__.Circuit at 0x23acdaeec30>,
#  <__main__.Circuit at 0x23acdaeecf0>,
#  <__main__.Circuit at 0x23acdaeed20>,
#  <__main__.Circuit at 0x23acdaeedb0>,
#  <__main__.Circuit at 0x23acdaeee70>,
#  <__main__.Circuit at 0x23acdaeeea0>,
#  <__main__.Circuit at 0x23acdaeeed0>,
#  <__main__.Circuit at 0x23acdaeeff0>,
#  <__main__.Circuit at 0x23acdaef020>,
#  <__main__.Circuit at 0x23acdaef110>,
#  <__main__.Circuit at 0x23acdaef170>,
#  <__main__.Circuit at 0x23acdaef200>,
#  <__main__.Circuit at 0x23acdaef2c0>,
#  <__main__.Circuit at 0x23acdaef3b0>,
#  <__main__.Circuit at 0x23acdaef3e0>,
#  <__main__.Circuit at 0x23acdaef530>,
#  <__main__.Circuit at 0x23acdaef650>,
#  <__main__.Circuit at 0x23acdaef680>,
#  <__main__.Circuit at 0x23acdaef740>,
#  <__main__.Circuit at 0x23acdaef7a0>,
#  <__main__.Circuit at 0x23acdaef830>,
#  <__main__.Circuit at 0x23acdaef8f0>,
#  <__main__.Circuit at 0x23acdaef950>,
#  <__main__.Circuit at 0x23acdaefa10>,
#  <__main__.Circuit at 0x23acdaefa40>,
#  <__main__.Circuit at 0x23acdaefb60>,
#  <__main__.Circuit at 0x23acdaefb90>,
#  <__main__.Circuit at 0x23acdaefcb0>,
#  <__main__.Circuit at 0x23acdaefce0>,
#  <__main__.Circuit at 0x23acdaefe30>,
#  <__main__.Circuit at 0x23acdaeff20>,
#  <__main__.Circuit at 0x23acdaeffe0>,
#  <__main__.Circuit at 0x23acdb180b0>,
#  <__main__.Circuit at 0x23acdb18170>,
#  <__main__.Circuit at 0x23acdb182c0>,
#  <__main__.Circuit at 0x23acdb18350>,
#  <__main__.Circuit at 0x23acdb18440>,
#  <__main__.Circuit at 0x23acdb184d0>,
#  <__main__.Circuit at 0x23acdb185c0>,
#  <__main__.Circuit at 0x23acdb186b0>,
#  <__main__.Circuit at 0x23acdb187d0>,
#  <__main__.Circuit at 0x23acdb18860>,
#  <__main__.Circuit at 0x23acdb188f0>,
#  <__main__.Circuit at 0x23acdb18920>,
#  <__main__.Circuit at 0x23acdb18980>,
#  <__main__.Circuit at 0x23acdb189b0>,
#  <__main__.Circuit at 0x23acdb189e0>,
#  <__main__.Circuit at 0x23acdb18ad0>,
#  <__main__.Circuit at 0x23acdb18bf0>,
#  <__main__.Circuit at 0x23acdb18c20>,
#  <__main__.Circuit at 0x23acdb18c80>,
#  <__main__.Circuit at 0x23acdb18d70>,
#  <__main__.Circuit at 0x23acdb18da0>,
#  <__main__.Circuit at 0x23acdb18dd0>,
#  <__main__.Circuit at 0x23acdb18e90>,
#  <__main__.Circuit at 0x23acdb18ec0>,
#  <__main__.Circuit at 0x23acdb18ef0>,
#  <__main__.Circuit at 0x23acdb18fe0>,
#  <__main__.Circuit at 0x23acdb19010>,
#  <__main__.Circuit at 0x23acdb190a0>,
#  <__main__.Circuit at 0x23acdb190d0>,
#  <__main__.Circuit at 0x23acdb19100>,
#  <__main__.Circuit at 0x23acdb19130>,
#  <__main__.Circuit at 0x23acdb191f0>,
#  <__main__.Circuit at 0x23acdb192b0>,
#  <__main__.Circuit at 0x23acdb193a0>,
#  <__main__.Circuit at 0x23acdb193d0>,
#  <__main__.Circuit at 0x23acdb19460>,
#  <__main__.Circuit at 0x23acdb19490>,
#  <__main__.Circuit at 0x23acdb19520>,
#  <__main__.Circuit at 0x23acdb19610>,
#  <__main__.Circuit at 0x23acdb196d0>,
#  <__main__.Circuit at 0x23acdb19700>,
#  <__main__.Circuit at 0x23acdb19730>,
#  <__main__.Circuit at 0x23acdb19850>,
#  <__main__.Circuit at 0x23acdb19910>,
#  <__main__.Circuit at 0x23acdb19a30>,
#  <__main__.Circuit at 0x23acdb19ac0>,
#  <__main__.Circuit at 0x23acdb19c10>,
#  <__main__.Circuit at 0x23acdb19d30>,
#  <__main__.Circuit at 0x23acdb19d60>,
#  <__main__.Circuit at 0x23acdb19df0>,
#  <__main__.Circuit at 0x23acdb19e20>,
#  <__main__.Circuit at 0x23acdb19eb0>,
#  <__main__.Circuit at 0x23acdb19ee0>,
#  <__main__.Circuit at 0x23acdb19fa0>,
#  <__main__.Circuit at 0x23acdb1a000>,
#  <__main__.Circuit at 0x23acdb1a090>,
#  <__main__.Circuit at 0x23acdb1a180>,
#  <__main__.Circuit at 0x23acdb1a1b0>,
#  <__main__.Circuit at 0x23acdb1a270>,
#  <__main__.Circuit at 0x23acdb1a390>,
#  <__main__.Circuit at 0x23acdb1a480>,
#  <__main__.Circuit at 0x23acdb1a510>,
#  <__main__.Circuit at 0x23acdb1a540>,
#  <__main__.Circuit at 0x23acdb1a570>,
#  <__main__.Circuit at 0x23acdb1a630>,
#  <__main__.Circuit at 0x23acdb1a660>,
#  <__main__.Circuit at 0x23acdb1a690>,
#  <__main__.Circuit at 0x23acdb1a720>,
#  <__main__.Circuit at 0x23acdb1a7b0>,
#  <__main__.Circuit at 0x23acdb1a8d0>,
#  <__main__.Circuit at 0x23acdb1a900>,
#  <__main__.Circuit at 0x23acdb1a930>,
#  <__main__.Circuit at 0x23acdb1a990>,
#  <__main__.Circuit at 0x23acdb1aa50>,
#  <__main__.Circuit at 0x23acdb1ab40>,
#  <__main__.Circuit at 0x23acdb1ac30>,
#  <__main__.Circuit at 0x23acdb1ac60>,
#  <__main__.Circuit at 0x23acdb1ad50>,
#  <__main__.Circuit at 0x23acdb1ae70>,
#  <__main__.Circuit at 0x23acdb1af60>,
#  <__main__.Circuit at 0x23acdb1b020>,
#  <__main__.Circuit at 0x23acdb1b0b0>,
#  <__main__.Circuit at 0x23acdb1b1d0>,
#  <__main__.Circuit at 0x23acdb1b200>,
#  <__main__.Circuit at 0x23acdb1b230>,
#  <__main__.Circuit at 0x23acdb1b260>,
#  <__main__.Circuit at 0x23acdb1b290>,
#  <__main__.Circuit at 0x23acdb1b2f0>,
#  <__main__.Circuit at 0x23acdb1b320>,
#  <__main__.Circuit at 0x23acdb1b3e0>,
#  <__main__.Circuit at 0x23acdb1b470>,
#  <__main__.Circuit at 0x23acdb1b4a0>,
#  <__main__.Circuit at 0x23acdb1b4d0>,
#  <__main__.Circuit at 0x23acdb1b560>,
#  <__main__.Circuit at 0x23acdb1b5f0>,
#  <__main__.Circuit at 0x23acdb1b6e0>,
#  <__main__.Circuit at 0x23acdb1b800>,
#  <__main__.Circuit at 0x23acdb1b8f0>,
#  <__main__.Circuit at 0x23acdb1b980>,
#  <__main__.Circuit at 0x23acdb1b9b0>,
#  <__main__.Circuit at 0x23acdb1ba70>,
#  <__main__.Circuit at 0x23acdb1bbc0>,
#  <__main__.Circuit at 0x23acdb1bc80>,
#  <__main__.Circuit at 0x23acdb1bdd0>,
#  <__main__.Circuit at 0x23acdb1be90>,
#  <__main__.Circuit at 0x23acdb1bf20>,
#  <__main__.Circuit at 0x23acdb1bf50>,
#  <__main__.Circuit at 0x23acdb1bf80>,
#  <__main__.Circuit at 0x23acdb3c080>,
#  <__main__.Circuit at 0x23acdb3c170>,
#  <__main__.Circuit at 0x23acdb3c260>,
#  <__main__.Circuit at 0x23acdb3c320>,
#  <__main__.Circuit at 0x23acdb3c440>,
#  <__main__.Circuit at 0x23acdb3c560>,
#  <__main__.Circuit at 0x23acdb3c5f0>,
#  <__main__.Circuit at 0x23acdb3c680>,
#  <__main__.Circuit at 0x23acdb3c7a0>,
#  <__main__.Circuit at 0x23acdb3c7d0>,
#  <__main__.Circuit at 0x23acdb3c800>,
#  <__main__.Circuit at 0x23acdb3c8f0>,
#  <__main__.Circuit at 0x23acdb3ca10>,
#  <__main__.Circuit at 0x23acdb3cb00>,
#  <__main__.Circuit at 0x23acdb3cbf0>,
#  <__main__.Circuit at 0x23acdb3cc20>,
#  <__main__.Circuit at 0x23acdb3cc50>,
#  <__main__.Circuit at 0x23acdb3cc80>,
#  <__main__.Circuit at 0x23acdb3cd40>,
#  <__main__.Circuit at 0x23acdb3ce00>,
#  <__main__.Circuit at 0x23acdb3cf50>,
#  <__main__.Circuit at 0x23acdb3cf80>,
#  <__main__.Circuit at 0x23acdb3cfb0>,
#  <__main__.Circuit at 0x23acdb3d0a0>,
#  <__main__.Circuit at 0x23acdb3d160>,
#  <__main__.Circuit at 0x23acdb3d190>,
#  <__main__.Circuit at 0x23acdb3d250>,
#  <__main__.Circuit at 0x23acdb3d2e0>,
#  <__main__.Circuit at 0x23acdb3d310>,
#  <__main__.Circuit at 0x23acdb3d340>,
#  <__main__.Circuit at 0x23acdb3d3d0>,
#  <__main__.Circuit at 0x23acdb3d490>,
#  <__main__.Circuit at 0x23acdb3d5b0>,
#  <__main__.Circuit at 0x23acdb3d6a0>,
#  <__main__.Circuit at 0x23acdb3d790>,
#  <__main__.Circuit at 0x23acdb3d7c0>,
#  <__main__.Circuit at 0x23acdb3d7f0>,
#  <__main__.Circuit at 0x23acdb3d820>,
#  <__main__.Circuit at 0x23acdb3d8b0>,
#  <__main__.Circuit at 0x23acdb3d940>,
#  <__main__.Circuit at 0x23acdb3d970>,
#  <__main__.Circuit at 0x23acdb3da00>,
#  <__main__.Circuit at 0x23acdb3da30>,
#  <__main__.Circuit at 0x23acdb3da60>,
#  <__main__.Circuit at 0x23acdb3da90>,
#  <__main__.Circuit at 0x23acdb3db80>,
#  <__main__.Circuit at 0x23acdb3dca0>,
#  <__main__.Circuit at 0x23acdb3dd60>,
#  <__main__.Circuit at 0x23acdb3de50>,
#  <__main__.Circuit at 0x23acdb3df10>,
#  <__main__.Circuit at 0x23acdb3dfa0>,
#  <__main__.Circuit at 0x23acdb3dfd0>,
#  <__main__.Circuit at 0x23acdb3e000>,
#  <__main__.Circuit at 0x23acdb3e0c0>,
#  <__main__.Circuit at 0x23acdb3e0f0>,
#  ...]

# %%
simulator = Aer.get_backend('statevector_simulator')
def criar_circuito(num_qubits, num_gates_por_qubit):
    qc = QuantumCircuit(num_qubits, num_gates_por_qubit)
    for qubit in range(num_qubits):
        for _ in range(num_gates_por_qubit):
            qc.h(qubit)  # Aplicando a porta de Hadamard como exemplo
    #qc.measure_all()
    return qc
def simular_circuito(qc, simulador):
    qc_simulator = transpile(qc, backend=simulador)
    job = simulador.run(qc_simulator, shots=1024)
    return job

# %%
qc_1 = criar_circuito(3, 0)
qc_2 = criar_circuito(3, 0)

# %%
qc_1.draw()
qc_1.r()
# Out:
#
# q_0:
#
# q_1:
#
# q_2:

# %%
qc_2.draw()
# Out:
#
# q_0:
#
# q_1:
#
# q_2:

# %%
#job_1 = simular_circuito(qc_1, simulator)
sv2 = Statevector.from_label("000")
sv2 = sv2.evolve(qc_2)
#job_1 = simular_circuito(qc_1, simulator)
sv1 = Statevector.from_label("000")
sv1 = sv1.evolve(qc_1)
state_fidelity(sv1, sv2)
# Out:
# 1.0

# %%
#job_2 = simular_circuito(qc_2, simulator)

# %%
result = job_1.result()

# %%
result.get_statevector()
# Out:
# Statevector([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2, 2))

# %%
result1 = job_2.result()

# %%
result1.get_statevector()
# Out:
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2, 2))

# %%
import matplotlib.pyplot as plt
import numpy as np

# Supondo que o statevector já esteja calculado e armazenado em uma lista


# Calculando as probabilidades
probabilities = np.abs(statevector)**2

# Criando os rótulos dos estados computacionais (ajuste conforme necessário)
states = ['0', '1']

# Criando o gráfico de barras
plt.bar(states, probabilities)
plt.xlabel('Computational basis states')
plt.ylabel('Amplitude')
plt.title('Probabilities')
plt.show()

# %%
statevector = result.get_statevector() # Substitua pelos seus valores
statevector2 = result1.get_statevector()
state_fidelity(statevector, statevector2)
# Out:
# 0.0
